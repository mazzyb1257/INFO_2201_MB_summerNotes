# %% [markdown]
# # Week 3 Day 2: CSV Files
#
# * CSV files
# * JSON Files

# %% [markdown]
# ## CSV Files
# comma-separated values
#
# The most common import and export format for spreadsheets and databases. CSV format was used for many years prior to attempts to describe the format in a standardized way.
# The lack of a well-defined standard means that subtle differences often exist in the data produced and consumed by different applications. These differences can make it annoying to process CSV files from multiple sources. Still, while the delimiters and quoting characters vary, the overall format is similar enough that it is possible to write a single module which can efficiently manipulate such data, hiding the details of reading and writing the data from the programmer.

# %%
# python has a library that simlifies reading csv files
import csv

# %% [markdown]
# #### csv.reader(csvfile, dialect='excel', **fmtparams)
#
# Return a reader object that will process lines from the given csvfile. A csvfile must be an iterable of strings, each in the reader’s defined csv format.
#
# We wil make a csvReader to read the csv file this creates an object that we can use to read csv files. A csvReader is a stream based parser for CSV files.
#
# link to documentation and info - [https://docs.python.org/3/library/csv.html]

# %%
#create a list to append the rows
myList = []

# we use with because it automatically closes the file when we're done with it
with open("data/movies.csv", 'r') as f:
    # file handle: not the contents of the file, but the way python "talks" to the file itself
    csvReader = csv.reader(f, delimiter= ',', quotechar='"')

    # skip the header
    next(csvReader) # start here,  pass by header
    for row in csvReader:
        myList.append(row)
# out here (not indented), the file is closed

# %%
# Data access
myList
# Out:
# [['0',
#   'The Shawshank Redemption',
#   '(1994)',
#   '142 mins.',
#   '9.3',
#   '1,432,740',
#   "[u'Crime', u'Drama']",
#   'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#   '$28.3M'],
#  ['1',
#   'The Dark Knight',
#   '(2008)',
#   '152 mins.',
#   '9.0',
#   '1,403,109',
#   "[u'Action', u'Crime', u'Drama']",
#   'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, the caped crusader must come to terms with one of the greatest psychological tests of his ability to fight injustice.',
#   '$533M'],
#  ['2',
#   'Inception',
#   '(2010)',
#   '148 mins.',
#   '8.8',
#   '1,202,244',
#   "[u'Action', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'A thief who steals corporate secrets through use of dream-sharing technology is given the inverse task of planting an idea into the mind of a CEO.',
#   '$293M'],
#  ['3',
#   'Fight Club',
#   '(1999)',
#   '139 mins.',
#   '8.9',
#   '1,117,474',
#   "[u'Drama']",
#   'An insomniac office worker looking for a way to change his life crosses paths with a devil-may-care soap maker and they form an underground fight club that evolves into something much, much more...',
#   '$37M'],
#  ['4',
#   'Pulp Fiction',
#   '(1994)',
#   '154 mins.',
#   '8.9',
#   '1,111,865',
#   "[u'Crime', u'Drama']",
#   "The lives of two mob hit men, a boxer, a gangster's wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
#   '$108M'],
#  ['5',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '(2001)',
#   '178 mins.',
#   '8.8',
#   '1,051,858',
#   "[u'Adventure', u'Fantasy']",
#   'A meek hobbit of the Shire and eight companions set out on a journey to Mount Doom to destroy the One Ring and the dark lord Sauron.',
#   '$314M'],
#  ['6',
#   'The Lord of the Rings: The Return of the King',
#   '(2003)',
#   '201 mins.',
#   '8.9',
#   '1,025,707',
#   "[u'Adventure', u'Fantasy']",
#   "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#   '$377M'],
#  ['7',
#   'The Matrix',
#   '(1999)',
#   '136 mins.',
#   '8.7',
#   '1,021,947',
#   "[u'Action', u'Sci-Fi']",
#   'A computer hacker learns from mysterious rebels about the true nature of his reality and his role in the war against its controllers.',
#   '$171M'],
#  ['8',
#   'Forrest Gump',
#   '(1994)',
#   '142 mins.',
#   '8.8',
#   '1,017,208',
#   "[u'Drama', u'Romance']",
#   'Forrest Gump, while not intelligent, has accidentally been present at many historic moments, but his true love, Jenny Curran, eludes him.',
#   '$330M'],
#  ['9',
#   'The Godfather',
#   '(1972)',
#   '175 mins.',
#   '9.2',
#   '984,305',
#   "[u'Crime', u'Drama']",
#   'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.',
#   '$135M'],
#  ['10',
#   'The Dark Knight Rises',
#   '(2012)',
#   '165 mins.',
#   '8.5',
#   '945,876',
#   "[u'Action', u'Thriller']",
#   "Eight years after the Joker's reign of anarchy, the Dark Knight is forced to return from his imposed exile to save Gotham City from the brutal guerrilla terrorist Bane with the help of the enigmatic Catwoman.",
#   '$448M'],
#  ['11',
#   'The Lord of the Rings: The Two Towers',
#   '(2002)',
#   '179 mins.',
#   '8.8',
#   '923,713',
#   "[u'Adventure', u'Fantasy']",
#   "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.",
#   '$340M'],
#  ['12',
#   'Se7en',
#   '(1995)',
#   '127 mins.',
#   '8.7',
#   '851,272',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his modus operandi.',
#   '$100M'],
#  ['13',
#   'Gladiator',
#   '(2000)',
#   '155 mins.',
#   '8.5',
#   '819,344',
#   "[u'Action', u'Drama']",
#   "When a Roman general is betrayed and his family murdered by an emperor's corrupt son, he comes to Rome as a gladiator to seek revenge.",
#   '$188M'],
#  ['14',
#   'Batman Begins',
#   '(2005)',
#   '140 mins.',
#   '8.3',
#   '805,368',
#   "[u'Action', u'Adventure']",
#   'After training with his mentor, Batman begins his war on crime to free the crime-ridden Gotham City from corruption that the Scarecrow and the League of Shadows have cast upon it.',
#   '$205M'],
#  ['15',
#   'The Avengers',
#   '(2012)',
#   '143 mins.',
#   '8.2',
#   '803,232',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   "Earth's mightiest heroes must come together and learn to fight as a team if they are to stop the mischievous Loki and his alien army from enslaving humanity.",
#   '$623M'],
#  ['16',
#   'Avatar',
#   '(2009)',
#   '162 mins.',
#   '7.9',
#   '772,274',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'A Paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home..',
#   '$761M'],
#  ['17',
#   'Django Unchained',
#   '(2012)',
#   '165 mins.',
#   '8.5',
#   '756,347',
#   "[u'Western']",
#   'With the help of a German bounty hunter, a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner.',
#   '$163M'],
#  ['18',
#   'Game of Thrones',
#   '(2011 TV Series)',
#   '55 mins.',
#   '9.5',
#   '748,557',
#   "[u'Adventure', u'Drama', u'Fantasy']",
#   'Several noble families fight for control of the mythical land of Westeros.',
#   '-'],
#  ['19',
#   'Game of Thrones',
#   '(2011 TV Series)',
#   '55 mins.',
#   '9.5',
#   '748,557',
#   "[u'Adventure', u'Drama', u'Fantasy']",
#   'Several noble families fight for control of the mythical land of Westeros.',
#   '-'],
#  ['20',
#   'Game of Thrones',
#   '(2011 TV Series)',
#   '55 mins.',
#   '9.5',
#   '20,405',
#   "[u'Adventure', u'Drama', u'Fantasy']",
#   "Joffery and Margaery's wedding has come. Tyrion breaks up with Shae. Ramsay tries to prove his worth to his father. Bran and company find a Weirwood tree.",
#   '-'],
#  ['21',
#   'Game of Thrones',
#   '(2011 TV Series)',
#   '55 mins.',
#   '9.5',
#   '20,405',
#   "[u'Adventure', u'Drama', u'Fantasy']",
#   "Joffery and Margaery's wedding has come. Tyrion breaks up with Shae. Ramsay tries to prove his worth to his father. Bran and company find a Weirwood tree.",
#   '-'],
#  ['22',
#   'Star Wars',
#   '(1977)',
#   '121 mins.',
#   '8.7',
#   '737,343',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a wookiee and two droids to save the universe from the Empire's world-destroying battle-station, while also attempting to rescue Princess Leia from the evil Darth Vader.",
#   '$461M'],
#  ['23',
#   'Saving Private Ryan',
#   '(1998)',
#   '169 mins.',
#   '8.6',
#   '732,198',
#   "[u'Action', u'Drama', u'War']",
#   'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.',
#   '$216M'],
#  ['24',
#   'The Departed',
#   '(2006)',
#   '151 mins.',
#   '8.5',
#   '728,338',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   '$132M'],
#  ['25',
#   'The Silence of the Lambs',
#   '(1991)',
#   '118 mins.',
#   '8.6',
#   '726,528',
#   "[u'Drama', u'Thriller']",
#   'A young F.B.I. cadet must confide in an incarcerated and manipulative killer to receive his help on catching another serial killer who skins his victims.',
#   '$131M'],
#  ['26',
#   'Schindler&#x27;s List',
#   '(1993)',
#   '195 mins.',
#   '8.9',
#   '726,392',
#   "[u'Biography', u'Drama', u'History']",
#   'In Poland during World War II, Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
#   '$96.1M'],
#  ['27',
#   'Memento',
#   '(2000)',
#   '113 mins.',
#   '8.5',
#   '720,581',
#   "[u'Mystery', u'Thriller']",
#   'A man creates a strange system to help him remember things; so he can hunt for the murderer of his wife without his short-term memory loss being an obstacle.',
#   '$25.5M'],
#  ['28',
#   'Inglourious Basterds',
#   '(2009)',
#   '153 mins.',
#   '8.3',
#   '712,003',
#   "[u'Adventure', u'Drama', u'War']",
#   "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.",
#   '$121M'],
#  ['29',
#   'American Beauty',
#   '(1999)',
#   '122 mins.',
#   '8.4',
#   '706,155',
#   "[u'Drama']",
#   "A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.",
#   '$130M'],
#  ['30',
#   'The Prestige',
#   '(2006)',
#   '130 mins.',
#   '8.5',
#   '696,541',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'Two stage magicians engage in competitive one-upmanship in an attempt to create the ultimate stage illusion.',
#   '$53.1M'],
#  ['31',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '(2003)',
#   '143 mins.',
#   '8.1',
#   '685,999',
#   "[u'Adventure', u'Fantasy']",
#   'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#   '$305M'],
#  ['32',
#   'Titanic',
#   '(1997)',
#   '194 mins.',
#   '7.7',
#   '674,725',
#   "[u'Drama', u'Romance']",
#   'A seventeen-year-old aristocrat, expecting to be married to a rich claimant by her mother, falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
#   '$659M'],
#  ['33',
#   'V for Vendetta',
#   '(2005)',
#   '132 mins.',
#   '8.2',
#   '671,045',
#   "[u'Action', u'Drama', u'Thriller']",
#   'In a future British tyranny, a shadowy freedom fighter, known only by the alias of "V", plots to overthrow it with the help of a young woman.',
#   '$70.5M'],
#  ['34',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '(1980)',
#   '124 mins.',
#   '8.8',
#   '668,362',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'After the rebels have been brutally overpowered by the Empire on their newly established base, Luke Skywalker takes advanced Jedi training with Master Yoda, while his friends are pursued by Darth Vader as part of his plan to capture Luke.',
#   '$290M'],
#  ['35',
#   'American History X',
#   '(1998)',
#   '119 mins.',
#   '8.6',
#   '664,503',
#   "[u'Crime', u'Drama']",
#   'A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.',
#   '$6.71M'],
#  ['36',
#   'Breaking Bad',
#   '(2008 TV Series)',
#   '45 mins.',
#   '9.5',
#   '662,459',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A chemistry teacher diagnosed with a terminal lung cancer, teams up with his former student, Jesse Pinkman, to cook and sell crystal meth.',
#   '-'],
#  ['37',
#   'The Godfather: Part II',
#   '(1974)',
#   '200 mins.',
#   '9.1',
#   '660,916',
#   "[u'Crime', u'Drama']",
#   'The early life and career of Vito Corleone in 1920s New York is portrayed while his son, Michael, expands and tightens his grip on his crime syndicate stretching from Lake Tahoe, Nevada to pre-revolution 1958 Cuba.',
#   '$57.3M'],
#  ['38',
#   'The Green Mile',
#   '(1999)',
#   '189 mins.',
#   '8.5',
#   '635,348',
#   "[u'Crime', u'Drama', u'Fantasy', u'Mystery']",
#   'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.',
#   '$137M'],
#  ['39',
#   'Shutter Island',
#   '(2010)',
#   '138 mins.',
#   '8.1',
#   '632,242',
#   "[u'Mystery', u'Thriller']",
#   'A U.S Marshal investigates the disappearance of a murderess who escaped from a hospital for the criminally insane.',
#   '$128M'],
#  ['40',
#   'The Usual Suspects',
#   '(1995)',
#   '106 mins.',
#   '8.7',
#   '627,597',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which begin when five criminals meet at a seemingly random police lineup.',
#   '$23.3M'],
#  ['41',
#   'Braveheart',
#   '(1995)',
#   '177 mins.',
#   '8.4',
#   '626,107',
#   "[u'Action', u'Biography', u'Drama', u'History', u'War']",
#   'When his secret bride is executed for assaulting an English soldier who tried to rape her, William Wallace begins a revolt and leads Scottish warriors against the cruel English tyrant who rules Scotland with an iron fist.',
#   '$75.6M'],
#  ['42',
#   'Terminator 2: Judgment Day',
#   '(1991)',
#   '137 mins.',
#   '8.5',
#   '624,949',
#   "[u'Action', u'Sci-Fi']",
#   'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her young son, John Connor, from a more advanced cyborg, made out of liquid metal.',
#   '$205M'],
#  ['43',
#   'Goodfellas',
#   '(1990)',
#   '146 mins.',
#   '8.7',
#   '616,407',
#   "[u'Biography', u'Crime', u'Drama']",
#   'Henry Hill and his friends work their way up through the mob hierarchy.',
#   '$46.8M'],
#  ['44',
#   'Kill Bill: Vol. 1',
#   '(2003)',
#   '111 mins.',
#   '8.1',
#   '616,328',
#   "[u'Action']",
#   'The Bride wakens from a four-year coma. The child she carried in her womb is gone. Now she must wreak vengeance on the team of assassins who betrayed her - a team she was once part of.',
#   '$70.1M'],
#  ['45',
#   'The Sixth Sense',
#   '(1999)',
#   '107 mins.',
#   '8.2',
#   '606,105',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   "A boy who communicates with spirits that don't know they're dead seeks the help of a disheartened child psychologist.",
#   '$294M'],
#  ['46',
#   'L&#xE9;on: The Professional',
#   '(1994)',
#   '110 mins.',
#   '8.6',
#   '605,118',
#   "[u'Crime', u'Drama', u'Thriller']",
#   "Mathilda, a 12-year-old girl, is reluctantly taken in by Léon, a professional assassin, after her family is murdered. Léon and Mathilda form an unusual relationship, as she becomes his protégée and learns the assassin's trade.",
#   '$32.3M'],
#  ['47',
#   'The Hunger Games',
#   '(2012)',
#   '142 mins.',
#   '7.3',
#   '604,473',
#   "[u'Adventure', u'Sci-Fi']",
#   "Katniss Everdeen voluntarily takes her younger sister's place in the Hunger Games, a televised fight to the death in which two teenagers from each of the twelve Districts of Panem are chosen at random to compete.",
#   '$408M'],
#  ['48',
#   'Back to the Future',
#   '(1985)',
#   '116 mins.',
#   '8.5',
#   '591,958',
#   "[u'Adventure', u'Comedy', u'Sci-Fi']",
#   'A young man is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his friend, Dr. Emmett Brown, and must make sure his high-school-age parents unite in order to save his own existence.',
#   '$211M'],
#  ['49',
#   'WALL&#xB7;E',
#   '(2008)',
#   '98 mins.',
#   '8.4',
#   '584,687',
#   "[u'Animation', u'Adventure', u'Sci-Fi']",
#   'In the distant future, a small waste collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.',
#   '$224M'],
#  ['50',
#   'One Flew Over the Cuckoo&#x27;s Nest',
#   '(1975)',
#   '133 mins.',
#   '8.7',
#   '582,369',
#   "[u'Drama']",
#   'Upon admittance to a mental institution, a brash rebel rallies the patients to take on the oppressive head nurse.',
#   '$112M'],
#  ['51',
#   'Sin City',
#   '(2005)',
#   '124 mins.',
#   '8.1',
#   '575,989',
#   "[u'Crime', u'Thriller']",
#   'A film that explores the dark and miserable town, Basin City, and tells the story of three different people, all caught up in violent corruption.',
#   '$74.1M'],
#  ['52',
#   'Iron Man',
#   '(2008)',
#   '126 mins.',
#   '7.9',
#   '575,561',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'After being held captive in an Afghan cave, an industrialist creates a unique weaponized suit of armor to fight against evil. This leads him to conflict within his own company.',
#   '$318M'],
#  ['53',
#   'Interstellar',
#   '(2014)',
#   '169 mins.',
#   '8.7',
#   '573,941',
#   "[u'Adventure', u'Sci-Fi']",
#   "A team of explorers travel through a wormhole in an attempt to ensure humanity's survival.",
#   '$188M'],
#  ['54',
#   'The Wolf of Wall Street',
#   '(2013)',
#   '180 mins.',
#   '8.2',
#   '570,229',
#   "[u'Biography', u'Comedy', u'Crime', u'Drama']",
#   'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#   '$117M'],
#  ['55',
#   'Eternal Sunshine of the Spotless Mind',
#   '(2004)',
#   '108 mins.',
#   '8.4',
#   '564,716',
#   "[u'Drama', u'Romance', u'Sci-Fi']",
#   'When their relationship turns sour, a couple undergoes a procedure to have each other erased from their memories. But it is only through the process of loss that they discover what they had to begin with.',
#   '$34.1M'],
#  ['56',
#   'Slumdog Millionaire',
#   '(2008)',
#   '120 mins.',
#   '8.0',
#   '561,301',
#   "[u'Drama', u'Romance']",
#   'A Mumbai teen who grew up in the slums, becomes a contestant on the Indian version of "Who Wants To Be A Millionaire?" He is arrested under suspicion of cheating, and while being interrogated, events from his life history are shown which explain why he knows the answers.',
#   '$141M'],
#  ['57',
#   'Raiders of the Lost Ark',
#   '(1981)',
#   '115 mins.',
#   '8.6',
#   '559,742',
#   "[u'Action', u'Adventure']",
#   'Archaeologist and adventurer Indiana Jones is hired by the US government to find the Ark of the Covenant before the Nazis.',
#   '$3.12M'],
#  ['58',
#   'Finding Nemo',
#   '(2003)',
#   '100 mins.',
#   '8.2',
#   '556,702',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family']",
#   'After his son is captured in the Great Barrier Reef and taken to Sydney, a timid clownfish sets out on a journey to bring him home.',
#   '$381M'],
#  ['59',
#   'The Truman Show',
#   '(1998)',
#   '103 mins.',
#   '8.1',
#   '555,094',
#   "[u'Drama']",
#   'An insurance salesman/adjuster discovers his entire life is actually a T.V. show.',
#   '$126M'],
#  ['60',
#   'The Hobbit: An Unexpected Journey',
#   '(2012)',
#   '169 mins.',
#   '8.0',
#   '551,781',
#   "[u'Adventure', u'Fantasy']",
#   'A reluctant hobbit, Bilbo Baggins, sets out to the Lonely Mountain with a spirited group of dwarves to reclaim their mountain home - and the gold within it - from the dragon Smaug.',
#   '$303M'],
#  ['61',
#   'Reservoir Dogs',
#   '(1992)',
#   '99 mins.',
#   '8.4',
#   '551,509',
#   "[u'Crime', u'Drama']",
#   'After a simple jewelery heist goes terribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#   '$2.81M'],
#  ['62',
#   '300',
#   '(2006)',
#   '117 mins.',
#   '7.8',
#   '538,231',
#   "[u'Action', u'Fantasy', u'War']",
#   'King Leonidas and a force of 300 men fight the Persians at Thermopylae in 480 B.C.',
#   '$211M'],
#  ['63',
#   'Up',
#   '(2009)',
#   '96 mins.',
#   '8.3',
#   '530,637',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family']",
#   'To avoid being taken away to a nursing home, an old widower tries to fly his home to Paradise Falls, South America, along with a boy scout who accidentally lifted off with him.',
#   '$293M'],
#  ['64',
#   'Star Wars: Episode VI - Return of the Jedi',
#   '(1983)',
#   '134 mins.',
#   '8.4',
#   '530,513',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'After rescuing Han Solo from the palace of Jabba the Hutt, the rebels attempt to destroy the second Death Star, while Luke struggles to make Vader return from the dark side of the Force.',
#   '$309M'],
#  ['65',
#   'No Country for Old Men',
#   '(2007)',
#   '122 mins.',
#   '8.1',
#   '518,189',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'Violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the Rio Grande.',
#   '$74.3M'],
#  ['66',
#   'The Lion King',
#   '(1994)',
#   '89 mins.',
#   '8.5',
#   '516,146',
#   "[u'Animation', u'Adventure', u'Drama', u'Family', u'Musical']",
#   'Tricked into thinking that he caused the death of his father, a lion cub flees and abandons his destiny as the future king.',
#   '$423M'],
#  ['67',
#   'Snatch.',
#   '(2000)',
#   '104 mins.',
#   '8.3',
#   '514,705',
#   "[u'Comedy', u'Crime']",
#   'Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers, and supposedly Jewish jewelers fight to track down a priceless stolen diamond.',
#   '$30.1M'],
#  ['68',
#   'The Hangover',
#   '(2009)',
#   '100 mins.',
#   '7.8',
#   '509,267',
#   "[u'Comedy']",
#   'Three buddies wake up from a bachelor party in Las Vegas, with no memory of the previous night and the bachelor missing. They make their way around the city in order to find their friend before his wedding.',
#   '$277M'],
#  ['69',
#   'Die Hard',
#   '(1988)',
#   '131 mins.',
#   '8.3',
#   '507,948',
#   "[u'Action', u'Thriller']",
#   'John McClane, officer of the NYPD, tries to save wife Holly Gennaro and several others, taken hostage by German terrorist Hans Gruber during a Christmas party at the Nakatomi Plaza in Los Angeles.',
#   '$81.4M'],
#  ['70',
#   'The Shining',
#   '(1980)',
#   '146 mins.',
#   '8.5',
#   '507,274',
#   "[u'Horror']",
#   'A family heads to an isolated hotel for the winter where an evil and spiritual presence influences the father into violence, while his psychic son sees horrific forebodings from the past and of the future.',
#   '-'],
#  ['71',
#   'Good Will Hunting',
#   '(1997)',
#   '126 mins.',
#   '8.3',
#   '506,565',
#   "[u'Drama']",
#   'Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.',
#   '$138M'],
#  ['72',
#   'Toy Story',
#   '(1995)',
#   '81 mins.',
#   '8.3',
#   '504,598',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']",
#   "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#   '$30.6M'],
#  ['73',
#   'Donnie Darko',
#   '(2001)',
#   '113 mins.',
#   '8.1',
#   '501,588',
#   "[u'Drama', u'Mystery', u'Sci-Fi']",
#   'A troubled teenager is plagued by visions of a large bunny rabbit that manipulates him to commit a series of crimes, after narrowly escaping a bizarre accident.',
#   '$728K'],
#  ['74',
#   'The Walking Dead',
#   '(2010 TV Series)',
#   '44 mins.',
#   '8.7',
#   '500,301',
#   "[u'Drama', u'Horror']",
#   "Sheriff's Deputy Rick Grimes leads a group of survivors in a world overrun by zombies.",
#   '-'],
#  ['75',
#   'The Terminator',
#   '(1984)',
#   '107 mins.',
#   '8.1',
#   '497,269',
#   "[u'Action', u'Sci-Fi']",
#   'A human-looking indestructible cyborg is sent from 2029 to 1984 to assassinate a waitress, whose unborn son will lead humanity in a war against the machines, while a soldier from that war is sent to protect her at all costs.',
#   '$38.4M'],
#  ['76',
#   'A Beautiful Mind',
#   '(2001)',
#   '135 mins.',
#   '8.2',
#   '496,484',
#   "[u'Biography', u'Drama']",
#   'After a brilliant but asocial mathematician accepts secret work in cryptography, his life takes a turn for the nightmarish.',
#   '$171M'],
#  ['77',
#   'Gravity',
#   '(2013)',
#   '91 mins.',
#   '7.9',
#   '490,641',
#   "[u'Sci-Fi', u'Thriller']",
#   'A medical engineer and an astronaut work together to survive after a catastrophe destroys their shuttle and leaves them adrift in orbit.',
#   '$274M'],
#  ['78',
#   'Requiem for a Dream',
#   '(2000)',
#   '102 mins.',
#   '8.4',
#   '490,405',
#   "[u'Drama']",
#   'The drug-induced utopias of four Coney Island people are shattered when their addictions become stronger.',
#   '$3.61M'],
#  ['79',
#   'Black Swan',
#   '(2010)',
#   '108 mins.',
#   '8.0',
#   '483,689',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'A ballet dancer wins the lead in "Swan Lake" and is perfect for the role of the delicate White Swan - Princess Odette - but slowly loses her mind as she becomes more and more like Odile, the Black Swan.',
#   '$107M'],
#  ['80',
#   'Gran Torino',
#   '(2008)',
#   '116 mins.',
#   '8.2',
#   '482,168',
#   "[u'Drama']",
#   "Disgruntled Korean War veteran Walt Kowalski sets out to reform his neighbor, a Hmong teenager who tried to steal Kowalski's prized possession: a 1972 Gran Torino.",
#   '$148M'],
#  ['81',
#   'District 9',
#   '(2009)',
#   '112 mins.',
#   '8.0',
#   '475,240',
#   "[u'Action', u'Sci-Fi', u'Thriller']",
#   'An extraterrestrial race forced to live in slum-like conditions on Earth suddenly finds a kindred spirit in a government agent who is exposed to their biotechnology.',
#   '$116M'],
#  ['82',
#   'Alien',
#   '(1979)',
#   '117 mins.',
#   '8.5',
#   '473,408',
#   "[u'Horror', u'Sci-Fi']",
#   'The commercial vessel Nostromo receives a distress call from an unexplored planet. After searching for survivors, the crew heads home only to realize that a deadly bioform has joined them.',
#   '$1.98M'],
#  ['83',
#   'Jurassic Park',
#   '(1993)',
#   '127 mins.',
#   '8.0',
#   '471,677',
#   "[u'Adventure', u'Sci-Fi', u'Thriller']",
#   'During a preview tour, a theme park suffers a major power breakdown that allows its cloned dinosaur exhibits to run amok.',
#   '$402M'],
#  ['84',
#   'Monsters, Inc.',
#   '(2001)',
#   '92 mins.',
#   '8.1',
#   '469,750',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']",
#   "Monsters generate their city's power by scaring children, but they are terribly afraid themselves of being contaminated by children, so when one enters Monstropolis, top scarer Sulley finds his world disrupted.",
#   '$290M'],
#  ['85',
#   'A Clockwork Orange',
#   '(1971)',
#   '136 mins.',
#   '8.4',
#   '467,573',
#   "[u'Crime', u'Drama', u'Sci-Fi']",
#   "In future Britain, charismatic delinquent Alex DeLarge is jailed and volunteers for an experimental aversion therapy developed by the government in an effort to solve society's crime problem - but not all goes according to plan.",
#   '-'],
#  ['86',
#   'Spider-Man',
#   '(2002)',
#   '121 mins.',
#   '7.3',
#   '465,635',
#   "[u'Action', u'Adventure']",
#   'When bitten by a genetically modified spider, a nerdy, shy, and awkward high school student gains spider-like abilities that he eventually must use to fight evil as a superhero after tragedy befalls his family.',
#   '$404M'],
#  ['87',
#   'Guardians of the Galaxy',
#   '(2014)',
#   '121 mins.',
#   '8.1',
#   '458,920',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#   '$333M'],
#  ['88',
#   'City of God',
#   '(2002)',
#   '130 mins.',
#   '8.7',
#   '458,064',
#   "[u'Crime', u'Drama']",
#   'Two boys growing up in a violent neighborhood of Rio de Janeiro take different paths: one becomes a photographer, the other a drug dealer.',
#   '$7.56M'],
#  ['89',
#   'Transformers',
#   '(2007)',
#   '144 mins.',
#   '7.2',
#   '456,919',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'An ancient struggle between two Cybertronian races, the heroic Autobots and the evil Decepticons, comes to Earth, with a clue to the ultimate power held by a teenager.',
#   '$319M'],
#  ['90',
#   'Silver Linings Playbook',
#   '(2012)',
#   '122 mins.',
#   '7.8',
#   '456,784',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'After a stint in a mental institution, former teacher Pat Solitano moves back in with his parents and tries to reconcile with his ex-wife. Things get more challenging when Pat meets Tiffany, a mysterious girl with problems of her own.',
#   '$132M'],
#  ['91',
#   'Star Trek',
#   '(2009)',
#   '127 mins.',
#   '8.0',
#   '456,491',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   "The brash James T. Kirk tries to live up to his father's legacy with Mr. Spock keeping him in check as a vengeful, time-traveling Romulan creates black holes to destroy the Federation one planet at a time.",
#   '$258M'],
#  ['92',
#   'Man of Steel',
#   '(2013)',
#   '143 mins.',
#   '7.2',
#   '456,137',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'Clark Kent, one of the last of an extinguished race disguised as an unremarkable human, is forced to reveal his identity when Earth is invaded by an army of survivors who threaten to bring the planet to the brink of destruction.',
#   '$291M'],
#  ['93',
#   'Iron Man 3',
#   '(2013)',
#   '130 mins.',
#   '7.3',
#   '455,264',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   "When Tony Stark's world is torn apart by a formidable terrorist called the Mandarin, he starts an odyssey of rebuilding and retribution.",
#   '$409M'],
#  ['94',
#   'Am&#xE9;lie',
#   '(2001)',
#   '122 mins.',
#   '8.4',
#   '454,611',
#   "[u'Comedy', u'Romance']",
#   'Amelie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.',
#   '$33.2M'],
#  ['95',
#   'Scarface',
#   '(1983)',
#   '170 mins.',
#   '8.3',
#   '454,286',
#   "[u'Crime', u'Drama']",
#   'In 1980 Miami, a determined Cuban immigrant takes over a drug cartel while succumbing to greed.',
#   '$656K'],
#  ['96',
#   'The Big Lebowski',
#   '(1998)',
#   '117 mins.',
#   '8.2',
#   '453,368',
#   "[u'Comedy', u'Crime']",
#   '"The Dude" Lebowski, mistaken for a millionaire Lebowski, seeks restitution for his ruined rug and enlists his bowling buddies to help get it.',
#   '$17.4M'],
#  ['97',
#   'I Am Legend',
#   '(2007)',
#   '101 mins.',
#   '7.2',
#   '451,463',
#   "[u'Drama', u'Sci-Fi', u'Thriller']",
#   'Years after a plague kills most of humanity and transforms the rest into monsters, the sole survivor in New York City struggles valiantly to find a cure.',
#   '$256M'],
#  ['98',
#   'Pirates of the Caribbean: Dead Man&#x27;s Chest',
#   '(2006)',
#   '151 mins.',
#   '7.3',
#   '448,727',
#   "[u'Action', u'Adventure', u'Fantasy']",
#   "Jack Sparrow races to recover the heart of Davy Jones to avoid enslaving his soul to Jones' service, as other friends and foes seek the heart for their own agenda as well.",
#   '$423M'],
#  ['99',
#   'Toy Story 3',
#   '(2010)',
#   '103 mins.',
#   '8.4',
#   '442,969',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']",
#   "The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.",
#   '$415M'],
#  ['100',
#   'Kill Bill: Vol. 2',
#   '(2004)',
#   '137 mins.',
#   '8.0',
#   '442,747',
#   "[u'Action', u'Crime', u'Thriller']",
#   'The Bride continues her quest of vengeance against her former boss and lover Bill, the reclusive bouncer Budd and the treacherous, one-eyed Elle.',
#   '$66.2M'],
#  ['101',
#   'Skyfall',
#   '(2012)',
#   '143 mins.',
#   '7.8',
#   '440,214',
#   "[u'Action', u'Thriller']",
#   "Bond's loyalty to M is tested when her past comes back to haunt her. Whilst MI6 comes under attack, 007 must track down and destroy the threat, no matter how personal the cost.",
#   '$304M'],
#  ['102',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '(2011)',
#   '130 mins.',
#   '8.1',
#   '440,293',
#   "[u'Adventure', u'Fantasy', u'Mystery']",
#   "Harry, Ron and Hermione search for Voldemort's remaining Horcruxes in their effort to destroy the Dark Lord as the final battle rages on at Hogwarts.",
#   '$381M'],
#  ['103',
#   'The Big Bang Theory',
#   '(2007 TV Series)',
#   '22 mins.',
#   '8.5',
#   '438,226',
#   "[u'Comedy']",
#   'A woman who moves into an apartment across the hall from two brilliant but socially awkward physicists shows them how little they know about life outside of the laboratory.',
#   '-'],
#  ['104',
#   'Thor',
#   '(2011)',
#   '115 mins.',
#   '7.0',
#   '434,550',
#   "[u'Action', u'Adventure', u'Fantasy']",
#   'The powerful but arrogant god Thor is cast out of Asgard to live amongst humans in Midgard (Earth), where he soon becomes one of their finest defenders.',
#   '$181M'],
#  ['105',
#   'Indiana Jones and the Last Crusade',
#   '(1989)',
#   '127 mins.',
#   '8.3',
#   '432,552',
#   "[u'Action', u'Adventure']",
#   "When Dr. Henry Jones Sr. suddenly goes missing while pursuing the Holy Grail, eminent archaeologist Indiana Jones must follow in his father's footsteps and stop the Nazis.",
#   '$197M'],
#  ['106',
#   'Taken',
#   '(2008)',
#   '93 mins.',
#   '7.9',
#   '431,838',
#   "[u'Action', u'Thriller']",
#   'A retired CIA agent travels across Europe and relies on his old skills to save his estranged daughter, who has been kidnapped while on a trip to Paris.',
#   '$145M'],
#  ['107',
#   'Star Wars: Episode I - The Phantom Menace',
#   '(1999)',
#   '136 mins.',
#   '6.6',
#   '431,125',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'Two Jedi Knights escape a hostile blockade to find allies and come across a young boy who may bring balance to the Force, but the long dormant Sith resurface to reclaim their old glory.',
#   '$475M'],
#  ['108',
#   'X-Men: First Class',
#   '(2011)',
#   '132 mins.',
#   '7.8',
#   '430,664',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'In 1962, the United States government enlists the help of Mutants with superhuman abilities to stop a malicious dictator who is determined to start World War III.',
#   '$146M'],
#  ['109',
#   'The Good, the Bad and the Ugly',
#   '(1966)',
#   '161 mins.',
#   '8.9',
#   '429,249',
#   "[u'Western']",
#   'A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.',
#   '$6.1M'],
#  ['110',
#   'Iron Man 2',
#   '(2010)',
#   '124 mins.',
#   '7.1',
#   '424,748',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   "With the world now aware of his identity as Iron Man, Tony Stark must contend with both his declining health and a vengeful mad man with ties to his father's legacy.",
#   '$312M'],
#  ['111',
#   'Taxi Driver',
#   '(1976)',
#   '113 mins.',
#   '8.4',
#   '424,332',
#   "[u'Crime', u'Drama']",
#   'A mentally unstable Vietnam war veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#   '-'],
#  ['112',
#   'Dexter',
#   '(2006 TV Series)',
#   '55 mins.',
#   '8.9',
#   '419,031',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A Miami police forensics expert moonlights as a serial killer of criminals whom he believes have escaped justice.',
#   '-'],
#  ['113',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '(2005)',
#   '140 mins.',
#   '7.7',
#   '417,972',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'As the Clone Wars near an end, the Sith Lord Darth Sidious steps out of the shadows, at which time Anakin succumbs to his emotions, becoming Darth Vader and putting his relationships with Obi-Wan and Padme at risk.',
#   '$380M'],
#  ['114',
#   'Aliens',
#   '(1986)',
#   '137 mins.',
#   '8.4',
#   '417,956',
#   "[u'Action', u'Adventure', u'Sci-Fi', u'Thriller']",
#   'The planet from ',
#   '$85.2M'],
#  ['115',
#   'The Bourne Ultimatum',
#   '(2007)',
#   '115 mins.',
#   '8.1',
#   '415,343',
#   "[u'Action', u'Thriller']",
#   'Jason Bourne dodges a ruthless CIA official and his agents from a new assassination program while searching for the origins of his life as a trained killer.',
#   '$227M'],
#  ['116',
#   'Catch Me If You Can',
#   '(2002)',
#   '141 mins.',
#   '8.0',
#   '414,316',
#   "[u'Biography', u'Crime', u'Drama']",
#   "A true story about Frank Abagnale Jr., who, before his 19th birthday, successfully conned millions of dollars' worth of checks as a Pan Am pilot, doctor, and legal prosecutor.",
#   '$164M'],
#  ['117',
#   'The Hunger Games: Catching Fire',
#   '(2013)',
#   '146 mins.',
#   '7.7',
#   '411,793',
#   "[u'Adventure', u'Sci-Fi']",
#   'Katniss Everdeen and Peeta Mellark become targets of the Capitol after their victory in the 74th Hunger Games sparks a rebellion in the Districts of Panem.',
#   '$425M'],
#  ['118',
#   'The King&#x27;s Speech',
#   '(2010)',
#   '118 mins.',
#   '8.1',
#   '411,574',
#   "[u'Biography', u'Drama', u'History']",
#   'The story of King George VI of the United Kingdom of Great Britain and Northern Ireland, his impromptu ascension to the throne and the speech therapist who helped the unsure monarch become worthy of it.',
#   '$139M'],
#  ['119',
#   'Sherlock Holmes',
#   '(2009)',
#   '128 mins.',
#   '7.6',
#   '411,466',
#   "[u'Action', u'Adventure', u'Crime', u'Mystery', u'Thriller']",
#   'Detective Sherlock Holmes and his stalwart partner Watson engage in a battle of wits and brawn with a nemesis whose plot is a threat to all of England.',
#   '$209M'],
#  ['120',
#   'The Pianist',
#   '(2002)',
#   '150 mins.',
#   '8.5',
#   '410,566',
#   "[u'Biography', u'Drama', u'War']",
#   'A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.',
#   '$32.5M'],
#  ['121',
#   'Million Dollar Baby',
#   '(2004)',
#   '132 mins.',
#   '8.1',
#   '405,801',
#   "[u'Drama', u'Sport']",
#   'A determined woman works with a hardened boxing trainer to become a professional.',
#   '$100M'],
#  ['122',
#   'Full Metal Jacket',
#   '(1987)',
#   '116 mins.',
#   '8.3',
#   '405,428',
#   "[u'Drama', u'War']",
#   'A pragmatic U.S. Marine observes the dehumanizing effects the U.S.-Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.',
#   '$46.4M'],
#  ['123',
#   'Prometheus',
#   '(2012)',
#   '124 mins.',
#   '7.0',
#   '405,266',
#   "[u'Adventure', u'Mystery', u'Sci-Fi']",
#   'Following clues to the origin of mankind a team journey across the universe and find a structure on a distant planet containing a monolithic statue of a humanoid head and stone cylinders of alien blood but they soon find they are not alone.',
#   '$126M'],
#  ['124',
#   'Pirates of the Caribbean: At World&#x27;s End',
#   '(2007)',
#   '169 mins.',
#   '7.1',
#   '404,824',
#   "[u'Action', u'Adventure', u'Fantasy']",
#   'Captain Barbossa, Will Turner and Elizabeth Swann must sail off the edge of the map, navigate treachery and betrayal, and make their final alliances for one last decisive battle.',
#   '$309M'],
#  ['125',
#   'The Social Network',
#   '(2010)',
#   '120 mins.',
#   '7.8',
#   '404,679',
#   "[u'Biography', u'Drama']",
#   'Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the cofounder who was later squeezed out of the business.',
#   '$96.9M'],
#  ['126',
#   'Trainspotting',
#   '(1996)',
#   '94 mins.',
#   '8.2',
#   '403,596',
#   "[u'Drama']",
#   'Renton, deeply immersed in the Edinburgh drug scene, tries to clean up and get out, despite the allure of the drugs and influence of friends.',
#   '$16.5M'],
#  ['127',
#   'Ted',
#   '(2012)',
#   '106 mins.',
#   '7.0',
#   '402,161',
#   "[u'Comedy', u'Fantasy']",
#   "As the result of a childhood wish, John Bennett's teddy bear, Ted, came to life and has been by John's side ever since - a friendship that's tested when Lori, John's girlfriend of four years, wants more from their relationship.",
#   '$219M'],
#  ['128',
#   'The Hobbit: The Desolation of Smaug',
#   '(2013)',
#   '161 mins.',
#   '8.0',
#   '400,999',
#   "[u'Adventure', u'Fantasy']",
#   'The dwarves, along with Bilbo Baggins and Gandalf the Grey, continue their quest to reclaim Erebor, their homeland, from Smaug. Bilbo Baggins is in possession of a mysterious and magical ring.',
#   '$258M'],
#  ['129',
#   'The Incredibles',
#   '(2004)',
#   '115 mins.',
#   '8.0',
#   '400,938',
#   "[u'Animation', u'Action', u'Adventure', u'Family']",
#   'A family of undercover superheroes, while trying to live the quiet suburban life, are forced into action to save the world.',
#   '$261M'],
#  ['130',
#   'Blade Runner',
#   '(1982)',
#   '117 mins.',
#   '8.2',
#   '400,849',
#   "[u'Sci-Fi', u'Thriller']",
#   'A blade runner must pursue and try to terminate four replicants who stole a ship in space and have returned to Earth to find their creator.',
#   '$1.45M'],
#  ['131',
#   'Twelve Monkeys',
#   '(1995)',
#   '129 mins.',
#   '8.1',
#   '400,029',
#   "[u'Mystery', u'Sci-Fi', u'Thriller']",
#   'In a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet.',
#   '$56.9M'],
#  ['132',
#   'Pan&#x27;s Labyrinth',
#   '(2006)',
#   '118 mins.',
#   '8.3',
#   '399,973',
#   "[u'Drama', u'Fantasy', u'War']",
#   'In the falangist Spain of 1944, the bookish young stepdaughter of a sadistic army officer escapes into an eerie but captivating fantasy world.',
#   '$37.6M'],
#  ['133',
#   'The Curious Case of Benjamin Button',
#   '(2008)',
#   '166 mins.',
#   '7.8',
#   '398,856',
#   "[u'Drama', u'Fantasy', u'Romance']",
#   'Tells the story of Benjamin Button, a man who starts aging backwards with bizarre consequences.',
#   '$127M'],
#  ['134',
#   'Shrek',
#   '(2001)',
#   '90 mins.',
#   '7.9',
#   '398,792',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']",
#   'After his swamp is filled with magical creatures, an ogre agrees to rescue a princess for a villainous lord in order to get his land back.',
#   '$268M'],
#  ['135',
#   'Ratatouille',
#   '(2007)',
#   '111 mins.',
#   '8.0',
#   '397,563',
#   "[u'Animation', u'Comedy', u'Family', u'Fantasy']",
#   'A rat who can cook makes an unusual alliance with a young kitchen worker at a famous restaurant.',
#   '$206M'],
#  ['136',
#   'Casino Royale',
#   '(2006)',
#   '144 mins.',
#   '8.0',
#   '393,973',
#   "[u'Action', u'Adventure', u'Thriller']",
#   'Armed with a licence to kill, Secret Agent James Bond sets out on his first mission as 007 and must defeat a weapons dealer in a high stakes game of poker at Casino Royale, but things are not what they seem.',
#   '$167M'],
#  ['137',
#   'The Intouchables',
#   '(2011)',
#   '112 mins.',
#   '8.6',
#   '391,716',
#   "[u'Biography', u'Comedy', u'Drama']",
#   'After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.',
#   '$13.2M'],
#  ['138',
#   'How to Train Your Dragon',
#   '(2010)',
#   '98 mins.',
#   '8.2',
#   '389,859',
#   "[u'Animation', u'Adventure', u'Family', u'Fantasy']",
#   'A hapless young Viking who aspires to hunt dragons becomes the unlikely friend of a young dragon himself, and learns there may be more to the creatures than he assumed.',
#   '$217M'],
#  ['139',
#   'Captain America: The First Avenger',
#   '(2011)',
#   '124 mins.',
#   '6.8',
#   '389,830',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'Steve Rogers, a rejected military soldier transforms into Captain America after taking a dose of a "Super-Soldier serum". But being Captain America comes at a price as he attempts to take down a war monger and a terrorist organization.',
#   '$177M'],
#  ['140',
#   'Apocalypse Now',
#   '(1979)',
#   '153 mins.',
#   '8.5',
#   '388,193',
#   "[u'Drama', u'War']",
#   'During the Vietnam War, Captain Willard is sent on a dangerous mission into Cambodia to assassinate a renegade colonel who has set himself up as a god among a local tribe.',
#   '$4.62M'],
#  ['141',
#   'Argo',
#   '(2012)',
#   '120 mins.',
#   '7.8',
#   '384,989',
#   "[u'Drama', u'Thriller']",
#   'Acting under the cover of a Hollywood producer scouting a location for a science fiction film, a CIA agent launches a dangerous operation to rescue six Americans in Tehran during the U.S. hostage crisis in Iran in 1980.',
#   '$136M'],
#  ['142',
#   'The Amazing Spider-Man',
#   '(2012)',
#   '136 mins.',
#   '7.1',
#   '384,159',
#   "[u'Action', u'Adventure', u'Fantasy']",
#   "After Peter Parker is bitten by a genetically altered spider, he gains newfound, spider-like powers and ventures out to solve the mystery of his parent's mysterious death.",
#   '$262M'],
#  ['143',
#   'Kick-Ass',
#   '(2010)',
#   '117 mins.',
#   '7.7',
#   '383,397',
#   "[u'Action', u'Comedy']",
#   'Dave Lizewski is an unnoticed high school student and comic book fan who one day decides to become a super-hero, even though he has no powers, training or meaningful reason to do so.',
#   '$48M'],
#  ['144',
#   'Drive',
#   '(2011)',
#   '100 mins.',
#   '7.8',
#   '383,105',
#   "[u'Crime', u'Drama']",
#   'A mysterious Hollywood stuntman, mechanic and getaway driver lands himself in trouble when he helps out his neighbor.',
#   '$35.1M'],
#  ['145',
#   'World War Z',
#   '(2013)',
#   '116 mins.',
#   '7.0',
#   '382,795',
#   "[u'Action', u'Adventure', u'Horror', u'Sci-Fi', u'Thriller']",
#   'United Nations employee Gerry Lane traverses the world in a race against time to stop the Zombie pandemic that is toppling armies and governments, and threatening to destroy humanity itself.',
#   '$202M'],
#  ['146',
#   'X-Men: Days of Future Past',
#   '(2014)',
#   '131 mins.',
#   '8.1',
#   '382,800',
#   "[u'Action', u'Adventure', u'Sci-Fi', u'Thriller']",
#   'The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.',
#   '$234M'],
#  ['147',
#   'The Matrix Reloaded',
#   '(2003)',
#   '138 mins.',
#   '7.2',
#   '381,076',
#   "[u'Action', u'Sci-Fi']",
#   'Neo and the rebel leaders estimate that they have 72 hours until 250,000 probes discover Zion and destroy it and its inhabitants. During this, Neo must decide how he can save Trinity from a dark fate in his dreams.',
#   '$281M'],
#  ['148',
#   'X-Men',
#   '(2000)',
#   '104 mins.',
#   '7.4',
#   '380,133',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'Two mutants come to a private academy for their kind whose resident superhero team must oppose a terrorist organization with similar powers.',
#   '$157M'],
#  ['149',
#   'Harry Potter and the Sorcerer&#x27;s Stone',
#   '(2001)',
#   '152 mins.',
#   '7.5',
#   '379,806',
#   "[u'Adventure', u'Family', u'Fantasy']",
#   'Rescued from the outrageous neglect of his aunt and uncle, a young boy with a great destiny proves his worth while attending Hogwarts School of Witchcraft and Wizardry.',
#   '$318M'],
#  ['150',
#   'Fargo',
#   '(1996)',
#   '98 mins.',
#   '8.2',
#   '378,179',
#   "[u'Crime', u'Drama', u'Thriller']",
#   "Jerry Lundegaard's inept crime falls apart due to his and his henchmen's bungling and the persistent police work of the quite pregnant Marge Gunderson.",
#   '$24.5M'],
#  ['151',
#   'Superbad',
#   '(2007)',
#   '113 mins.',
#   '7.6',
#   '377,991',
#   "[u'Comedy']",
#   'Two co-dependent high school seniors are forced to deal with separation anxiety after their plan to stage a booze-soaked party goes awry.',
#   '$121M'],
#  ['152',
#   'How I Met Your Mother',
#   '(2005 TV Series)',
#   '22 mins.',
#   '8.5',
#   '377,971',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'A father recounts to his children, through a series of flashbacks, the journey he and his four best friends took leading up to him meeting their mother.',
#   '-'],
#  ['153',
#   'Gone Girl',
#   '(2014)',
#   '149 mins.',
#   '8.2',
#   '376,783',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   "With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#   '$168M'],
#  ['154',
#   'Independence Day',
#   '(1996)',
#   '145 mins.',
#   '6.9',
#   '374,992',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   "The aliens are coming and their goal is to invade and destroy. Fighting superior technology, Man's best weapon is the will to survive.",
#   '$306M'],
#  ['155',
#   'Heat',
#   '(1995)',
#   '170 mins.',
#   '8.3',
#   '374,545',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'A group of professional bank robbers start to feel the heat from police when they unknowingly leave a clue at their latest heist.',
#   '$67.4M'],
#  ['156',
#   'Looper',
#   '(2012)',
#   '119 mins.',
#   '7.5',
#   '370,793',
#   "[u'Action', u'Crime', u'Sci-Fi', u'Thriller']",
#   "In 2074, when the mob wants to get rid of someone, the target is sent into the past, where a hired gun awaits - someone like Joe - who one day learns the mob wants to 'close the loop' by sending back Joe's future self for assassination.",
#   '$66.5M'],
#  ['157',
#   'Star Wars: Episode II - Attack of the Clones',
#   '(2002)',
#   '142 mins.',
#   '6.8',
#   '369,364',
#   "[u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'Ten years after initially meeting, Anakin Skywalker shares a forbidden romance with Padmé, while Obi-Wan investigates an assassination attempt on the Senator and discovers a secret clone army crafted for the Jedi.',
#   '$311M'],
#  ['158',
#   'Juno',
#   '(2007)',
#   '96 mins.',
#   '7.6',
#   '367,686',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'Faced with an unplanned pregnancy, an offbeat young woman makes an unusual decision regarding her unborn child.',
#   '$143M'],
#  ['159',
#   'Groundhog Day',
#   '(1993)',
#   '101 mins.',
#   '8.1',
#   '367,627',
#   "[u'Comedy', u'Fantasy', u'Romance']",
#   'A weatherman finds himself living the same day over and over again.',
#   '$70.9M'],
#  ['160',
#   'Life of Pi',
#   '(2012)',
#   '127 mins.',
#   '8.0',
#   '366,534',
#   "[u'Adventure', u'Drama']",
#   'A young man who survives a disaster at sea is hurtled into an epic journey of adventure and discovery. While cast away, he forms an unexpected connection with another survivor: a fearsome Bengal tiger.',
#   '$125M'],
#  ['161',
#   'Now You See Me',
#   '(2013)',
#   '115 mins.',
#   '7.3',
#   '366,035',
#   "[u'Crime', u'Mystery', u'Thriller']",
#   'An FBI agent and an Interpol detective track a team of illusionists who pull off bank heists during their performances and reward their audiences with the money.',
#   '$118M'],
#  ['162',
#   'Friends',
#   '(1994 TV Series)',
#   '22 mins.',
#   '9.0',
#   '365,611',
#   "[u'Comedy', u'Romance']",
#   'Follows the lives of six 20-something friends living in Manhattan.',
#   '-'],
#  ['163',
#   'Sherlock',
#   '(2010 TV Series)',
#   '90 mins.',
# ...
#   'Chicken Run is a comedy escape drama with a touch of passion set on a sinister Yorkshire chicken farm in 1950s England.',
#   '$107M'],
#  ['943',
#   'Close Encounters of the Third Kind',
#   '(1977)',
#   '137 mins.',
#   '7.7',
#   '123,177',
#   "[u'Drama', u'Sci-Fi']",
#   'After an encounter with U.F.O.s, a line worker feels undeniably drawn to an isolated area in the wilderness where something spectacular is about to happen.',
#   '$128M'],
#  ['944',
#   'The Perfect Storm',
#   '(2000)',
#   '130 mins.',
#   '6.4',
#   '123,006',
#   "[u'Action', u'Adventure', u'Drama', u'Thriller']",
#   'An unusually intense storm pattern catches some commercial fishermen unaware and puts them in mortal danger.',
#   '$183M'],
#  ['945',
#   'Hitman',
#   '(2007)',
#   '100 mins.',
#   '6.3',
#   '122,980',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   "A gun-for-hire known only as Agent 47 hired by a group known only as 'The Organization' is ensnared in a political conspiracy, which finds him pursued by both Interpol and the Russian military as he treks across Russia and Eastern Europe.",
#   '$39.7M'],
#  ['946',
#   'The Life Aquatic with Steve Zissou',
#   '(2004)',
#   '119 mins.',
#   '7.3',
#   '122,904',
#   "[u'Adventure', u'Comedy', u'Drama']",
#   'With a plan to exact revenge on a mythical shark that killed his partner, oceanographer Steve Zissou rallies a crew that includes his estranged wife, a journalist, and a man who may or may not be his son.',
#   '$24M'],
#  ['947',
#   'Michael Clayton',
#   '(2007)',
#   '119 mins.',
#   '7.3',
#   '122,878',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A law firm brings in its "fixer" to remedy the situation after a lawyer has a breakdown while representing a chemical company that he knows is guilty in a multi-billion dollar class action suit.',
#   '$49M'],
#  ['948',
#   'Milk',
#   '(2008)',
#   '128 mins.',
#   '7.6',
#   '122,817',
#   "[u'Biography', u'Drama', u'History']",
#   "The story of Harvey Milk, and his struggles as an American gay activist who fought for gay rights and became California's first openly gay elected official.",
#   '$31.8M'],
#  ['949',
#   'Letters from Iwo Jima',
#   '(2006)',
#   '141 mins.',
#   '8.0',
#   '122,734',
#   "[u'Drama', u'History', u'War']",
#   'The story of the battle of Iwo Jima between the United States and Imperial Japan during World War II, as told from the perspective of the Japanese who fought it.',
#   '$13.8M'],
#  ['950',
#   'How the Grinch Stole Christmas',
#   '(2000)',
#   '104 mins.',
#   '6.0',
#   '122,638',
#   "[u'Comedy', u'Family', u'Fantasy']",
#   'A creature is intent on stealing Christmas.',
#   '$260M'],
#  ['951',
#   'The Talented Mr. Ripley',
#   '(1999)',
#   '139 mins.',
#   '7.3',
#   '122,538',
#   "[u'Drama', u'Music', u'Thriller']",
#   'In late 1950s New York, Tom Ripley, a young underachiever, is sent to Italy to retrieve a rich and spoiled millionaire playboy, named Dickie Greenleaf. But when the errand fails, Ripley takes extreme measures.',
#   '$81.3M'],
#  ['952',
#   'The Ghost Writer',
#   '(2010)',
#   '128 mins.',
#   '7.2',
#   '122,451',
#   "[u'Mystery', u'Thriller']",
#   'A ghostwriter hired to complete the memoirs of a former British prime minister uncovers secrets that put his own life in jeopardy.',
#   '$15.5M'],
#  ['953',
#   'Shoot &#x27;Em Up',
#   '(2007)',
#   '86 mins.',
#   '6.7',
#   '122,270',
#   "[u'Action', u'Comedy', u'Crime', u'Thriller']",
#   "A man named Mr. Smith delivers a woman's baby during a shootout, and is then called upon to protect the newborn from the army of gunmen.",
#   '$12.8M'],
#  ['954',
#   'King Arthur',
#   '(2004)',
#   '126 mins.',
#   '6.3',
#   '122,262',
#   "[u'Action', u'Adventure', u'Drama', u'History', u'War']",
#   'A demystified take on the tale of King Arthur and the Knights of the Round Table.',
#   '$51.9M'],
#  ['955',
#   'Doctor Who',
#   '(2005 TV Series)',
#   '45 mins.',
#   '8.9',
#   '122,209',
#   "[u'Adventure', u'Drama', u'Family', u'Mystery', u'Sci-Fi']",
#   'The further adventures of the time traveling alien adventurer and his companions.',
#   '-'],
#  ['956',
#   'The Insider',
#   '(1999)',
#   '157 mins.',
#   '7.9',
#   '122,161',
#   "[u'Biography', u'Drama', u'Thriller']",
#   'A research chemist comes under personal and professional attack when he decides to appear in a "60 Minutes" expose on Big Tobacco.',
#   '$29M'],
#  ['957',
#   'Community',
#   '(2009 TV Series)',
#   '22 mins.',
#   '8.6',
#   '122,141',
#   "[u'Comedy']",
#   'A suspended lawyer is forced to enroll in a community college with an eclectic staff and student body.',
#   '-'],
#  ['958',
#   'The Tree of Life',
#   '(2011)',
#   '139 mins.',
#   '6.7',
#   '122,036',
#   "[u'Drama', u'Fantasy']",
#   "The story of a family in Waco, Texas in 1956. The eldest son witnesses the loss of innocence and struggles with his parents' conflicting teachings.",
#   '$13.3M'],
#  ['959',
#   'Dirty Dancing',
#   '(1987)',
#   '100 mins.',
#   '6.8',
#   '121,979',
#   "[u'Drama', u'Music', u'Romance']",
#   'Spending the summer in a holiday camp with her family, Frances "Baby" Houseman falls in love with the camp\'s dance instructor Johnny Castle.',
#   '$63.9M'],
#  ['960',
#   'The Evil Dead',
#   '(1981)',
#   '85 mins.',
#   '7.6',
#   '121,943',
#   "[u'Horror']",
#   'Five friends travel to a cabin in the woods, where they unknowingly release flesh-possessing demons.',
#   '-'],
#  ['961',
#   'Who Framed Roger Rabbit',
#   '(1988)',
#   '104 mins.',
#   '7.7',
#   '121,033',
#   "[u'Animation', u'Comedy', u'Crime', u'Family', u'Fantasy']",
#   "A toon hating detective is a cartoon rabbit's only hope to prove his innocence when he is accused of murder.",
#   '$154M'],
#  ['962',
#   'Erin Brockovich',
#   '(2000)',
#   '131 mins.',
#   '7.3',
#   '120,993',
#   "[u'Biography', u'Drama']",
#   "An unemployed single mother becomes a legal assistant and almost single-handedly brings down a California power company accused of polluting a city's water supply.",
#   '$126M'],
#  ['963',
#   'Hard Candy',
#   '(2005)',
#   '104 mins.',
#   '7.2',
#   '120,958',
#   "[u'Crime', u'Drama', u'Thriller']",
#   "A teenage girl raids a man's home, suspecting he is a pedophile, in order to expose him.",
#   '$1.01M'],
#  ['964',
#   'Rushmore',
#   '(1998)',
#   '93 mins.',
#   '7.7',
#   '120,800',
#   "[u'Comedy', u'Drama']",
#   'The extracurricular king of Rushmore preparatory school is put on academic probation.',
#   '$17.1M'],
#  ['965',
#   'The Darjeeling Limited',
#   '(2007)',
#   '91 mins.',
#   '7.2',
#   '120,753',
#   "[u'Adventure', u'Comedy', u'Drama']",
#   "A year after their father's funeral, three brothers travel across India by train in an attempt to bond with each other.",
#   '$11.9M'],
#  ['966',
#   'Road Trip',
#   '(2000)',
#   '93 mins.',
#   '6.5',
#   '120,579',
#   "[u'Adventure', u'Comedy']",
#   'Four friends take off on an 1800 mile road trip to retrieve an illicit tape mistakenly mailed to a girl friend.',
#   '$68.5M'],
#  ['967',
#   'Spaceballs',
#   '(1987)',
#   '96 mins.',
#   '7.1',
#   '120,288',
#   "[u'Adventure', u'Comedy', u'Sci-Fi']",
#   "Planet Spaceball's President Skroob sends Lord Dark Helmet to steal Planet Druidia's abundant supply of air to replenish their own, and only Lone Starr can stop them.",
#   '$38.1M'],
#  ['968',
#   'Ice Age: Continental Drift',
#   '(2012)',
#   '88 mins.',
#   '6.7',
#   '120,176',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family']",
#   'Manny, Diego, and Sid embark upon another adventure after their continent is set adrift. Using an iceberg as a ship, they encounter sea creatures and battle pirates as they explore a new world.',
#   '$161M'],
#  ['969',
#   'The Mask of Zorro',
#   '(1998)',
#   '136 mins.',
#   '6.7',
#   '120,125',
#   "[u'Action', u'Adventure', u'Comedy', u'Romance', u'Thriller', u'Western']",
#   'A young thief, seeking revenge over the death of his brother, is trained by the once great, but aged Zorro, who is also seeking a vengeance of his own.',
#   '$93.8M'],
#  ['970',
#   'Gremlins',
#   '(1984)',
#   '106 mins.',
#   '7.2',
#   '119,923',
#   "[u'Comedy', u'Horror']",
#   'A boy inadvertantly breaks 3 important rules concerning his new pet and unleashes a horde of malevolently mischievous monsters on a small town.',
#   '$148M'],
#  ['971',
#   'Futurama',
#   '(1999 TV Series)',
#   '22 mins.',
#   '8.7',
#   '119,726',
#   "[u'Animation', u'Comedy', u'Sci-Fi']",
#   "Fry, a pizza guy is accidentally frozen in 1999 and thawed out New Year's Eve 2999.",
#   '-'],
#  ['972',
#   'Layer Cake',
#   '(2004)',
#   '105 mins.',
#   '7.4',
#   '119,691',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A successful cocaine dealer gets two tough assignments from his boss on the eve of his planned early retirement.',
#   '$2.34M'],
#  ['973',
#   'The Vow',
#   '(2012)',
#   '104 mins.',
#   '6.8',
#   '119,383',
#   "[u'Drama', u'Romance']",
#   'A car accident puts Paige in a coma, and when she wakes up with severe memory loss, her husband Leo works to win her heart again.',
#   '$125M'],
#  ['974',
#   'Jay and Silent Bob Strike Back',
#   '(2001)',
#   '104 mins.',
#   '6.9',
#   '119,086',
#   "[u'Comedy']",
#   "The comic 'Bluntman and Chronic' is based on real-life stoners Jay and Silent Bob, so when they get no profit from a big-screen adaptation they set out to wreck the movie.",
#   '$30.1M'],
#  ['975',
#   'Madagascar: Escape 2 Africa',
#   '(2008)',
#   '89 mins.',
#   '6.7',
#   '119,077',
#   "[u'Animation', u'Action', u'Adventure', u'Comedy', u'Family']",
#   'The animals try to fly back to New York City, but crash-land on an African wildlife refuge, where Alex is reunited with his parents.',
#   '$180M'],
#  ['976',
#   'Wild Wild West',
#   '(1999)',
#   '106 mins.',
#   '4.8',
#   '119,040',
#   "[u'Action', u'Western', u'Comedy', u'Sci-Fi']",
#   'The two best hired guns in the West must save President Grant from the clutches of a 19th century inventor-villain.',
#   '$114M'],
#  ['977',
#   'Sunset Blvd.',
#   '(1950)',
#   '110 mins.',
#   '8.5',
#   '119,006',
#   "[u'Drama', u'Film-Noir']",
#   'A hack screenwriter writes a screenplay for a former silent-film star who has faded into Hollywood obscurity.',
#   '-'],
#  ['978',
#   'Vantage Point',
#   '(2008)',
#   '90 mins.',
#   '6.6',
#   '118,965',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'The attempted assassination of the American President is told and re-told from several different perspectives.',
#   '$72.3M'],
#  ['979',
#   'Misery',
#   '(1990)',
#   '107 mins.',
#   '7.8',
#   '118,905',
#   "[u'Thriller']",
#   'Paul Sheldon, a successful novelist, is rescued after a snow storm by his "Number One Fan" and must rewrite his latest novel to her liking in order to stay alive.',
#   '$61.3M'],
#  ['980',
#   'Basic Instinct',
#   '(1992)',
#   '127 mins.',
#   '6.9',
#   '118,794',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'A police detective is in charge of the investigation of a brutal murder, in which a beautiful and seductive woman could be involved.',
#   '$118M'],
#  ['981',
#   'He&#x27;s Just Not That Into You',
#   '(2009)',
#   '129 mins.',
#   '6.4',
#   '118,725',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'The Baltimore-set movie of interconnecting story arcs deals with the challenges of reading or misreading human behavior.',
#   '$94M'],
#  ['982',
#   'Vikings',
#   '(2013 TV Series)',
#   '44 mins.',
#   '8.6',
#   '118,757',
#   "[u'Action', u'Drama', u'History', u'War']",
#   "The adventures of Ragnar Lothbrok: the greatest hero of his age. The series tells the saga of Ragnar's...",
#   '-'],
#  ['983',
#   'Shrek Forever After',
#   '(2010)',
#   '93 mins.',
#   '6.4',
#   '118,468',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']",
#   'Rumpelstiltskin tricks a mid-life crisis burdened Shrek into allowing himself to be erased from existence and cast in a dark alternate timeline where Rumpel rules supreme.',
#   '$238M'],
#  ['984',
#   'Resident Evil: Afterlife',
#   '(2010)',
#   '97 mins.',
#   '5.9',
#   '118,427',
#   "[u'Action', u'Adventure', u'Horror', u'Sci-Fi']",
#   'While still out to destroy the evil Umbrella Corporation, Alice joins a group of survivors living in a prison surrounded by the infected who also want to relocate to the mysterious but supposedly unharmed safe haven known only as Arcadia.',
#   '$60.1M'],
#  ['985',
#   'Fantastic Mr. Fox',
#   '(2009)',
#   '87 mins.',
#   '7.8',
#   '118,366',
#   "[u'Animation', u'Adventure', u'Comedy', u'Crime', u'Family']",
#   "An urbane fox cannot resist returning to his farm raiding ways and then must help his community survive the farmers' retaliation.",
#   '$21M'],
#  ['986',
#   'Miss Congeniality',
#   '(2000)',
#   '109 mins.',
#   '6.1',
#   '118,181',
#   "[u'Action', u'Comedy', u'Crime']",
#   'An FBI agent must go undercover in the Miss United States beauty pageant to prevent a group from bombing the event.',
#   '$107M'],
#  ['987',
#   'Once Upon a Time in Mexico',
#   '(2003)',
#   '102 mins.',
#   '6.4',
#   '118,103',
#   "[u'Action', u'Thriller']",
#   'Hitman "El Mariachi" becomes involved in international espionage involving a psychotic CIA agent and a corrupt Mexican general.',
#   '$55.8M'],
#  ['988',
#   'The Abyss',
#   '(1989)',
#   '139 mins.',
#   '7.6',
#   '118,047',
#   "[u'Adventure', u'Drama', u'Sci-Fi', u'Thriller']",
#   'A civilian diving team are enlisted to search for a lost nuclear submarine and face danger while encountering an alien aquatic species.',
#   '$54.2M'],
#  ['989',
#   'Adventureland',
#   '(2009)',
#   '107 mins.',
#   '6.8',
#   '118,036',
#   "[u'Comedy', u'Drama', u'Romance']",
#   "In the summer of 1987, a college graduate takes a 'nowhere' job at his local amusement park, only to find it's the perfect course to get him prepared for the real world.",
#   '$16M'],
#  ['990',
#   'Sinister',
#   '(2012)',
#   '110 mins.',
#   '6.8',
#   '118,023',
#   "[u'Horror', u'Mystery']",
#   'A true-crime writer finds a cache of 8mm home movies films that suggest the murder he is currently researching is the work of a serial killer whose career dates back to the 1960s.',
#   '$48.1M'],
#  ['991',
#   'Definitely, Maybe',
#   '(2008)',
#   '112 mins.',
#   '7.2',
#   '117,860',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'A political consultant tries to explain his impending divorce and past relationships to his 11-year-old daughter.',
#   '$32M'],
#  ['992',
#   'Ghostbusters II',
#   '(1989)',
#   '108 mins.',
#   '6.5',
#   '117,866',
#   "[u'Comedy', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']",
#   'The discovery of a massive river of ectoplasm and a resurgence of spectral activity allows the staff of Ghostbusters to revive the business.',
#   '$112M'],
#  ['993',
#   'Orphan',
#   '(2009)',
#   '123 mins.',
#   '7.0',
#   '117,544',
#   "[u'Mystery', u'Thriller']",
#   'A husband and wife who recently lost their baby adopt a 9-year-old girl who is not nearly as innocent as she claims to be.',
#   '$41.6M'],
#  ['994',
#   'Abraham Lincoln: Vampire Hunter',
#   '(2012)',
#   '105 mins.',
#   '6.0',
#   '117,328',
#   "[u'Action', u'Fantasy', u'Horror', u'Thriller']",
#   'Abraham Lincoln, the 16th President of the United States, discovers vampires are planning to take over the United States. He makes it his mission to eliminate them.',
#   '$37.5M'],
#  ['995',
#   'Mad Men',
#   '(2007 TV Series)',
#   '45 mins.',
#   '8.7',
#   '117,210',
#   "[u'Drama']",
#   "A drama about one of New York's most prestigious ad agencies at the beginning of the 1960s, focusing on one of the firm's most mysterious but extremely talented ad executives, Donald Draper.",
#   '-'],
#  ['996',
#   'A Fistful of Dollars',
#   '(1964)',
#   '99 mins.',
#   '8.1',
#   '117,010',
#   "[u'Action', u'Western']",
#   'A wandering gunfighter plays two rival families against each other in a town torn apart by greed, pride, and revenge.',
#   '$3.5M'],
#  ['997',
#   'Shark Tale',
#   '(2004)',
#   '90 mins.',
#   '6.0',
#   '116,895',
#   "[u'Animation', u'Adventure', u'Comedy', u'Family']",
#   'When a son of a gangster shark boss is accidently killed while on the hunt, his would-be prey and his vegetarian brother both decide to use the incident to their own advantage.',
#   '$161M'],
#  ['998',
#   'The Imaginarium of Doctor Parnassus',
#   '(2009)',
#   '123 mins.',
#   '6.9',
#   '116,755',
#   "[u'Adventure', u'Fantasy', u'Mystery']",
#   'A traveling theater company gives its audience much more than they were expecting.',
#   '$7.69M'],
#  ['999',
#   'Lethal Weapon 4',
#   '(1998)',
#   '127 mins.',
#   '6.6',
#   '116,247',
#   "[u'Action', u'Crime', u'Thriller']",
#   'With personal crises and age weighing in on them, LAPD officers Riggs and Murtaugh must contend with a deadly Chinese crimelord trying to get his brother out of prison.',
#   '$130M'],
#  ...]

# %%
#get the first sublist
myList[0]
# Out:
# ['0',
#  'The Shawshank Redemption',
#  '(1994)',
#  '142 mins.',
#  '9.3',
#  '1,432,740',
#  "[u'Crime', u'Drama']",
#  'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#  '$28.3M']

# %%
# how many items
len(myList)
# Out:
# 6518

# %%
#get the actual text we want
myList[0] # gets first think
# we want 7th thing
myList[0][7]
# Out:
# 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'

# %%
#print out every genre that is mentioned in the csv file
for movie in myList:
    print(movie[6]) # print item at position of genre
# Out:
# [u'Crime', u'Drama']
# [u'Action', u'Crime', u'Drama']
# [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Crime', u'Drama']
# [u'Adventure', u'Fantasy']
# [u'Adventure', u'Fantasy']
# [u'Action', u'Sci-Fi']
# [u'Drama', u'Romance']
# [u'Crime', u'Drama']
# [u'Action', u'Thriller']
# [u'Adventure', u'Fantasy']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Drama']
# [u'Action', u'Adventure']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Western']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Drama', u'War']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'Thriller']
# [u'Biography', u'Drama', u'History']
# [u'Mystery', u'Thriller']
# [u'Adventure', u'Drama', u'War']
# [u'Drama']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Adventure', u'Fantasy']
# [u'Drama', u'Romance']
# [u'Action', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Fantasy', u'Mystery']
# [u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Biography', u'Drama', u'History', u'War']
# [u'Action', u'Sci-Fi']
# [u'Biography', u'Crime', u'Drama']
# [u'Action']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Sci-Fi']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Sci-Fi']
# [u'Drama']
# [u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Adventure', u'Sci-Fi']
# [u'Biography', u'Comedy', u'Crime', u'Drama']
# [u'Drama', u'Romance', u'Sci-Fi']
# [u'Drama', u'Romance']
# [u'Action', u'Adventure']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Drama']
# [u'Adventure', u'Fantasy']
# [u'Crime', u'Drama']
# [u'Action', u'Fantasy', u'War']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Animation', u'Adventure', u'Drama', u'Family', u'Musical']
# [u'Comedy', u'Crime']
# [u'Comedy']
# [u'Action', u'Thriller']
# [u'Horror']
# [u'Drama']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Drama', u'Mystery', u'Sci-Fi']
# [u'Drama', u'Horror']
# [u'Action', u'Sci-Fi']
# [u'Biography', u'Drama']
# [u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Sci-Fi']
# [u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Crime', u'Drama', u'Sci-Fi']
# [u'Action', u'Adventure']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Romance']
# [u'Crime', u'Drama']
# [u'Comedy', u'Crime']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Thriller']
# [u'Adventure', u'Fantasy', u'Mystery']
# [u'Comedy']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Action', u'Adventure']
# [u'Action', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Western']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Thriller']
# [u'Biography', u'Crime', u'Drama']
# [u'Adventure', u'Sci-Fi']
# [u'Biography', u'Drama', u'History']
# [u'Action', u'Adventure', u'Crime', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'War']
# [u'Drama', u'Sport']
# [u'Drama', u'War']
# [u'Adventure', u'Mystery', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Biography', u'Drama']
# [u'Drama']
# [u'Comedy', u'Fantasy']
# [u'Adventure', u'Fantasy']
# [u'Animation', u'Action', u'Adventure', u'Family']
# [u'Sci-Fi', u'Thriller']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Fantasy', u'War']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Animation', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Thriller']
# [u'Biography', u'Comedy', u'Drama']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Drama', u'War']
# [u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Action', u'Comedy']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Fantasy', u'Romance']
# [u'Adventure', u'Drama']
# [u'Crime', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Crime', u'Drama', u'Mystery']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Comedy', u'Crime']
# [u'Adventure', u'Biography', u'Drama']
# [u'Mystery', u'Sci-Fi']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Action', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Crime', u'Thriller']
# [u'Comedy', u'Horror']
# [u'Adventure', u'Drama', u'Thriller']
# [u'Drama', u'Thriller']
# [u'Comedy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Comedy', u'Crime']
# [u'Drama', u'Romance']
# [u'Action', u'Mystery', u'Sci-Fi']
# [u'Drama', u'Romance', u'War']
# [u'Action', u'Adventure']
# [u'Comedy', u'Drama', u'Romance']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Adventure', u'Drama']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy', u'Musical']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama']
# [u'Comedy', u'Horror']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Biography', u'Drama', u'History']
# [u'Adventure', u'Comedy', u'Fantasy']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Adventure']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Adventure', u'Comedy', u'Drama']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Mystery', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Adventure']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Drama']
# [u'Adventure', u'Drama', u'Fantasy', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Adventure', u'Comedy', u'Drama']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Adventure', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Sci-Fi', u'Thriller']
# [u'Animation', u'Comedy', u'Family']
# [u'Comedy', u'Crime']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Thriller']
# [u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Drama', u'Sport']
# [u'Comedy', u'War']
# [u'Biography', u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Thriller']
# [u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance']
# [u'Biography', u'Drama']
# [u'Action', u'Comedy', u'Crime', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Adventure']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Action', u'Fantasy']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Crime', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Drama', u'Thriller', u'War']
# [u'Action', u'Adventure', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Romance', u'Sci-Fi']
# [u'Biography', u'Crime', u'Drama']
# [u'Action', u'Drama', u'History', u'War']
# [u'Biography', u'Drama', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance', u'Sci-Fi']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Mystery', u'Thriller']
# [u'Action', u'Adventure']
# [u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Crime', u'Drama', u'History']
# [u'Comedy', u'Crime', u'Drama']
# [u'Action', u'Comedy']
# [u'Drama', u'Sport']
# [u'Drama']
# [u'Action', u'Crime', u'Fantasy', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Fantasy']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Horror']
# [u'Comedy', u'Romance']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Comedy', u'Drama']
# [u'Biography', u'Drama']
# [u'Drama', u'History', u'Thriller', u'War']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Mystery']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Sci-Fi']
# [u'Drama', u'Mystery', u'Romance', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama', u'Fantasy']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Comedy', u'Family']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Biography', u'Drama', u'Sport']
# [u'Animation', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Horror']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Comedy', u'Family', u'Fantasy', u'Romance']
# [u'Action', u'Crime', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Sci-Fi']
# [u'Comedy', u'Romance']
# [u'Drama', u'Mystery']
# [u'Drama', u'War']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Drama', u'Horror', u'Musical', u'Thriller']
# [u'Comedy']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Sci-Fi']
# [u'Family', u'Sci-Fi']
# [u'Adventure', u'Family', u'Fantasy', u'Musical']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Drama', u'Romance']
# [u'Crime', u'Thriller']
# [u'Drama', u'Thriller']
# [u'Adventure', u'Biography', u'Drama', u'Thriller']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Adventure', u'Fantasy']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Biography', u'Drama', u'Sport']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Western']
# [u'Action', u'Biography', u'Drama', u'Sport']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Biography', u'Drama', u'Thriller', u'War']
# [u'Action', u'Drama', u'Thriller']
# [u'Drama', u'Horror', u'Mystery']
# [u'Action', u'Adventure', u'Thriller']
# [u'Action', u'Adventure']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Horror']
# [u'Action', u'Thriller']
# [u'Animation', u'Comedy', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Action', u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Romance']
# [u'Drama', u'Sport']
# [u'Drama', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Family', u'Fantasy']
# [u'Comedy']
# [u'Adventure', u'Drama']
# [u'Drama', u'Fantasy', u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Animation', u'Adventure', u'Comedy']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'Music']
# [u'Comedy', u'Fantasy']
# [u'Comedy', u'Romance']
# [u'Animation', u'Comedy', u'Family']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Comedy', u'Sci-Fi']
# [u'Biography', u'Drama']
# [u'Comedy', u'Crime', u'Fantasy', u'Romance']
# [u'Comedy', u'Fantasy']
# [u'Action', u'Adventure', u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'History', u'War']
# [u'Action', u'Comedy', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Drama', u'Sci-Fi', u'Sport']
# [u'Comedy', u'Romance']
# [u'Action', u'Drama', u'Romance', u'War']
# [u'Crime', u'Thriller']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Adventure', u'Comedy', u'Sci-Fi', u'Western']
# [u'Crime', u'Drama', u'Mystery']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Drama']
# [u'Comedy', u'Crime', u'Drama']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Drama', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Drama']
# [u'Action', u'Comedy', u'Crime']
# [u'Action', u'Crime', u'Mystery', u'Thriller']
# [u'Drama', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Horror', u'Sci-Fi']
# [u'Adventure', u'Drama', u'Family', u'Mystery']
# [u'Action', u'Fantasy', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Action', u'Adventure', u'Thriller']
# [u'Horror', u'Romance']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Biography', u'Drama', u'History', u'War']
# [u'Adventure', u'Crime', u'Drama', u'Western']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Musical', u'Romance']
# [u'Action', u'Adventure', u'Crime', u'Drama', u'Mystery', u'Sci-Fi']
# [u'Adventure', u'Drama', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Adventure', u'Drama', u'Western']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Sport']
# [u'Animation', u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Mystery', u'Romance', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama']
# [u'Drama', u'Fantasy', u'Horror']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Biography', u'Crime', u'Drama', u'History']
# [u'Drama', u'Musical', u'Romance']
# [u'Adventure', u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy']
# [u'Biography', u'Crime', u'Drama']
# [u'Drama']
# [u'Animation', u'Comedy']
# [u'Biography', u'Drama', u'Sport']
# [u'Drama', u'War']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Mystery', u'Romance', u'Thriller']
# [u'Action', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Drama', u'Romance']
# [u'Action', u'Drama', u'War']
# [u'Action', u'Drama', u'Fantasy']
# [u'Action', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Thriller']
# [u'Action', u'Adventure', u'Family', u'Fantasy', u'Romance']
# [u'Action', u'Adventure', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Adventure', u'Comedy', u'Crime', u'Music']
# [u'Adventure', u'Comedy', u'Drama', u'Fantasy']
# [u'Drama']
# [u'Action', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Animation', u'Family', u'Fantasy', u'Musical']
# [u'Comedy', u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Music']
# [u'Action', u'Comedy']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Romance']
# [u'Comedy']
# [u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Crime', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Animation', u'Comedy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy', u'Romance']
# [u'Action', u'Drama', u'Romance']
# [u'Drama', u'History', u'Thriller']
# [u'Action', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Comedy']
# [u'Action', u'Adventure', u'Drama', u'History', u'War']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Comedy', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'History']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Comedy']
# [u'Drama', u'Fantasy', u'Mystery', u'Romance', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Horror', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Biography', u'Drama', u'Sport']
# [u'Horror', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Comedy', u'Drama']
# [u'Fantasy', u'Mystery', u'Romance', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Action']
# [u'Comedy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Comedy', u'Crime']
# [u'Crime', u'Drama']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Fantasy', u'Horror', u'Mystery', u'Romance', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Action', u'Fantasy', u'Thriller']
# [u'Adventure', u'Sci-Fi']
# [u'Drama', u'Romance', u'War']
# [u'Comedy', u'Drama']
# [u'Action', u'Crime', u'Thriller']
# [u'Adventure', u'Drama', u'History', u'Sci-Fi']
# [u'Comedy']
# [u'Drama', u'Music', u'Romance']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Drama', u'History', u'War']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Western']
# [u'Drama', u'Thriller']
# [u'Action', u'Drama', u'Fantasy', u'War']
# [u'Action', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Adventure', u'Drama', u'Thriller']
# [u'Comedy', u'Music']
# [u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Animation', u'Adventure', u'Fantasy']
# [u'Drama', u'History', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Drama']
# [u'Drama', u'Romance']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Mystery', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Drama']
# [u'Comedy']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Romance', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Comedy']
# [u'Comedy', u'Romance']
# [u'Action', u'Horror', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Horror', u'Sci-Fi']
# [u'Action', u'Adventure', u'Thriller']
# [u'Biography', u'Crime', u'Drama']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Biography', u'Crime', u'Drama', u'Thriller']
# [u'Biography', u'Drama', u'History', u'War']
# [u'Action', u'Crime', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Horror']
# [u'Drama']
# [u'Action', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Drama', u'Romance']
# [u'Drama']
# [u'Drama', u'Romance', u'Sci-Fi']
# [u'Crime', u'Thriller']
# [u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy']
# [u'Biography', u'Drama', u'Music', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'Mystery', u'Romance', u'War']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Adventure', u'Family', u'Fantasy', u'Thriller']
# [u'Crime', u'Drama', u'Fantasy']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Comedy', u'Romance', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Action', u'Thriller']
# [u'Action']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Mystery', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Drama']
# [u'Action', u'Biography', u'Thriller', u'War']
# [u'Adventure', u'Comedy', u'Fantasy']
# [u'Comedy', u'Drama', u'Romance', u'Sport']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Drama']
# [u'Comedy']
# [u'Comedy']
# [u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Drama', u'History', u'War']
# [u'Comedy']
# [u'Comedy']
# [u'Action', u'Comedy', u'Crime']
# [u'Action', u'Horror']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Drama']
# [u'Adventure', u'Drama', u'Fantasy', u'Romance']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Action', u'Comedy', u'Crime']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Drama', u'History', u'Romance', u'Thriller', u'War']
# [u'Adventure', u'Drama', u'Western']
# [u'Horror']
# [u'Action', u'Comedy', u'Thriller', u'Crime']
# [u'Adventure', u'Comedy', u'Drama']
# [u'Comedy', u'Crime', u'Sci-Fi']
# [u'Adventure', u'Drama', u'Fantasy', u'Romance']
# [u'Adventure', u'Biography', u'Drama', u'History', u'War']
# [u'Action', u'Adventure', u'Comedy', u'Crime', u'Sci-Fi']
# [u'Comedy', u'Drama']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Thriller']
# [u'Comedy', u'Music', u'Romance']
# [u'Comedy', u'Drama', u'Romance']
# [u'Adventure', u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Thriller', u'War']
# [u'Biography', u'Drama', u'Family']
# [u'Adventure', u'Comedy', u'Family']
# [u'Drama', u'History', u'Thriller']
# [u'Crime', u'Drama', u'Romance', u'Thriller']
# [u'Action', u'Biography', u'Drama', u'Thriller', u'War']
# [u'Comedy']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Drama']
# [u'Drama', u'Thriller', u'War']
# [u'Comedy']
# [u'Action', u'Mystery', u'Thriller']
# [u'Animation', u'Fantasy', u'Musical', u'Romance']
# [u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Comedy', u'Horror', u'Romance']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Comedy']
# [u'Drama', u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Mystery', u'Thriller']
# [u'Action', u'Fantasy', u'Horror', u'Thriller']
# [u'Comedy', u'Crime']
# [u'Comedy', u'Sport']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Comedy', u'Romance']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Family', u'Mystery']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Western']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Western']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'Horror', u'Romance']
# [u'Adventure', u'Drama']
# [u'Action', u'Comedy', u'Crime', u'Mystery']
# [u'Drama', u'Music']
# [u'Action', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama']
# [u'Comedy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Crime']
# [u'Comedy']
# [u'Comedy']
# [u'Adventure', u'Drama', u'Sci-Fi']
# [u'Drama', u'Romance']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Drama', u'Thriller']
# [u'Comedy', u'Crime', u'Musical']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Sci-Fi', u'Thriller', u'Western']
# [u'Comedy', u'Drama', u'Family']
# [u'Adventure', u'Comedy', u'Family']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'War']
# [u'Crime', u'Drama']
# [u'Action', u'Adventure', u'Comedy', u'Romance', u'Thriller']
# [u'Comedy', u'Sci-Fi']
# [u'Horror', u'Mystery']
# [u'Comedy', u'Drama']
# [u'Action', u'Crime', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Action', u'Romance', u'Thriller']
# [u'Drama', u'Horror', u'Thriller']
# [u'Adventure', u'Drama', u'Romance', u'Thriller']
# [u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Sci-Fi']
# [u'Drama']
# [u'Action', u'Thriller']
# [u'Action', u'Horror']
# [u'Crime', u'Drama']
# [u'Drama', u'Fantasy', u'Mystery', u'Romance']
# [u'Drama', u'Romance']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Biography', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Crime', u'Thriller']
# [u'Comedy', u'Crime', u'Drama']
# [u'Action', u'Mystery', u'Thriller']
# [u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama']
# [u'Action', u'Comedy', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Romance']
# [u'Action', u'Crime', u'Mystery', u'Thriller']
# [u'Action', u'Comedy', u'Sci-Fi']
# [u'Drama', u'Romance', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Sci-Fi']
# [u'Action', u'Adventure', u'Biography', u'Drama', u'History']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Romance']
# [u'Animation', u'Action', u'Comedy', u'Family', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Drama', u'War']
# [u'Adventure', u'Comedy']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Sci-Fi']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Animation', u'Comedy', u'Musical']
# [u'Comedy', u'Romance']
# [u'Biography', u'Drama', u'History']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Drama', u'Family']
# [u'Musical', u'Romance']
# [u'Comedy']
# [u'Biography', u'Drama', u'Sport']
# [u'Comedy', u'Fantasy', u'Romance', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Musical']
# [u'Action', u'Comedy', u'Crime', u'Mystery', u'Thriller']
# [u'Comedy']
# [u'Adventure', u'Comedy']
# [u'Horror']
# [u'Action', u'Horror', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Drama', u'Romance']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Crime', u'Drama', u'Thriller']
# [u'Mystery', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Adventure', u'Drama', u'History', u'War']
# [u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Adventure', u'Crime', u'Thriller']
# [u'Adventure', u'Comedy']
# [u'Biography', u'Drama']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Thriller']
# [u'Action', u'Fantasy', u'Horror']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama']
# [u'Animation', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Comedy', u'Romance']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Crime']
# [u'Adventure', u'Fantasy', u'Romance']
# [u'Action', u'Comedy']
# [u'Comedy']
# [u'Action', u'Adventure', u'History']
# [u'Drama', u'Fantasy', u'Romance', u'Thriller']
# [u'Drama', u'Sport']
# [u'Comedy']
# [u'Drama', u'Horror', u'Thriller']
# [u'Sci-Fi']
# [u'Action', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Mystery', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Drama']
# [u'Action', u'Drama', u'Thriller']
# [u'Animation', u'Adventure', u'Family', u'Musical', u'War']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family']
# [u'Drama', u'Romance']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Action', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Drama', u'Romance']
# [u'Biography', u'Drama', u'Sport']
# [u'Action', u'Crime', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Drama', u'Romance']
# [u'Drama', u'Romance']
# [u'Adventure', u'Drama', u'History']
# [u'Comedy', u'Music']
# [u'Action', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Sport']
# [u'Adventure', u'Horror']
# [u'Action', u'Adventure', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance']
# [u'Action', u'Comedy', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Adventure', u'Comedy', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Animation', u'Family', u'Fantasy']
# [u'Action', u'Crime', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Fantasy']
# [u'Comedy', u'Drama', u'Romance']
# [u'Biography', u'Comedy', u'Drama']
# [u'Action', u'Thriller']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Drama', u'Sci-Fi']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Romance', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Comedy', u'Romance']
# [u'Mystery', u'Thriller']
# [u'Drama', u'Thriller']
# [u'Biography', u'Drama', u'History']
# [u'Action', u'Biography', u'Drama', u'Sport']
# [u'Comedy', u'Drama']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Drama', u'Music', u'Romance']
# [u'Action', u'Adventure', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Action', u'Comedy', u'Romance']
# [u'Biography', u'Crime', u'Western']
# [u'Drama', u'War']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Western']
# [u'Action', u'Drama', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'Family', u'Musical', u'Romance']
# [u'Comedy', u'Family', u'Fantasy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Drama']
# [u'Action', u'Adventure', u'Biography', u'Drama', u'History', u'Romance', u'War']
# [u'Adventure', u'Drama', u'War']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Drama', u'Thriller']
# [u'Comedy', u'Musical', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Animation', u'Comedy', u'Family', u'Fantasy', u'Romance']
# [u'Horror', u'Romance']
# [u'Horror']
# [u'Action', u'Comedy', u'Crime', u'Music']
# [u'Action', u'Adventure', u'Comedy', u'Drama', u'War']
# [u'Action', u'Drama', u'Fantasy']
# [u'Drama', u'Romance', u'War']
# [u'Comedy', u'Romance']
# [u'Horror', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Sci-Fi']
# [u'Drama', u'War']
# [u'Mystery', u'Thriller']
# [u'Comedy', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Animation', u'Fantasy']
# [u'Action', u'Adventure', u'Comedy', u'Fantasy', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Comedy', u'Musical', u'Romance']
# [u'Comedy', u'Drama', u'Romance']
# [u'Adventure', u'Mystery', u'Sci-Fi']
# [u'Drama', u'Horror', u'Mystery']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Animation', u'Comedy', u'Family', u'Fantasy']
# [u'Horror']
# [u'Action', u'Comedy', u'Crime', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Crime', u'Drama']
# [u'Biography', u'Crime', u'Drama', u'History', u'Western']
# [u'Drama']
# [u'Action', u'Adventure', u'Thriller']
# [u'Animation', u'Action', u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Fantasy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Romance']
# [u'Drama', u'Horror', u'Thriller']
# [u'Animation', u'Family', u'Comedy']
# [u'Drama', u'Sci-Fi']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Comedy', u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'History']
# [u'Drama', u'History', u'War']
# [u'Comedy', u'Family', u'Fantasy']
# [u'Drama', u'Music', u'Thriller']
# [u'Mystery', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'History', u'War']
# [u'Adventure', u'Drama', u'Family', u'Mystery', u'Sci-Fi']
# [u'Biography', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Fantasy']
# [u'Drama', u'Music', u'Romance']
# [u'Horror']
# [u'Animation', u'Comedy', u'Crime', u'Family', u'Fantasy']
# [u'Biography', u'Drama']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Adventure', u'Comedy', u'Drama']
# [u'Adventure', u'Comedy']
# [u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Adventure', u'Comedy', u'Romance', u'Thriller', u'Western']
# [u'Comedy', u'Horror']
# [u'Animation', u'Comedy', u'Sci-Fi']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'Romance']
# [u'Comedy']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Western', u'Comedy', u'Sci-Fi']
# [u'Drama', u'Film-Noir']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Drama', u'History', u'War']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Adventure', u'Horror', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Crime', u'Family']
# [u'Action', u'Comedy', u'Crime']
# [u'Action', u'Thriller']
# [u'Adventure', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Horror', u'Mystery']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Mystery', u'Thriller']
# [u'Action', u'Fantasy', u'Horror', u'Thriller']
# [u'Drama']
# [u'Action', u'Western']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Adventure', u'Fantasy', u'Mystery']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Crime', u'Romance', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Horror', u'Thriller']
# [u'Crime', u'Drama', u'History']
# [u'Comedy', u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Sport']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy']
# [u'Animation', u'Adventure', u'Drama', u'Family', u'Romance']
# [u'Documentary']
# [u'Comedy', u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Action', u'Comedy', u'Sport']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Comedy', u'Crime']
# [u'Drama']
# [u'Animation', u'Comedy', u'Family', u'Music']
# [u'Crime', u'Drama', u'Horror', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Horror']
# [u'Horror', u'Romance']
# [u'Comedy', u'Crime', u'Sport']
# [u'Drama']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Fantasy', u'Horror']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Comedy', u'Crime']
# [u'Drama', u'Fantasy', u'Romance', u'Sci-Fi']
# [u'Drama']
# [u'Animation', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Comedy', u'Crime']
# [u'Drama', u'Family']
# [u'Action', u'Adventure', u'Comedy', u'Drama', u'Fantasy']
# [u'Crime', u'Drama']
# [u'Drama', u'Sci-Fi']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Drama', u'Family', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Comedy', u'Drama', u'War']
# [u'Horror']
# [u'Action', u'Adventure', u'Comedy', u'Sci-Fi']
# [u'Action', u'Drama', u'Sci-Fi']
# [u'Action', u'Crime', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Thriller']
# [u'Family', u'Fantasy', u'Musical']
# [u'Comedy']
# [u'Biography', u'Drama', u'History', u'Sport']
# [u'Biography', u'Drama']
# [u'Action', u'Comedy']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'History', u'Romance', u'War']
# [u'Action', u'Drama', u'Sport']
# [u'Comedy', u'Drama', u'Music', u'Musical']
# [u'Comedy', u'Horror']
# [u'Horror', u'Thriller']
# [u'Comedy', u'Drama', u'Thriller']
# [u'Action', u'Horror', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Crime', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Thriller']
# [u'Crime', u'Drama']
# [u'Drama', u'War']
# [u'Action', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Horror']
# [u'Comedy', u'Romance']
# [u'Animation', u'Drama', u'War']
# [u'Drama', u'Sci-Fi']
# [u'Drama', u'Sport']
# [u'Horror', u'Thriller']
# [u'Comedy']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Crime', u'Mystery', u'Thriller']
# [u'Action', u'Drama', u'Family', u'Sport']
# [u'Comedy']
# [u'Action', u'Adventure', u'Comedy', u'Crime']
# [u'Comedy']
# [u'Action', u'Adventure', u'Family', u'Fantasy']
# [u'Comedy', u'Mystery', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Romance']
# [u'Documentary']
# [u'Drama', u'Mystery']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Sport']
# [u'Comedy', u'Family', u'Fantasy']
# [u'Adventure', u'Comedy']
# [u'Action', u'Drama', u'History', u'Thriller', u'War']
# [u'Crime', u'Drama', u'Sport']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Sci-Fi']
# [u'Comedy', u'Western']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Drama', u'Family', u'Sport']
# [u'Crime', u'Drama']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Romance']
# [u'Action', u'Mystery', u'Sci-Fi']
# [u'Drama', u'History', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Comedy', u'Drama', u'Family', u'Romance']
# [u'Horror', u'Sci-Fi']
# [u'Comedy']
# [u'Action', u'Adventure', u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Adventure', u'Fantasy']
# [u'Drama', u'War']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Action', u'Fantasy', u'Horror']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Horror', u'Sci-Fi']
# [u'Action', u'Adventure', u'Fantasy', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Drama', u'Fantasy', u'Horror', u'War']
# [u'Comedy']
# [u'Comedy', u'Fantasy', u'Romance']
# [u'Action', u'Adventure', u'Thriller', u'War']
# [u'Drama', u'Fantasy', u'Romance', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Family', u'Musical']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Romance']
# [u'Drama']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Music']
# [u'Drama', u'War']
# [u'Drama', u'Mystery', u'Romance', u'Thriller']
# [u'Comedy', u'War']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Drama', u'Romance']
# [u'Comedy', u'Crime']
# [u'Comedy', u'Drama']
# [u'Action', u'Drama', u'Thriller', u'War']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Action', u'Adventure', u'Drama', u'Romance', u'War']
# [u'Comedy', u'Crime']
# [u'Action', u'Comedy', u'Crime']
# [u'Comedy', u'Crime', u'Drama', u'Mystery']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Drama', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy']
# [u'Comedy']
# [u'Action', u'Adventure', u'Drama', u'Fantasy', u'History']
# [u'Crime', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Crime', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Crime']
# [u'Animation', u'Action', u'Adventure', u'Drama', u'Fantasy', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Family', u'Fantasy']
# [u'Comedy']
# [u'Animation', u'Action', u'Adventure', u'Family', u'Fantasy', u'Mystery']
# [u'Comedy', u'Drama', u'Family']
# [u'Comedy', u'Romance']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Sci-Fi']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Family']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Film-Noir', u'Mystery']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Comedy', u'Drama']
# [u'Drama', u'Romance', u'War', u'Western']
# [u'Horror']
# [u'Comedy']
# [u'Film-Noir', u'Mystery', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Comedy', u'Horror']
# [u'Comedy', u'Romance']
# [u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy']
# [u'Comedy', u'Crime']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'Music']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Drama', u'Family', u'Fantasy']
# [u'Comedy', u'Crime', u'Drama', u'Thriller']
# [u'Biography', u'Comedy', u'Drama', u'History', u'Music']
# [u'Sci-Fi', u'Adventure', u'Action']
# [u'Animation', u'Comedy', u'Drama']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Sport']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Animation', u'Adventure', u'Drama', u'Family', u'History', u'Musical', u'Romance']
# [u'Drama', u'Romance', u'Sci-Fi']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Music']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'History']
# [u'Comedy', u'Romance']
# [u'Action', u'Comedy', u'Crime']
# [u'Action', u'Adventure']
# [u'Action', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Romance', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Drama']
# [u'Drama', u'History', u'War']
# [u'Animation', u'Adventure', u'Comedy', u'Drama', u'Family', u'Fantasy', u'Music', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Fantasy']
# [u'Drama', u'Sci-Fi']
# [u'Drama', u'Fantasy']
# [u'Comedy', u'Drama']
# [u'Adventure', u'Drama', u'History', u'Romance', u'War']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Comedy', u'Family', u'Fantasy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Biography', u'Crime', u'Drama']
# [u'Action', u'Crime', u'Romance', u'Thriller']
# [u'Comedy', u'Crime', u'Drama', u'Mystery', u'Romance']
# [u'Adventure', u'Comedy', u'Sci-Fi', u'Thriller']
# [u'Sci-Fi', u'Thriller']
# [u'Drama', u'History', u'War']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Thriller']
# [u'Adventure', u'Fantasy']
# [u'Biography', u'Comedy', u'Drama']
# [u'Comedy', u'Sci-Fi']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Comedy', u'Crime']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Comedy']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Drama']
# [u'Comedy']
# [u'Comedy', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy']
# [u'Horror', u'Mystery']
# [u'Action', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Animation', u'Adventure', u'Comedy', u'Family']
# [u'Action', u'Adventure', u'Comedy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Fantasy', u'Sci-Fi', u'Sport']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Drama', u'History', u'Romance', u'War']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Horror', u'Romance']
# [u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'Horror', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Family', u'Fantasy', u'Musical']
# [u'Biography', u'Crime', u'Drama']
# [u'Crime', u'Drama']
# [u'Drama', u'Sport']
# [u'Comedy', u'Romance']
# [u'Drama', u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Mystery', u'Romance']
# [u'Drama', u'Mystery']
# [u'Action', u'Drama', u'Sci-Fi']
# [u'Adventure', u'Comedy', u'Family', u'Sci-Fi']
# [u'Biography', u'Drama', u'History']
# [u'Action', u'Adventure', u'Fantasy', u'Thriller']
# [u'Drama']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Adventure', u'Family', u'Fantasy']
# [u'Horror', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Musical']
# [u'Action', u'Drama', u'History', u'War']
# [u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Action', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Crime']
# [u'Action', u'Adventure', u'Comedy', u'Fantasy', u'Thriller']
# [u'Action', u'Drama', u'Fantasy']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Romance', u'Sci-Fi']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Fantasy']
# [u'Adventure', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Biography', u'Drama', u'History', u'War']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Thriller']
# [u'Comedy', u'Drama', u'Music']
# [u'Drama']
# [u'Action', u'Comedy', u'Crime', u'Fantasy']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Drama']
# [u'Action', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Adventure', u'Fantasy', u'Thriller']
# [u'Biography', u'Crime', u'Drama']
# [u'Animation', u'Family', u'Fantasy', u'Musical', u'Romance']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Crime', u'Drama']
# [u'Drama']
# [u'Comedy', u'Musical', u'Romance']
# [u'Drama']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Horror']
# [u'Action', u'Adventure']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Adventure', u'Comedy']
# [u'Drama', u'Romance']
# [u'Comedy', u'Drama', u'Romance']
# [u'Mystery', u'Thriller']
# [u'Drama', u'Romance']
# [u'Animation', u'Action', u'Sci-Fi']
# [u'Drama', u'Musical', u'Romance', u'Thriller']
# [u'Drama', u'Romance']
# [u'Horror', u'Mystery']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Animation', u'Comedy', u'Family']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Mystery']
# [u'Adventure', u'Drama', u'History', u'War']
# [u'Adventure', u'Drama', u'Romance', u'Sci-Fi']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Fantasy']
# [u'Adventure', u'Drama', u'Family', u'Fantasy']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Crime', u'Comedy']
# [u'Drama', u'Fantasy', u'Romance']
# [u'Adventure', u'Biography', u'Drama', u'History', u'War']
# [u'Crime', u'Drama']
# [u'Drama']
# [u'Comedy', u'Drama']
# [u'Drama', u'Romance']
# [u'Drama', u'Fantasy', u'Musical', u'Romance']
# [u'Action', u'Adventure', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Comedy', u'Western']
# [u'Comedy', u'Drama', u'War']
# [u'Action', u'Drama', u'History', u'Romance', u'Western']
# [u'Horror', u'Thriller']
# [u'Comedy', u'Fantasy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'War']
# [u'Comedy']
# ...
# [u'Comedy', u'Drama']
# [u'Documentary', u'History', u'Music']
# [u'Drama', u'Music']
# [u'Action', u'Western']
# [u'Drama', u'Comedy']
# [u'Comedy']
# [u'Drama']
# [u'Fantasy', u'Horror', u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Film-Noir', u'Mystery']
# [u'Comedy', u'Crime']
# [u'Biography', u'Comedy', u'Drama', u'Musical', u'Romance']
# [u'Drama']
# [u'Horror', u'Sci-Fi']
# [u'Drama', u'Comedy']
# [u'Biography', u'Drama', u'Romance']
# [u'Comedy', u'Drama', u'Music']
# [u'Horror', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama']
# [u'Horror', u'Thriller']
# [u'Comedy', u'Drama', u'Family', u'Romance']
# [u'Comedy', u'Drama']
# [u'Comedy']
# [u'Action', u'Crime', u'Drama', u'Romance', u'Thriller']
# [u'Action', u'Drama', u'War']
# [u'Horror', u'Thriller']
# [u'Comedy']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Crime', u'Drama', u'Mystery']
# [u'Animation', u'Drama', u'Family', u'Fantasy', u'Romance']
# [u'Comedy', u'Crime', u'Romance']
# [u'Drama']
# [u'Drama', u'Romance']
# [u'Comedy']
# [u'Action', u'Crime', u'Fantasy', u'Music', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Drama']
# [u'Drama']
# [u'Biography', u'Drama', u'History', u'War']
# [u'Comedy', u'Romance']
# [u'Action', u'Sci-Fi']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Animation', u'Comedy', u'Music']
# [u'Comedy']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Horror', u'Sci-Fi']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Thriller']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'History']
# [u'Comedy', u'Family']
# [u'Comedy', u'Drama', u'Romance']
# [u'Animation', u'Comedy', u'Family']
# [u'Comedy', u'Crime']
# [u'Horror', u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance']
# [u'Action', u'Comedy', u'Romance']
# [u'Drama', u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Crime', u'Mystery', u'Comedy']
# [u'Documentary', u'History', u'Sport']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Romance', u'Thriller']
# [u'Comedy', u'Drama', u'Family', u'Music', u'Romance']
# [u'Comedy', u'Musical', u'Drama', u'Romance']
# [u'Biography', u'Drama', u'History']
# [u'Crime', u'Film-Noir', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Drama', u'Music', u'Romance']
# [u'Crime', u'Drama']
# [u'Drama']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Comedy', u'Horror', u'Sci-Fi']
# [u'Comedy', u'Crime', u'Family', u'Musical']
# [u'Action', u'Crime', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Mystery']
# [u'Comedy']
# [u'Comedy', u'Drama', u'Family']
# [u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'History', u'War']
# [u'Comedy', u'Drama', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Family', u'Comedy', u'Adventure', u'Romance']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Crime', u'Drama', u'Western']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Western']
# [u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Family', u'Fantasy']
# [u'Drama']
# [u'Comedy', u'Crime']
# [u'Drama', u'Romance']
# [u'Drama']
# [u'Biography', u'Comedy', u'Drama', u'History']
# [u'Western']
# [u'Action', u'Adventure', u'Romance', u'Thriller']
# [u'Comedy', u'Family']
# [u'Comedy']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Sport']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'Horror', u'Romance', u'Thriller']
# [u'Drama', u'War']
# [u'Action', u'Comedy', u'Crime', u'Horror', u'Thriller']
# [u'Comedy', u'Crime', u'Drama']
# [u'Action', u'Adventure']
# [u'Animation', u'Action', u'Drama', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Animation', u'Comedy']
# [u'Crime', u'Drama', u'Mystery']
# [u'Comedy', u'Drama', u'Mystery', u'Romance']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Action', u'Adventure', u'Comedy', u'Family', u'Musical', u'Romance', u'Sport', u'Western']
# [u'Drama', u'Mystery']
# [u'Comedy']
# [u'Drama']
# [u'Adventure', u'Drama']
# [u'Action', u'Fantasy', u'Horror', u'Thriller']
# [u'Adventure', u'Comedy', u'Drama', u'Family', u'Sport']
# [u'Comedy', u'Drama', u'Family']
# [u'Adventure', u'Drama', u'Fantasy']
# [u'Drama']
# [u'Horror', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Film-Noir', u'Thriller']
# [u'Mystery', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Drama']
# [u'Action', u'Crime', u'Drama', u'Music', u'Romance', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Drama']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Drama', u'Romance', u'Sport']
# [u'Drama', u'Family', u'Sport']
# [u'Comedy', u'Drama', u'Fantasy', u'Mystery']
# [u'Action', u'Adventure', u'Drama', u'Thriller']
# [u'Reality-TV']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Drama', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Biography', u'Drama']
# [u'Horror']
# [u'Drama', u'Mystery', u'Thriller']
# [u'Biography', u'Drama', u'History', u'Sport']
# [u'Mystery', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Comedy']
# [u'Drama', u'History', u'War']
# [u'Comedy']
# [u'Action', u'Comedy', u'Horror', u'Sci-Fi']
# [u'Action', u'Drama', u'Sport']
# [u'Horror', u'Romance', u'Thriller']
# [u'Comedy', u'Drama', u'Horror', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy']
# [u'Drama', u'Music', u'Musical', u'Romance']
# [u'Action', u'Comedy', u'Thriller']
# [u'Biography', u'Crime', u'Drama']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Crime']
# [u'Biography', u'Drama']
# [u'Comedy']
# [u'Documentary', u'History', u'War']
# [u'Drama', u'Romance', u'Thriller']
# [u'Documentary']
# [u'Comedy']
# [u'Documentary', u'Comedy']
# [u'Comedy']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Western']
# [u'Drama', u'Romance']
# [u'Adventure', u'Fantasy', u'Sci-Fi', u'Western']
# [u'Comedy', u'Sci-Fi']
# [u'Comedy']
# [u'Biography', u'Crime', u'Drama', u'History', u'Mystery']
# [u'Drama']
# [u'Horror']
# [u'Documentary']
# [u'Drama', u'Music']
# [u'Comedy', u'Mystery', u'Romance']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'History', u'Sci-Fi']
# [u'Biography', u'Drama']
# [u'Drama']
# [u'Thriller', u'Drama']
# [u'Comedy']
# [u'Adventure', u'Comedy', u'Mystery', u'Romance', u'Sci-Fi']
# [u'Drama', u'Romance', u'Thriller']
# [u'Biography', u'Drama', u'History', u'Romance']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Crime', u'Thriller']
# [u'Animation', u'Comedy', u'Family', u'Fantasy']
# [u'Drama', u'Fantasy', u'Horror', u'Thriller']
# [u'Action', u'Adventure', u'Drama', u'Sci-Fi']
# [u'Family', u'Fantasy']
# [u'Comedy', u'Drama', u'War']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Musical', u'Romance']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Horror', u'Mystery']
# [u'Drama', u'War']
# [u'Crime', u'Drama', u'Mystery', u'Romance', u'Thriller']
# [u'Action', u'Crime', u'Drama']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Mystery', u'Romance']
# [u'Animation', u'Comedy', u'Family', u'Fantasy']
# [u'Comedy', u'Drama', u'Fantasy', u'Romance']
# [u'Comedy', u'Romance']
# [u'Animation', u'Action', u'Comedy', u'Family', u'Musical']
# [u'Comedy', u'Drama']
# [u'Documentary']
# [u'Drama']
# [u'Comedy', u'Drama', u'Mystery']
# [u'Comedy', u'Horror']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Thriller']
# [u'Adventure', u'Mystery', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Animation', u'Comedy', u'Family']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama', u'Fantasy']
# [u'Crime', u'Drama']
# [u'Action', u'Crime', u'Drama', u'Thriller']
# [u'Drama', u'Romance', u'Western']
# [u'Animation', u'Drama', u'Sci-Fi']
# [u'Comedy', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Crime', u'Mystery']
# [u'Drama', u'Horror', u'Mystery']
# [u'Comedy', u'Crime']
# [u'Drama']
# [u'Drama', u'Mystery', u'Sci-Fi']
# [u'Drama', u'Horror']
# [u'Crime', u'Drama', u'Mystery']
# [u'Drama', u'Fantasy', u'History', u'Mystery', u'Romance']
# [u'Action', u'Fantasy', u'Horror']
# [u'Comedy', u'Drama', u'Romance', u'War']
# [u'Action', u'Adventure', u'Comedy']
# [u'Drama', u'Fantasy', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Family', u'Music', u'Romance']
# [u'Animation', u'Action', u'Adventure', u'Fantasy', u'Horror']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Crime', u'Drama', u'Mystery', u'Romance', u'Thriller']
# [u'Action', u'Drama', u'Thriller']
# [u'Comedy', u'Musical', u'Romance']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Comedy']
# [u'Horror', u'Fantasy']
# [u'Animation', u'Action', u'Adventure', u'Comedy', u'Family']
# [u'Comedy']
# [u'Adventure', u'Drama', u'Family']
# [u'Comedy', u'Crime']
# [u'Drama', u'Western']
# [u'Comedy', u'Romance']
# [u'Comedy', u'Drama']
# [u'Action', u'Comedy', u'Thriller']
# [u'Drama', u'Horror', u'Thriller']
# [u'Comedy', u'Crime']
# [u'Comedy', u'Drama']
# [u'Action', u'Fantasy', u'Horror', u'Thriller']
# [u'Drama']
# [u'Comedy', u'Drama']
# [u'Horror', u'Sci-Fi']
# [u'Mystery', u'Sci-Fi', u'Thriller']
# [u'Drama']
# [u'Adventure', u'Comedy', u'Drama', u'Family']
# [u'Horror', u'Thriller']
# [u'Action', u'Adventure', u'Comedy', u'Crime', u'Family', u'Fantasy', u'Mystery', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Comedy', u'Crime', u'Drama']
# [u'Horror', u'Mystery']
# [u'Comedy', u'Romance']
# [u'Drama', u'Romance']
# [u'Romance', u'Sci-Fi']
# [u'Adventure', u'Comedy', u'Romance']
# [u'Drama', u'Romance']
# [u'Action', u'Comedy']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Crime', u'Thriller']
# [u'Drama', u'Romance']
# [u'Action', u'Comedy']
# [u'Crime', u'Drama', u'Thriller']
# [u'Comedy']
# [u'Drama', u'Romance']
# [u'Documentary']
# [u'Documentary']
# [u'Adventure', u'Comedy', u'Drama', u'Family', u'Fantasy']
# [u'Drama', u'Mystery', u'Romance']
# [u'Drama', u'War']
# [u'Documentary', u'Comedy']
# [u'Drama', u'Fantasy']
# [u'Comedy', u'Drama']
# [u'Crime', u'Drama']
# [u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Comedy', u'Drama', u'Fantasy']
# [u'Comedy']
# [u'Animation', u'Action', u'Adventure', u'Family', u'Fantasy', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama', u'Romance', u'War', u'Western']
# [u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Crime', u'Drama', u'Thriller', u'War']
# [u'Adventure', u'Drama', u'History', u'Romance']
# [u'Comedy', u'Crime', u'Romance', u'Thriller']
# [u'Documentary']
# [u'Comedy', u'Drama']
# [u'Animation', u'Action', u'Adventure', u'Drama', u'Fantasy']
# [u'Drama', u'Horror', u'Mystery', u'Thriller']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Drama', u'Romance']
# [u'Drama', u'Mystery', u'Romance']
# [u'Drama']
# [u'Drama']
# [u'History', u'Thriller', u'War']
# [u'Drama']
# [u'Horror', u'Thriller']
# [u'Adventure', u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama']
# [u'Horror']
# [u'Biography', u'Drama']
# [u'Drama', u'Romance', u'Thriller']
# [u'Drama', u'History', u'Romance', u'War']
# [u'Comedy', u'Thriller']
# [u'Comedy']
# [u'Comedy', u'Romance']
# [u'Crime', u'Mystery', u'Thriller']
# [u'Adventure', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama']
# [u'Drama', u'Romance']
# [u'Comedy', u'Romance', u'Drama']
# [u'Comedy', u'Musical', u'Adventure', u'Action']
# [u'Drama', u'Romance']
# [u'Horror', u'Thriller']
# [u'Drama', u'Sport']
# [u'Crime', u'Drama']
# [u'Animation', u'Family', u'Sci-Fi']
# [u'Drama', u'Fantasy', u'Thriller']
# [u'Drama', u'Romance']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Adventure', u'Fantasy']
# [u'Comedy', u'Romance']
# [u'Action', u'Adventure', u'Horror', u'Sci-Fi', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Drama', u'Thriller']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama']
# [u'Drama', u'Thriller']
# [u'Action', u'Adventure', u'Game-Show', u'Reality-TV']
# [u'Horror', u'Thriller']
# [u'Drama', u'Romance']
# [u'Documentary', u'Sport']
# [u'Drama', u'Fantasy', u'Mystery', u'Romance', u'Thriller']
# [u'Action', u'Comedy', u'Crime', u'Drama', u'Thriller']
# [u'Animation', u'Adventure', u'Crime', u'Family', u'Mystery']
# [u'Action', u'Drama', u'Fantasy', u'Romance']
# [u'Drama', u'Romance']
# [u'Action', u'Comedy']
# [u'Drama', u'Romance', u'Thriller']
# [u'Drama', u'Horror', u'Thriller', u'Mystery']
# [u'Horror', u'Thriller']
# [u'Action', u'War']
# [u'Comedy', u'Drama', u'Family']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Comedy', u'Music', u'Talk-Show']
# [u'Animation', u'Action', u'Drama', u'Sci-Fi']
# [u'Action', u'Comedy', u'Crime', u'Drama', u'Western']
# [u'Crime', u'Drama', u'Thriller']
# [u'Crime', u'Drama', u'Thriller']
# [u'Biography', u'Drama', u'Music']
# [u'Adventure', u'Family', u'Sci-Fi']
# [u'Drama']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Drama', u'War']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama']
# [u'Action', u'Comedy', u'Horror']
# [u'Action', u'Drama']
# [u'Drama', u'Fantasy']
# [u'Comedy', u'Crime']
# [u'Comedy', u'Family', u'Sci-Fi']
# [u'Comedy']
# [u'Drama', u'Romance', u'Western']
# [u'Animation', u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']
# [u'Action', u'Crime', u'Sci-Fi']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Action', u'Crime', u'Thriller']
# [u'Family', u'Comedy']
# [u'Action', u'Comedy', u'Musical', u'Thriller']
# [u'Crime', u'Thriller']
# [u'Action', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Biography', u'Drama', u'History', u'Romance']
# [u'Documentary', u'Comedy']
# [u'Action', u'Adventure', u'Comedy', u'Family', u'Sci-Fi']
# [u'Drama', u'Thriller']
# [u'Documentary', u'Horror']
# [u'Drama']
# [u'Comedy', u'Family', u'Music']
# [u'Comedy', u'Drama', u'Romance']
# [u'Biography', u'Drama', u'Mystery']
# [u'Adventure', u'Crime', u'Drama', u'Film-Noir', u'Thriller']
# [u'Crime', u'Drama', u'Romance']
# [u'Comedy', u'Family']
# [u'Action', u'Drama', u'Horror', u'Sci-Fi']
# [u'Comedy', u'Drama']
# [u'Drama', u'Family', u'Romance', u'Western']
# [u'Action', u'Thriller']
# [u'Comedy', u'Horror']
# [u'Comedy', u'Romance']
# [u'Comedy', u'Crime', u'Drama']
# [u'Drama', u'Horror']
# [u'Crime', u'Drama', u'Thriller']
# [u'Action', u'Sci-Fi', u'Thriller']
# [u'Crime', u'Drama', u'Romance']
# [u'Horror', u'Mystery', u'Thriller']
# [u'Drama']
# [u'Biography', u'Crime', u'Drama', u'History', u'Thriller']
# [u'Horror']
# [u'Animation', u'Adventure', u'Family', u'Fantasy']
# [u'Adventure', u'Crime', u'Drama', u'Fantasy', u'Mystery', u'Thriller']
# [u'Comedy', u'Crime']
# [u'Biography', u'Drama', u'Musical', u'Romance']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Documentary']
# [u'Adventure', u'Biography', u'Drama', u'Fantasy', u'Romance', u'Sci-Fi', u'Thriller']
# [u'Adventure', u'Thriller']
# [u'Drama', u'War']
# [u'Comedy']
# [u'Drama']
# [u'Comedy', u'Family']
# [u'Action', u'Adventure', u'History', u'Sci-Fi']
# [u'Drama', u'Music', u'Romance']
# [u'Animation', u'Action', u'Adventure', u'Music', u'Sci-Fi']
# [u'Drama', u'Music']
# [u'Romance', u'Sci-Fi']
# [u'Drama', u'Thriller']
# [u'Comedy']
# [u'Crime', u'Drama', u'Mystery', u'Thriller']
# [u'Comedy', u'Romance']
# [u'Action', u'Crime', u'Drama']
# [u'Comedy']
# [u'Animation', u'Action', u'Comedy', u'Drama', u'Sci-Fi', u'Western']
# [u'Drama', u'Horror']
# [u'Comedy']
# [u'Comedy']
# [u'Comedy']
# [u'Action', u'Crime', u'Thriller']
# [u'Action', u'Adventure', u'Sci-Fi']
# [u'Comedy', u'Drama', u'Romance']
# [u'Drama']
# [u'Biography', u'Drama']
# [u'Comedy', u'Crime', u'Romance']
# [u'Drama']
# [u'Documentary', u'Drama', u'War']
# [u'Documentary', u'Sport']
# [u'Drama']
# [u'Drama', u'Thriller']
# [u'Animation', u'Comedy', u'Family', u'Fantasy']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Documentary']
# [u'Crime', u'Drama']
# [u'Crime', u'Drama', u'Thriller']
# [u'Biography', u'Drama', u'History']
# [u'Documentary']
# [u'Drama']
# [u'Adventure', u'Drama', u'Romance', u'Sci-Fi', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Drama', u'Romance']
# [u'Comedy', u'Drama']
# [u'Drama', u'Sci-Fi', u'Thriller']
# [u'Drama', u'Romance', u'War']
# [u'Drama', u'History', u'War']
# [u'Action', u'Drama']
# [u'Comedy', u'Drama', u'Romance']
# [u'Biography', u'Drama']
# [u'Action', u'Adventure', u'Mystery', u'Sci-Fi']
# [u'Action', u'Comedy', u'Crime', u'Thriller']
# [u'Animation', u'Fantasy', u'Sci-Fi', u'Thriller']
# [u'Horror', u'Thriller']
# [u'Comedy', u'Drama']
# [u'Action', u'Comedy', u'Crime', u'Romance']
# [u'Drama']
# [u'Comedy', u'Drama']
# [u'Comedy', u'Drama']
# [u'Biography', u'Drama', u'Music']
# [u'Crime', u'Drama', u'Mystery']
# [u'Animation', u'Adventure', u'Comedy', u'Family', u'Romance']
# [u'Comedy']

# %%
# clean the data 

# 1- create empty list
genreLyst_clean = []

# enumerate() genre list 
# 2 - iterate thru each item in list 
for movie in myList:
    # 3 - assign the genre to a variable 
    genre = movie[6]
    genreLyst = genre.split(',') # make list in case their are multiple genres

    # 4 - use enumerate 
    
    for index, item in enumerate(genreLyst):
        # go thru each item in the list of genres for that movie and clean
        
        #remove brackets
        genreLyst[index] = genreLyst[index].replace("[","").replace("]","")
        #remove single quotes
        genreLyst[index] = genreLyst[index].replace("'","") # get rid of single quotes
        # remove empty space
        genreLyst[index] = genreLyst[index].replace(" ","") #get rid of empty space
        # get rid of the first character 
        genreLyst[index] = genreLyst[index][1:] # get rid of u [1:] = start at index 1
    # add all cleaned items to new list and go to next movie 
    genreLyst_clean.append(genreLyst)
genreLyst_clean
# Out:
# [['Crime', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Fantasy'],
#  ['Adventure', 'Fantasy'],
#  ['Action', 'Sci-Fi'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Fantasy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Drama'],
#  ['Action', 'Adventure'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Western'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Drama', 'War'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Biography', 'Drama', 'History'],
#  ['Mystery', 'Thriller'],
#  ['Adventure', 'Drama', 'War'],
#  ['Drama'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Adventure', 'Fantasy'],
#  ['Drama', 'Romance'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Drama', 'Fantasy', 'Mystery'],
#  ['Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Biography', 'Drama', 'History', 'War'],
#  ['Action', 'Sci-Fi'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Sci-Fi'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Sci-Fi'],
#  ['Drama'],
#  ['Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Sci-Fi'],
#  ['Biography', 'Comedy', 'Crime', 'Drama'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Adventure', 'Fantasy'],
#  ['Crime', 'Drama'],
#  ['Action', 'Fantasy', 'War'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Animation', 'Adventure', 'Drama', 'Family', 'Musical'],
#  ['Comedy', 'Crime'],
#  ['Comedy'],
#  ['Action', 'Thriller'],
#  ['Horror'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Drama', 'Horror'],
#  ['Action', 'Sci-Fi'],
#  ['Biography', 'Drama'],
#  ['Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Sci-Fi'],
#  ['Adventure', 'Sci-Fi', 'Thriller'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'Sci-Fi'],
#  ['Action', 'Adventure'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Crime'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Fantasy', 'Mystery'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure'],
#  ['Action', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Western'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Adventure', 'Sci-Fi'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Crime', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'War'],
#  ['Drama', 'Sport'],
#  ['Drama', 'War'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Fantasy'],
#  ['Adventure', 'Fantasy'],
#  ['Animation', 'Action', 'Adventure', 'Family'],
#  ['Sci-Fi', 'Thriller'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Fantasy', 'War'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Animation', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'War'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Comedy'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Romance'],
#  ['Adventure', 'Drama'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Crime'],
#  ['Adventure', 'Biography', 'Drama'],
#  ['Mystery', 'Sci-Fi'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Thriller'],
#  ['Comedy', 'Horror'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'Romance'],
#  ['Action', 'Mystery', 'Sci-Fi'],
#  ['Drama', 'Romance', 'War'],
#  ['Action', 'Adventure'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Animation', 'Adventure', 'Family', 'Fantasy'],
#  ['Adventure', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Horror'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Biography', 'Drama', 'History'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Adventure'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama'],
#  ['Adventure', 'Drama', 'Fantasy', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Sci-Fi', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Comedy', 'Crime'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Comedy'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Sport'],
#  ['Comedy', 'War'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Biography', 'Drama'],
#  ['Action', 'Comedy', 'Crime', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'Thriller', 'War'],
#  ['Action', 'Adventure', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Romance', 'Sci-Fi'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Drama', 'History', 'War'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Adventure'],
#  ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'History'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Action', 'Comedy'],
#  ['Drama', 'Sport'],
#  ['Drama'],
#  ['Action', 'Crime', 'Fantasy', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Fantasy'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Horror'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Biography', 'Drama'],
#  ['Drama', 'History', 'Thriller', 'War'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Mystery'],
#  ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Sci-Fi'],
#  ['Drama', 'Mystery', 'Romance', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Family'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Animation', 'Family', 'Fantasy', 'Musical', 'Romance'],
#  ['Horror'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Adventure', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance'],
#  ['Action', 'Crime', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Mystery'],
#  ['Drama', 'War'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Drama', 'Horror', 'Musical', 'Thriller'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Sci-Fi'],
#  ['Family', 'Sci-Fi'],
#  ['Adventure', 'Family', 'Fantasy', 'Musical'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Adventure', 'Biography', 'Drama', 'Thriller'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Fantasy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Western'],
#  ['Action', 'Biography', 'Drama', 'Sport'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Biography', 'Drama', 'Thriller', 'War'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Adventure'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Horror'],
#  ['Action', 'Thriller'],
#  ['Animation', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Romance'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Sport'],
#  ['Drama', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Comedy'],
#  ['Adventure', 'Drama'],
#  ['Drama', 'Fantasy', 'Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy', 'Fantasy'],
#  ['Comedy', 'Romance'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Biography', 'Drama'],
#  ['Comedy', 'Crime', 'Fantasy', 'Romance'],
#  ['Comedy', 'Fantasy'],
#  ['Action', 'Adventure', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'History', 'War'],
#  ['Action', 'Comedy', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'Sci-Fi', 'Sport'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Drama', 'Romance', 'War'],
#  ['Crime', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Comedy', 'Sci-Fi', 'Western'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Drama', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Crime', 'Mystery', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Horror', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Family', 'Mystery'],
#  ['Action', 'Fantasy', 'Sci-Fi'],
#  ['Animation',
#   'Adventure',
#   'Comedy',
#   'Family',
#   'Fantasy',
#   'Musical',
#   'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Horror', 'Romance'],
#  ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#  ['Biography', 'Drama', 'History', 'War'],
#  ['Adventure', 'Crime', 'Drama', 'Western'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Musical', 'Romance'],
#  ['Action', 'Adventure', 'Crime', 'Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Sport'],
#  ['Animation', 'Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Mystery', 'Romance', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Crime', 'Drama', 'History'],
#  ['Drama', 'Musical', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Animation', 'Comedy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Drama', 'War'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Mystery', 'Romance', 'Thriller'],
#  ['Action', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Drama', 'Romance'],
#  ['Action', 'Drama', 'War'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Action', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Thriller'],
#  ['Action', 'Adventure', 'Family', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Adventure', 'Comedy', 'Crime', 'Music'],
#  ['Adventure', 'Comedy', 'Drama', 'Fantasy'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Animation', 'Family', 'Fantasy', 'Musical'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Music'],
#  ['Action', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Romance'],
#  ['Comedy'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Comedy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy', 'Romance'],
#  ['Action', 'Drama', 'Romance'],
#  ['Drama', 'History', 'Thriller'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama', 'History', 'War'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Comedy'],
#  ['Drama', 'Fantasy', 'Mystery', 'Romance', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Horror', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Horror', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Fantasy', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Action'],
#  ['Comedy'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Crime', 'Drama'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Thriller'],
#  ['Crime', 'Thriller'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Adventure', 'Sci-Fi'],
#  ['Drama', 'Romance', 'War'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Adventure', 'Drama', 'History', 'Sci-Fi'],
#  ['Comedy'],
#  ['Drama', 'Music', 'Romance'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'History', 'War'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Western'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Drama', 'Fantasy', 'War'],
#  ['Action', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Comedy', 'Music'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Animation', 'Adventure', 'Fantasy'],
#  ['Drama', 'History', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Romance', 'Sci-Fi', 'Thriller'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Biography', 'Crime', 'Drama', 'Thriller'],
#  ['Biography', 'Drama', 'History', 'War'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Horror'],
#  ['Drama'],
#  ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Crime', 'Thriller'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy'],
#  ['Biography', 'Drama', 'Music', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Mystery', 'Romance', 'War'],
#  ['Animation', 'Adventure', 'Family', 'Fantasy'],
#  ['Adventure', 'Family', 'Fantasy', 'Thriller'],
#  ['Crime', 'Drama', 'Fantasy'],
#  ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Comedy', 'Romance', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Thriller'],
#  ['Action'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Mystery', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Drama'],
#  ['Action', 'Biography', 'Thriller', 'War'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance', 'Sport'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Drama', 'History', 'War'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Horror'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'History', 'Romance', 'Thriller', 'War'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Horror'],
#  ['Action', 'Comedy', 'Thriller', 'Crime'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Comedy', 'Crime', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#  ['Adventure', 'Biography', 'Drama', 'History', 'War'],
#  ['Action', 'Adventure', 'Comedy', 'Crime', 'Sci-Fi'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Thriller', 'War'],
#  ['Biography', 'Drama', 'Family'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Drama', 'History', 'Thriller'],
#  ['Crime', 'Drama', 'Romance', 'Thriller'],
#  ['Action', 'Biography', 'Drama', 'Thriller', 'War'],
#  ['Comedy'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Drama'],
#  ['Drama', 'Thriller', 'War'],
#  ['Comedy'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Animation', 'Fantasy', 'Musical', 'Romance'],
#  ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Horror', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Comedy'],
#  ['Drama', 'Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Mystery', 'Thriller'],
#  ['Action', 'Fantasy', 'Horror', 'Thriller'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Sport'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Romance'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Animation', 'Action', 'Adventure', 'Family', 'Mystery'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Western'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Western'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Horror', 'Romance'],
#  ['Adventure', 'Drama'],
#  ['Action', 'Comedy', 'Crime', 'Mystery'],
#  ['Drama', 'Music'],
#  ['Action', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Crime'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Adventure', 'Drama', 'Sci-Fi'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy', 'Crime', 'Musical'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Sci-Fi', 'Thriller', 'Western'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'War'],
#  ['Crime', 'Drama'],
#  ['Action', 'Adventure', 'Comedy', 'Romance', 'Thriller'],
#  ['Comedy', 'Sci-Fi'],
#  ['Horror', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Fantasy', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Romance', 'Thriller'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Adventure', 'Drama', 'Romance', 'Thriller'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'],
#  ['Drama'],
#  ['Action', 'Thriller'],
#  ['Action', 'Horror'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Fantasy', 'Mystery', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Crime', 'Thriller'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Action', 'Comedy', 'Crime', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Biography', 'Drama', 'History'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Action', 'Comedy', 'Family', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Drama', 'War'],
#  ['Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Animation', 'Comedy', 'Musical'],
#  ['Comedy', 'Romance'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Drama', 'Family'],
#  ['Musical', 'Romance'],
#  ['Comedy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Comedy', 'Fantasy', 'Romance', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Musical'],
#  ['Action', 'Comedy', 'Crime', 'Mystery', 'Thriller'],
#  ['Comedy'],
#  ['Adventure', 'Comedy'],
#  ['Horror'],
#  ['Action', 'Horror', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Mystery', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Drama', 'History', 'War'],
#  ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Crime', 'Thriller'],
#  ['Adventure', 'Comedy'],
#  ['Biography', 'Drama'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Fantasy', 'Thriller'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Animation', 'Family', 'Fantasy', 'Musical', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Fantasy', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Crime'],
#  ['Adventure', 'Fantasy', 'Romance'],
#  ['Action', 'Comedy'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'History'],
#  ['Drama', 'Fantasy', 'Romance', 'Thriller'],
#  ['Drama', 'Sport'],
#  ['Comedy'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Sci-Fi'],
#  ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Action', 'Comedy', 'Crime', 'Drama'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Animation', 'Adventure', 'Family', 'Musical', 'War'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'Romance'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Drama', 'History'],
#  ['Comedy', 'Music'],
#  ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Sport'],
#  ['Adventure', 'Horror'],
#  ['Action', 'Adventure', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Comedy', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Animation', 'Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Drama', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Romance', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Mystery', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Biography', 'Drama', 'Sport'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama', 'Music', 'Romance'],
#  ['Action', 'Adventure', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Biography', 'Crime', 'Western'],
#  ['Drama', 'War'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#  ['Western'],
#  ['Action', 'Drama', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'Family', 'Musical', 'Romance'],
#  ['Comedy', 'Family', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Biography', 'Drama', 'History', 'Romance', 'War'],
#  ['Adventure', 'Drama', 'War'],
#  ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  ['Animation', 'Comedy', 'Family', 'Fantasy', 'Romance'],
#  ['Horror', 'Romance'],
#  ['Horror'],
#  ['Action', 'Comedy', 'Crime', 'Music'],
#  ['Action', 'Adventure', 'Comedy', 'Drama', 'War'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Drama', 'Romance', 'War'],
#  ['Comedy', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'],
#  ['Drama', 'War'],
#  ['Mystery', 'Thriller'],
#  ['Comedy', 'Family', 'Fantasy', 'Musical', 'Romance'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Animation', 'Fantasy'],
#  ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Horror', 'Mystery'],
#  ['Comedy'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Animation', 'Comedy', 'Family', 'Fantasy'],
#  ['Horror'],
#  ['Action', 'Comedy', 'Crime', 'Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Biography', 'Crime', 'Drama', 'History', 'Western'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Animation', 'Action', 'Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Fantasy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Animation', 'Family', 'Comedy'],
#  ['Drama', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama', 'History'],
#  ['Drama', 'History', 'War'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Drama', 'Music', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'History', 'War'],
#  ['Adventure', 'Drama', 'Family', 'Mystery', 'Sci-Fi'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Fantasy'],
#  ['Drama', 'Music', 'Romance'],
#  ['Horror'],
#  ['Animation', 'Comedy', 'Crime', 'Family', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Adventure', 'Comedy'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Comedy', 'Romance', 'Thriller', 'Western'],
#  ['Comedy', 'Horror'],
#  ['Animation', 'Comedy', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Animation', 'Action', 'Adventure', 'Comedy', 'Family'],
#  ['Action', 'Western', 'Comedy', 'Sci-Fi'],
#  ['Drama', 'Film-Noir'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Drama', 'History', 'War'],
#  ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Horror', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy', 'Crime', 'Family'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Drama', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Horror', 'Sci-Fi', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Fantasy', 'Horror', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Western'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Adventure', 'Fantasy', 'Mystery'],
#  ['Action', 'Crime', 'Thriller'],
#  ...]

# %%
# make an empty dicitonary for movie genres
genreCount = {}


#iterate through the text and add the movie genere (key) and the amount of times 
# that it is mentioned (value)

for movie in myList: # iterate thru each movie 
    for genre in genreLyst_clean # iterate thru each genre for that movie 
        if genre in genreCount.keys(): # if genre alredy in dictionary keys, increase value by 1 
            genreCount[genre] += 1 
        else:
            genreCount[genre] = 1
genreCount
# Out:
# {"[u'Crime'": 530,
#  " u'Drama']": 544,
#  "[u'Action'": 1355,
#  " u'Crime'": 645,
#  " u'Mystery'": 586,
#  " u'Sci-Fi'": 342,
#  " u'Thriller']": 1890,
#  "[u'Drama']": 301,
#  "[u'Adventure'": 377,
#  " u'Fantasy']": 296,
#  " u'Sci-Fi']": 462,
#  "[u'Drama'": 921,
#  " u'Romance']": 1011,
#  " u'Adventure']": 22,
#  " u'Adventure'": 677,
#  " u'Fantasy'": 419,
#  "[u'Western']": 18,
#  " u'Drama'": 1643,
#  " u'War']": 259,
#  "[u'Biography'": 256,
#  " u'History']": 74,
#  "[u'Mystery'": 55,
#  " u'Mystery']": 179,
#  " u'Biography'": 56,
#  " u'History'": 153,
#  "[u'Action']": 5,
#  " u'Comedy'": 601,
#  "[u'Animation'": 386,
#  " u'Romance'": 307,
#  " u'Family']": 144,
#  " u'Family'": 460,
#  " u'Musical']": 72,
#  "[u'Comedy'": 1434,
#  " u'Crime']": 124,
#  "[u'Comedy']": 319,
#  "[u'Horror']": 86,
#  " u'Horror']": 99,
#  "[u'Sci-Fi'": 24,
#  "[u'Horror'": 265,
#  " u'Sport']": 198,
#  " u'Action'": 107,
#  " u'Comedy']": 102,
#  " u'Horror'": 264,
#  "[u'Adventure']": 2,
#  " u'Thriller'": 78,
#  " u'Musical'": 87,
#  "[u'Family'": 10,
#  " u'Music']": 125,
#  " u'Western']": 94,
#  "[u'Fantasy'": 19,
#  " u'Music'": 86,
#  "[u'Romance'": 10,
#  "[u'Musical'": 5,
#  "[u'Sci-Fi']": 3,
#  " u'Western'": 2,
#  " u'Film-Noir']": 5,
#  "[u'Thriller']": 17,
#  "[u'Documentary']": 34,
#  " u'Film-Noir'": 24,
#  " u'War'": 9,
#  "[u'Film-Noir'": 4,
#  " u'Action']": 6,
#  "[u'Documentary'": 64,
#  " u'Talk-Show']": 5,
#  " u'Sport'": 7,
#  " u'Animation'": 6,
#  " u'Biography']": 3,
#  "[u'History'": 2,
#  "[u'Mystery']": 2,
#  '': 1,
#  "[u'Adult'": 1,
#  " u'News'": 2,
#  " u'Game-Show']": 2,
#  " u'Reality-TV']": 8,
#  " u'Reality-TV'": 2,
#  "[u'Music'": 1,
#  "[u'Game-Show'": 3,
#  "[u'Thriller'": 3,
#  "[u'Western'": 1,
#  " u'Game-Show'": 2,
#  " u'Animation']": 1,
#  "[u'Musical']": 1,
#  "[u'Romance']": 1,
#  "[u'Music']": 1,
#  "[u'Reality-TV']": 1,
#  " u'Documentary']": 1}

# %% [markdown]
# ### Exercise 1:
#
# import tv_shows.csv and find the 5 most recently made tv shows

# %%
import re
myList = []
with open("data/tv_shows.csv", 'r') as myFile:
    csvReader = csv.reader(myFile)
    # add to list
    # get list of tv shows and values
    # order from 0-5 index

    
    next(csvReader)

    for row in csvReader:
        myList.append(row)
myList
# Out:
# [['0',
#   'Game of Thrones',
#   '(2011 TV Series)',
#   '55 mins.',
#   '9.5',
#   '748,557',
#   "[u'Adventure', u'Drama', u'Fantasy']",
#   'Several noble families fight for control of the mythical land of Westeros.'],
#  ['1',
#   'Breaking Bad',
#   '(2008 TV Series)',
#   '45 mins.',
#   '9.5',
#   '662,459',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A chemistry teacher diagnosed with a terminal lung cancer, teams up with his former student, Jesse Pinkman, to cook and sell crystal meth.'],
#  ['2',
#   'The Walking Dead',
#   '(2010 TV Series)',
#   '44 mins.',
#   '8.7',
#   '500,301',
#   "[u'Drama', u'Horror']",
#   "Sheriff's Deputy Rick Grimes leads a group of survivors in a world overrun by zombies."],
#  ['3',
#   'The Big Bang Theory',
#   '(2007 TV Series)',
#   '22 mins.',
#   '8.5',
#   '438,226',
#   "[u'Comedy']",
#   'A woman who moves into an apartment across the hall from two brilliant but socially awkward physicists shows them how little they know about life outside of the laboratory.'],
#  ['4',
#   'Dexter',
#   '(2006 TV Series)',
#   '55 mins.',
#   '8.9',
#   '419,031',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A Miami police forensics expert moonlights as a serial killer of criminals whom he believes have escaped justice.'],
#  ['5',
#   'How I Met Your Mother',
#   '(2005 TV Series)',
#   '22 mins.',
#   '8.5',
#   '377,971',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'A father recounts to his children, through a series of flashbacks, the journey he and his four best friends took leading up to him meeting their mother.'],
#  ['6',
#   'Friends',
#   '(1994 TV Series)',
#   '22 mins.',
#   '9.0',
#   '365,611',
#   "[u'Comedy', u'Romance']",
#   'Follows the lives of six 20-something friends living in Manhattan.'],
#  ['7',
#   'Sherlock',
#   '(2010 TV Series)',
#   '90 mins.',
#   '9.3',
#   '365,419',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'A modern update finds the famous sleuth and his doctor partner solving crime in 21st century London.'],
#  ['8',
#   'Lost',
#   '(2004 TV Series)',
#   '44 mins.',
#   '8.5',
#   '317,981',
#   "[u'Adventure', u'Drama', u'Fantasy', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'The survivors of a plane crash are forced to work together in order to survive on a seemingly deserted tropical island.'],
#  ['9',
#   'Prison Break',
#   '(2005 TV Series)',
#   '44 mins.',
#   '8.6',
#   '259,384',
#   "[u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'Due to a political conspiracy an innocent man is sent to death row and his only hope is his brother who makes it his mission to deliberately get himself sent to the same prison in order to break the both of them out from the inside out.'],
#  ['10',
#   'House M.D.',
#   '(2004 TV Series)',
#   '44 mins.',
#   '8.9',
#   '253,142',
#   "[u'Drama', u'Mystery']",
#   'An antisocial maverick doctor who specializes in diagnostic medicine does whatever it takes to solve puzzling cases that come his way using his crack team of doctors and his wits.'],
#  ['11',
#   'Supernatural',
#   '(2005 TV Series)',
#   '44 mins.',
#   '8.7',
#   '232,424',
#   "[u'Drama', u'Fantasy', u'Horror', u'Mystery', u'Thriller']",
#   'Two brothers follow their father\'s footsteps as "hunters" fighting evil supernatural beings of many kinds including monsters, demons, and gods that roam the earth.'],
#  ['12',
#   'True Detective',
#   '(2014 TV Series)',
#   '55 mins.',
#   '9.3',
#   '223,407',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'An anthology police detective series in which investigations seem to unearth both personal and professional secrets of those involved, both within or outside the law.'],
#  ['13',
#   'Arrow',
#   '(2012 TV Series)',
#   '42 mins.',
#   '8.2',
#   '213,631',
#   "[u'Action', u'Adventure', u'Crime', u'Drama', u'Mystery', u'Sci-Fi']",
#   'Spoiled billionaire playboy Oliver Queen is missing and presumed dead when his yacht is lost at sea. He returns five years later a changed man, determined to clean up the city as a hooded vigilante armed with a bow.'],
#  ['14',
#   'The Simpsons',
#   '(1989 TV Series)',
#   '22 mins.',
#   '8.9',
#   '210,708',
#   "[u'Animation', u'Comedy']",
#   'The satiric adventures of a working-class family in the misfit city of Springfield.'],
#  ['15',
#   'House of Cards',
#   '(2013 TV Series)',
#   '55 mins.',
#   '9.1',
#   '203,278',
#   "[u'Drama']",
#   'A Congressman works with his equally conniving wife to exact revenge on the people who betrayed him.'],
#  ['16',
#   'Family Guy',
#   '(1999 TV Series)',
#   '22 mins.',
#   '8.4',
#   '202,732',
#   "[u'Animation', u'Comedy']",
#   'In a wacky Rhode Island town, a dysfunctional family strive to cope with everyday life as they are thrown from one crazy scenario to another.'],
#  ['17',
#   'Modern Family',
#   '(2009 TV Series)',
#   '22 mins.',
#   '8.6',
#   '193,819',
#   "[u'Comedy']",
#   'Three different, but related families face trials and tribulations in their own uniquely comedic ways.'],
#  ['18',
#   'South Park',
#   '(1997 TV Series)',
#   '22 mins.',
#   '8.8',
#   '193,282',
#   "[u'Animation', u'Comedy']",
#   'Follows the misadventures of four irreverent grade-schoolers in the quiet, dysfunctional town of South Park, Colorado.'],
#  ['19',
#   'True Blood',
#   '(2008 TV Series)',
#   '55 mins.',
#   '8.0',
#   '190,292',
#   "[u'Drama', u'Fantasy', u'Mystery', u'Romance', u'Thriller']",
#   'Telepathic waitress Sookie Stackhouse encounters a strange new supernatural world when she meets the mysterious Bill, a southern Louisiana gentleman and vampire.'],
#  ['20',
#   'The Vampire Diaries',
#   '(2009 TV Series)',
#   '43 mins.',
#   '8.0',
#   '186,601',
#   "[u'Drama', u'Fantasy', u'Horror', u'Mystery', u'Romance', u'Thriller']",
#   'A teenage girl is torn between two vampire brothers.'],
#  ['21',
#   'Homeland',
#   '(2011 TV Series)',
#   '55 mins.',
#   '8.5',
#   '182,903',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'When Marine Nicolas Brody is hailed as a hero after he returns home from eight years of captivity in Iraq, intelligence officer Carrie Mathison is the only one who suspects that he may have been "turned".'],
#  ['22',
#   'Suits',
#   '(2011 TV Series)',
#   '44 mins.',
#   '8.8',
#   '181,608',
#   "[u'Comedy', u'Drama']",
#   "On the run from a drug deal gone bad, Mike Ross, a brilliant college-dropout, finds himself a job working with Harvey Specter, one of New York City's best lawyers."],
#  ['23',
#   'Heroes',
#   '(2006 TV Series)',
#   '45 mins.',
#   '7.7',
#   '181,308',
#   "[u'Drama', u'Sci-Fi', u'Thriller']",
#   'The lives of common people, who discover they have superpowers, intertwine in order to save the world from different threats.'],
#  ['24',
#   'Arrested Development',
#   '(2003 TV Series)',
#   '22 mins.',
#   '9.1',
#   '180,399',
#   "[u'Comedy']",
#   'Level-headed son Michael Bluth takes over family affairs after his father is imprisoned. But the rest of his spoiled, dysfunctional family are making his job unbearable.'],
#  ['25',
#   'Two and a Half Men',
#   '(2003 TV Series)',
#   '22 mins.',
#   '7.2',
#   '173,194',
#   "[u'Comedy']",
#   "A hedonistic jingle writer's free-wheeling life comes to an abrupt halt when his brother and 10-year-old nephew move into his beach-front house."],
#  ['26',
#   'Scrubs',
#   '(2001 TV Series)',
#   '22 mins.',
#   '8.5',
#   '163,632',
#   "[u'Comedy', u'Drama']",
#   'In the unreal world of Sacred Heart Hospital, intern John "J.D" Dorian learns the ways of medicine, friendship and life.'],
#  ['27',
#   'The Office',
#   '(2005 TV Series)',
#   '22 mins.',
#   '8.8',
#   '161,733',
#   "[u'Comedy']",
#   'A mockumentary on a group of typical office workers, where the workday consists of ego clashes, inappropriate behavior, and tedium. Based on the hit BBC series.'],
#  ['28',
#   'Firefly',
#   '(2002 TV Series)',
#   '44 mins.',
#   '9.2',
#   '156,002',
#   "[u'Adventure', u'Drama', u'Sci-Fi']",
#   'Five hundred years in the future, a renegade crew aboard a small spacecraft tries to survive as they travel the unknown parts of the galaxy and evade warring factions as well as authority agents out to get them.'],
#  ['29',
#   'Fringe',
#   '(2008 TV Series)',
#   '60 mins.',
#   '8.5',
#   '154,733',
#   "[u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'A television drama centered around a female FBI agent who is forced to work with an institutionalized scientist in order to rationalize a brewing storm of unexplained phenomena.'],
#  ['30',
#   'American Horror Story',
#   '(2011 TV Series)',
#   '60 mins.',
#   '8.4',
#   '152,715',
#   "[u'Drama', u'Horror', u'Thriller']",
#   'An anthology series that centers on different characters and locations, including a haunted house, an insane asylum, a witch coven, a freak show and a hotel.'],
#  ['31',
#   'The Sopranos',
#   '(1999 TV Series)',
#   '55 mins.',
#   '9.3',
#   '151,341',
#   "[u'Crime', u'Drama']",
#   'New Jersey mob boss, Tony Soprano, deals with personal and professional issues in his home and business life.'],
#  ['32',
#   'The Wire',
#   '(2002 TV Series)',
#   '55 mins.',
#   '9.4',
#   '150,527',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'Baltimore drug scene, seen through the eyes of drug dealers, and law enforcement.'],
#  ['33',
#   'Spartacus: War of the Damned',
#   '(2010 TV Series)',
#   '55 mins.',
#   '8.7',
#   '147,077',
#   "[u'Action', u'Adventure', u'Biography', u'Drama', u'History']",
#   "Watch the story of history's greatest gladiator unfold with graphic violence and the passions of the women that love them. This is Spartacus."],
#  ['34',
#   'Sons of Anarchy',
#   '(2008 TV Series)',
#   '45 mins.',
#   '8.7',
#   '142,103',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A man in his early 30s struggles to find a balance in his life between being a new dad and his involvement in a motorcycle club.'],
#  ['35',
#   'Once Upon a Time',
#   '(2011 TV Series)',
#   '44 mins.',
#   '8.1',
#   '139,045',
#   "[u'Adventure', u'Fantasy', u'Romance']",
#   'A woman with a troubled past is drawn to a town in Maine where fairy tales are to be believed.'],
#  ['36',
#   'Seinfeld',
#   '(1989 TV Series)',
#   '22 mins.',
#   '9.0',
#   '138,356',
#   "[u'Comedy']",
#   'The continuing misadventures of neurotic New York stand-up comedian Jerry Seinfeld and his equally neurotic New York friends.'],
#  ['37',
#   'Grey&#x27;s Anatomy',
#   '(2005 TV Series)',
#   '41 mins.',
#   '7.7',
#   '134,407',
#   "[u'Drama', u'Romance']",
#   'A drama centered on the personal and professional lives of five surgical interns and their supervisors.'],
#  ['38',
#   'Californication',
#   '(2007 TV Series)',
#   '28 mins.',
#   '8.4',
#   '128,697',
#   "[u'Comedy', u'Drama']",
#   'A self-loathing, alcoholic writer attempts to repair his damaged relationships with his daughter and her mother while combating sex addiction, a budding drug problem, and the seeming inability to avoid making bad decisions.'],
#  ['39',
#   '24',
#   '(2001 TV Series)',
#   '44 mins.',
#   '8.5',
#   '128,282',
#   "[u'Action', u'Drama', u'Mystery', u'Thriller']",
#   'Jack Bauer, Director of Field Ops for the Counter-Terrorist Unit of Los Angeles, races against the clock to subvert terrorist plots and save his nation from ultimate disaster.'],
#  ['40',
#   'Orange Is the New Black',
#   '(2013 TV Series)',
#   '55 mins.',
#   '8.4',
#   '124,683',
#   "[u'Comedy', u'Crime', u'Drama']",
#   'The story of Piper Chapman, a woman in her thirties who is sentenced to fifteen months in prison after being convicted of a decade-old crime of transporting money for her drug-dealing girlfriend.'],
#  ['41',
#   'Doctor Who',
#   '(2005 TV Series)',
#   '45 mins.',
#   '8.9',
#   '122,209',
#   "[u'Adventure', u'Drama', u'Family', u'Mystery', u'Sci-Fi']",
#   'The further adventures of the time traveling alien adventurer and his companions.'],
#  ['42',
#   'Community',
#   '(2009 TV Series)',
#   '22 mins.',
#   '8.6',
#   '122,141',
#   "[u'Comedy']",
#   'A suspended lawyer is forced to enroll in a community college with an eclectic staff and student body.'],
#  ['43',
#   'Futurama',
#   '(1999 TV Series)',
#   '22 mins.',
#   '8.7',
#   '119,726',
#   "[u'Animation', u'Comedy', u'Sci-Fi']",
#   "Fry, a pizza guy is accidentally frozen in 1999 and thawed out New Year's Eve 2999."],
#  ['44',
#   'Vikings',
#   '(2013 TV Series)',
#   '44 mins.',
#   '8.6',
#   '118,757',
#   "[u'Action', u'Drama', u'History', u'War']",
#   "The adventures of Ragnar Lothbrok: the greatest hero of his age. The series tells the saga of Ragnar's..."],
#  ['45',
#   'Mad Men',
#   '(2007 TV Series)',
#   '45 mins.',
#   '8.7',
#   '117,210',
#   "[u'Drama']",
#   "A drama about one of New York's most prestigious ad agencies at the beginning of the 1960s, focusing on one of the firm's most mysterious but extremely talented ad executives, Donald Draper."],
#  ['46',
#   'The Mentalist',
#   '(2008 TV Series)',
#   '43 mins.',
#   '8.1',
#   '115,613',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A famous "psychic" outs himself as a fake and starts working as a consultant for the California Bureau of Investigation so he can find "Red John," the madman who killed his wife and daughter.'],
#  ['47',
#   'Boardwalk Empire',
#   '(2010 TV Series)',
#   '55 mins.',
#   '8.7',
#   '115,307',
#   "[u'Crime', u'Drama', u'History']",
#   'An Atlantic City politician plays both sides of the law, conspiring with gangsters during the Prohibition era.'],
#  ['48',
#   'New Girl',
#   '(2011 TV Series)',
#   '30 mins.',
#   '7.8',
#   '114,369',
#   "[u'Comedy']",
#   'After a bad break-up, Jess, an offbeat young woman, moves into an apartment loft with three single men. Although they find her behavior very unusual, the men support her - most of the time.'],
#  ['49',
#   'Entourage',
#   '(2004 TV Series)',
#   '28 mins.',
#   '8.6',
#   '114,150',
#   "[u'Comedy', u'Drama']",
#   'Film star Vince Chase navigates the vapid terrain of Los Angeles with a close circle of friends and his trusty agent.'],
#  ['50',
#   'Hannibal',
#   '(2013 TV Series)',
#   '44 mins.',
#   '8.6',
#   '113,254',
#   "[u'Crime', u'Drama', u'Horror', u'Thriller']",
#   'Explores the early relationship between the renowned psychiatrist and his patient, a young FBI criminal profiler, who is haunted by his ability to empathize with serial killers.'],
#  ['51',
#   'It&#x27;s Always Sunny in Philadelphia',
#   '(2005 TV Series)',
#   '22 mins.',
#   '8.8',
#   '110,691',
#   "[u'Comedy']",
#   'Four young friends with big egos and slightly arrogant attitudes are the proprietors of an Irish bar in Philadelphia.'],
#  ['52',
#   'Glee',
#   '(2009 TV Series)',
#   '44 mins.',
#   '6.8',
#   '109,456',
#   "[u'Comedy', u'Drama', u'Music', u'Musical']",
#   'A group of ambitious misfits try to escape the harsh realities of high school by joining a glee club, where they find strength, acceptance and, ultimately, their voice, while working to pursue dreams of their own.'],
#  ['53',
#   'The X-Files',
#   '(1993 TV Series)',
#   '44 mins.',
#   '8.8',
#   '106,676',
#   "[u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'Two FBI agents, Fox Mulder the believer and Dana Scully the skeptic, investigate the strange and unexplained while hidden forces work to impede their efforts.'],
#  ['54',
#   'Battlestar Galactica',
#   '(2004 TV Series)',
#   '44 mins.',
#   '8.8',
#   '104,676',
#   "[u'Action', u'Adventure', u'Drama', u'Sci-Fi']",
#   'When an old enemy, the Cylons, resurfaces and obliterate the 12 colonies, the crew of the aged Galactica protects a small civilian fleet - the last of humanity - as they journey toward the fabled 13th colony of Earth.'],
#  ['55',
#   'Castle',
#   '(2009 TV Series)',
#   '43 mins.',
#   '8.3',
#   '100,196',
#   "[u'Comedy', u'Crime', u'Drama', u'Mystery']",
#   'After a serial killer imitates the plots of his novels, successful mystery novelist Richard "Rick" Castle receives permission from the Mayor of New York City to tag along with an NYPD homicide investigation team for research purposes.'],
#  ['56',
#   'That &#x27;70s Show',
#   '(1998 TV Series)',
#   '22 mins.',
#   '8.1',
#   '99,830',
#   "[u'Comedy']",
#   'A comedy revolving around a group of teenage friends, their mishaps, and their coming of age, set in 1970s Wisconsin.'],
#  ['57',
#   'Avatar: The Last Airbender',
#   '(2005 TV Series)',
#   '23 mins.',
#   '9.2',
#   '98,829',
#   "[u'Animation', u'Action', u'Adventure', u'Family', u'Fantasy', u'Mystery']",
#   'In a war-torn world of elemental magic, a young boy reawakens to undertake a dangerous mystic quest to fulfill his destiny as the Avatar.'],
#  ['58',
#   'Chuck',
#   '(2007 TV Series)',
#   '43 mins.',
#   '8.3',
#   '98,206',
#   "[u'Action', u'Comedy', u'Drama']",
#   'When a twenty-something computer geek inadvertently downloads critical government secrets into his brain, CIA and NSA assign two agents to protect him and exploit such knowledge, turning his life upside down.'],
#  ['59',
#   'Gossip Girl',
#   '(2007 TV Series)',
#   '42 mins.',
#   '7.4',
#   '97,611',
#   "[u'Drama', u'Romance']",
#   'Privileged teens living on the Upper Eastside of New York City.'],
#  ['60',
#   'Bones',
#   '(2005 TV Series)',
#   '40 mins.',
#   '8.0',
#   '93,849',
#   "[u'Comedy', u'Crime', u'Drama', u'Mystery', u'Romance']",
#   "A forensic anthropologist and a cocky FBI agent build a team to investigate death causes. And quite often, there isn't more to examine than rotten flesh or mere bones."],
#  ['61',
#   'Person of Interest',
#   '(2011 TV Series)',
#   '43 mins.',
#   '8.5',
#   '93,133',
#   "[u'Action', u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   "An ex-assassin and a wealthy programmer save lives via a surveillance AI that sends them the identities of civilians involved in impending crimes. However, the details of the crimes--including the civilians' roles--are left a mystery."],
#  ['62',
#   'Rome',
#   '(2005 TV Series)',
#   '90 mins.',
#   '8.9',
#   '92,191',
#   "[u'Action', u'Drama', u'History', u'Romance', u'War']",
#   'A down-to-earth account of the lives of both illustrious and ordinary Romans set in the last days of the Roman Republic.'],
#  ['63',
#   'Criminal Minds',
#   '(2005 TV Series)',
#   '42 mins.',
#   '8.2',
#   '91,606',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   "The cases of the BAU, an elite group of profilers who analyze the nation's most dangerous criminal minds in an effort to anticipate their next moves before they strike again."],
#  ['64',
#   'Agents of S.H.I.E.L.D.',
#   '(2013 TV Series)',
#   '45 mins.',
#   '7.5',
#   '91,167',
#   "[u'Action', u'Drama', u'Sci-Fi']",
#   'The missions of the Strategic Homeland Intervention, Enforcement and Logistics Division.'],
#  ['65',
#   'Pretty Little Liars',
#   '(2010 TV Series)',
#   '60 mins.',
#   '7.9',
#   '90,552',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'Four friends band together against an anonymous foe who threatens to reveal their darkest secrets, while unraveling the mystery of the murder of their best friend.'],
#  ['66',
#   'Buffy the Vampire Slayer',
#   '(1997 TV Series)',
#   '44 mins.',
#   '8.2',
#   '89,507',
#   "[u'Action', u'Drama', u'Fantasy']",
#   'A young girl, destined to slay vampires, demons and other infernal creatures, deals with her life fighting evil, with the help of her friends.'],
#  ['67',
#   'Downton Abbey',
#   '(2010 TV Series)',
#   '65 mins.',
#   '8.8',
#   '89,222',
#   "[u'Drama', u'Romance']",
#   'A chronicle of the lives of the Crawley family and their servants, beginning in the years leading up to World War I.'],
#  ['68',
#   'Revenge',
#   '(2011 TV Series)',
#   '44 mins.',
#   '8.0',
#   '88,397',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'An emotionally troubled young woman makes it her mission to exact revenge against the people who wronged her father.'],
#  ['69',
#   'Fargo',
#   '(2014 TV Series)',
#   '53 mins.',
#   '9.0',
#   '87,925',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A drifter named Lorne Malvo arrives in small-town Minnesota and influences the population with his malice and violence, including put-upon insurance salesman Lester Nygaard.'],
#  ['70',
#   'Smallville',
#   '(2001 TV Series)',
#   '60 mins.',
#   '7.5',
#   '86,475',
#   "[u'Adventure', u'Drama', u'Romance', u'Sci-Fi']",
#   'A young Clark Kent struggles to find his place in the world as he learns to harness his alien powers for good and deals with the typical troubles of teenage life in Smallville.'],
#  ['71',
#   'Twin Peaks',
#   '(1990 TV Series)',
#   '47 mins.',
#   '9.0',
#   '86,213',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   'An idiosyncratic FBI agent investigates the murder of a young woman in the even more idiosyncratic town of Twin Peaks.'],
#  ['72',
#   'Parks and Recreation',
#   '(2009 TV Series)',
#   '22 mins.',
#   '8.6',
#   '84,962',
#   "[u'Comedy']",
#   "The absurd antics of an Indiana town's public officials as they pursue sundry projects to make their city a better place."],
#  ['73',
#   'Desperate Housewives',
#   '(2004 TV Series)',
#   '45 mins.',
#   '7.4',
#   '84,109',
#   "[u'Comedy', u'Drama', u'Mystery', u'Romance']",
#   'Secrets and truths unfold through the lives of female friends in one suburban neighborhood, after the mysterious suicide of a neighbor.'],
#  ['74',
#   'Malcolm in the Middle',
#   '(2000 TV Series)',
#   '30 mins.',
#   '8.0',
#   '82,896',
#   "[u'Comedy']",
#   'A gifted young teen tries to survive with his dimwitted, dysfunctional family.'],
#  ['75',
#   '30 Rock',
#   '(2006 TV Series)',
#   '22 mins.',
#   '8.3',
#   '82,369',
#   "[u'Comedy']",
#   'Liz Lemon, head writer of the sketch comedy show "TGS with Tracy Jordan", must deal with an arrogant new boss and a crazy new star, all while trying to run a successful TV show without losing her mind.'],
#  ['76',
#   'White Collar',
#   '(2009 TV Series)',
#   '40 mins.',
#   '8.3',
#   '78,798',
#   "[u'Comedy', u'Crime', u'Drama', u'Mystery']",
#   'A white collar criminal agrees to help the FBI catch other white collar criminals using his expertise as an art and securities thief, counterfeiter, and conman.'],
#  ['77',
#   'Weeds',
#   '(2005 TV Series)',
#   '30 mins.',
#   '8.1',
#   '78,601',
#   "[u'Comedy', u'Crime', u'Drama']",
#   'When a suburban mother turns to dealing marijuana in order to maintain her privileged lifestyle after her husband dies, she finds out just how addicted her entire neighborhood already is.'],
#  ['78',
#   'Lie to Me',
#   '(2009 TV Series)',
#   '43 mins.',
#   '8.0',
#   '78,285',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   "Dr. Cal Lightman teaches a course in body language and makes an honest fortune exploiting it. He's employed..."],
#  ['79',
#   'Six Feet Under',
#   '(2001 TV Series)',
#   '55 mins.',
#   '8.8',
#   '77,174',
#   "[u'Drama']",
#   'A drama series that takes a darkly comical look at members of a dysfunctional California family that runs an independent funeral home.'],
#  ['80',
#   'My Name Is Earl',
#   '(2005 TV Series)',
#   '30 mins.',
#   '7.8',
#   '76,180',
#   "[u'Comedy']",
#   "A ne'er do well wins $100,000 in the lottery and decides to right all the wrongs from his past with his newfound realization."],
#  ['81',
#   'The Fresh Prince of Bel-Air',
#   '(1990 TV Series)',
#   '22 mins.',
#   '8.0',
#   '75,975',
#   "[u'Comedy']",
#   'The Banks family, a respectable Californian family, take in a relative - Will Smith, a street-smart teenager from Philadelphia. The idea is to make him respectable, responsible and mature, but Will has got other plans...'],
#  ['82',
#   'Freaks and Geeks',
#   '(1999 TV Series)',
#   '44 mins.',
#   '9.0',
#   '75,505',
#   "[u'Comedy', u'Drama']",
#   "After her grandmother's death, a high school mathlete starts hanging out with a group of burnouts while her younger brother navigates his freshman year."],
#  ['83',
#   'The IT Crowd',
#   '(2006 TV Series)',
#   '25 mins.',
#   '8.6',
#   '74,985',
#   "[u'Comedy']",
#   'The comedic adventures of a rag-tag group of technical support workers at a large corporation.'],
#  ['84',
#   'Death Note',
#   '(2006 TV Series)',
#   '24 mins.',
#   '9.0',
#   '72,845',
#   "[u'Animation', u'Crime', u'Drama', u'Fantasy', u'Horror', u'Mystery', u'Thriller']",
#   'An intelligent high school student goes on a secret crusade to eliminate criminals from the world after discovering a notebook capable of killing anyone whose name is written into it.'],
#  ['85',
#   'Shameless',
#   '(2011 TV Series)',
#   '46 mins.',
#   '8.7',
#   '72,042',
#   "[u'Comedy', u'Drama']",
#   'An alcoholic man lives in a perpetual stupor while his six children with whom he lives cope as best they can.'],
#  ['86',
#   'NCIS',
#   '(2003 TV Series)',
#   '60 mins.',
#   '8.0',
#   '71,299',
#   "[u'Action', u'Comedy', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   "The cases of the Naval Criminal Investigative Service's Washington DC Major Case Response Team, led by Special Agent Leroy Jethro Gibbs."],
#  ['87',
#   'The Flash',
#   '(2014 TV Series)',
#   '43 mins.',
#   '8.2',
#   '71,276',
#   "[u'Action', u'Adventure', u'Drama', u'Fantasy', u'Sci-Fi']",
#   'Barry Allen wakes up 9 months after he was struck by lightning and discovers that the bolt gave him the power of super speed. With his new team and powers, Barry becomes "The Flash" and fights crime in Central City.'],
#  ['88',
#   'Sex and the City',
#   '(1998 TV Series)',
#   '30 mins.',
#   '6.9',
#   '69,620',
#   "[u'Comedy', u'Romance']",
#   'Four beautiful female New Yorkers gossip about their sex-lives (or lack thereof) and find new ways to deal with being a woman in the 90s.'],
#  ['89',
#   'Married with Children',
#   '(1987 TV Series)',
#   '22 mins.',
#   '8.1',
#   '69,074',
#   "[u'Comedy']",
#   "Al Bundy is a misanthropic women's shoe salesman with a miserable life. He hates his job, his wife is lazy, his son is dysfunctional (especially with women), and his daughter is dim-witted and promiscuous."],
#  ['90',
#   'The Blacklist',
#   '(2013 TV Series)',
#   '43 mins.',
#   '8.2',
#   '68,418',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A highly articulate, erudite and intelligent businessman and mastermind, "Red" Reddington, has allegedly...'],
#  ['91',
#   'Gotham',
#   '(2014 TV Series)',
#   '42 mins.',
#   '8.1',
#   '67,356',
#   "[u'Crime', u'Drama', u'Thriller']",
#   "The story behind Commissioner James Gordon's rise to prominence in Gotham City in the years before Batman's arrival."],
#  ['92',
#   'American Dad!',
#   '(2005 TV Series)',
#   '22 mins.',
#   '7.6',
#   '67,123',
#   "[u'Animation', u'Comedy']",
#   'The random escapades of Stan Smith, an extreme right wing CIA agent dealing with family life and keeping America safe, all in the most absurd way possible.'],
#  ['93',
#   'Grimm',
#   '(2011 TV Series)',
#   '45 mins.',
#   '7.8',
#   '66,724',
#   "[u'Drama', u'Fantasy', u'Horror', u'Mystery']",
#   'A homicide detective discovers he is a descendant of hunters who fight supernatural forces.'],
#  ['94',
#   'The Newsroom',
#   '(2012 TV Series)',
#   '55 mins.',
#   '8.7',
#   '66,060',
#   "[u'Drama']",
#   'A newsroom undergoes some changes in its workings and morals as a new team is brought in, bringing unexpected results for its existing news anchor.'],
#  ['95',
#   'Under the Dome',
#   '(2013 TV Series)',
#   '43 mins.',
#   '7.0',
#   '65,405',
#   "[u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'An invisible and mysterious force field descends upon a small fictional town in the United States, trapping residents inside, cut off from the rest of civilization. The trapped townsfolk must discover the secrets and purpose of the "dome" and its origins, while coming to learn more than they ever knew about each other.'],
#  ['96',
#   'Revolution',
#   '(2012 TV Series)',
#   '43 mins.',
#   '6.7',
#   '65,128',
#   "[u'Action', u'Adventure', u'Drama', u'Sci-Fi']",
#   'Fifteen years after a permanent global blackout, a group of revolutionaries seeks to drive out an occupying force posing as the United States Government.'],
#  ['97',
#   'Teen Wolf',
#   '(2011 TV Series)',
#   '41 mins.',
#   '7.8',
#   '64,802',
#   "[u'Comedy', u'Drama', u'Horror', u'Romance', u'Thriller']",
#   'A somewhat awkward teen is attacked by a werewolf and inherits the curse himself, as well as the enemies that come with it.'],
#  ['98',
#   'The Following',
#   '(2013 TV Series)',
#   '43 mins.',
#   '7.5',
#   '64,392',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A brilliant and charismatic, yet psychotic serial killer communicates with other active serial killers and activates a cult of believers following his every command.'],
#  ['99',
#   'Misfits',
#   '(2009 TV Series)',
#   '60 mins.',
#   '8.4',
#   '63,756',
#   "[u'Comedy', u'Drama', u'Fantasy', u'Sci-Fi']",
#   'A group of young offenders doing community service get struck by lightning during a storm, and begin to develop superpowers.'],
#  ['100',
#   'Terra Nova',
#   '(2011 TV Series)',
#   '46 mins.',
#   '6.8',
#   '63,664',
#   "[u'Adventure', u'Mystery', u'Sci-Fi']",
#   'Centers on the Shannons, an ordinary family from 2149 when the planet is dying who are transported back 85 million years to prehistoric Earth where they join Terra Nova, a colony of humans with a second chance to build a civilization.'],
#  ['101',
#   'Falling Skies',
#   '(2011 TV Series)',
#   '42 mins.',
#   '7.3',
#   '62,934',
#   "[u'Action', u'Sci-Fi', u'Thriller']",
#   'Survivors of an alien attack on earth gather together to fight for their lives and fight back.'],
#  ['102',
#   'CSI: Crime Scene Investigation',
#   '(2000 TV Series)',
#   '60 mins.',
#   '7.8',
#   '61,717',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'An elite team of police forensic evidence investigation experts work their cases in Las Vegas.'],
#  ['103',
#   'Archer',
#   '(2009 TV Series)',
#   '22 mins.',
#   '8.9',
#   '61,639',
#   "[u'Animation', u'Action', u'Comedy']",
#   'At ISIS, an international spy agency, global crises are merely opportunities for its highly trained employees to confuse, undermine, betray and royally screw each other.'],
#  ['104',
#   'Psych',
#   '(2006 TV Series)',
#   '44 mins.',
#   '8.4',
#   '60,423',
#   "[u'Comedy', u'Crime', u'Mystery']",
#   'A novice sleuth is hired by the police after he cons them into thinking he has psychic powers which help solve crimes. With the assistance of his reluctant best friend, the duo take on a series of complicated cases.'],
#  ['105',
#   'Leyla and Mecnun',
#   '(2011 TV Series)',
#   '80 mins.',
#   '9.2',
#   '60,243',
#   "[u'Adventure', u'Comedy', u'Drama', u'Fantasy', u'Mystery', u'Romance']",
#   'Turkish television comedy series set in Istanbul, Leyla and Mecnun is a surreal and absurd comedy that revolves around the fictional love story between Leyla and Mecnun.'],
#  ['106',
#   '2 Broke Girls',
#   '(2011 TV Series)',
#   '22 mins.',
#   '7.0',
#   '58,613',
#   "[u'Comedy']",
#   'Two young women waitressing at a greasy spoon diner strike up an unlikely friendship in the hopes of launching a successful business - if only they can raise the cash.'],
#  ['107',
#   'The O.C.',
#   '(2003 TV Series)',
#   '44 mins.',
#   '7.5',
#   '58,268',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'A troubled youth becomes embroiled in the lives of a close-knit group of people in the wealthy, upper-class neighborhood of Newport Beach, Orange County, California.'],
#  ['108',
#   'Top Gear',
#   '(2002 TV Series)',
#   '60 mins.',
#   '9.0',
#   '57,423',
#   "[u'Comedy', u'Talk-Show']",
#   "Jeremy, Richard and James talk about everything car-related. From new cars to how they're fueled, this show has it all."],
#  ['109',
#   'Better Call Saul',
#   '(2015 TV Series)',
#   '60 mins.',
#   '9.2',
#   '57,815',
#   "[u'Crime', u'Drama']",
#   'The trials and tribulations of criminal lawyer, Saul Goodman, in the time leading up to establishing his strip-mall law office in Albuquerque, New Mexico.'],
#  ['110',
#   'Elementary',
#   '(2012 TV Series)',
#   '60 mins.',
#   '8.0',
#   '55,984',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'A modern take on the cases of Sherlock Holmes, with the detective now living in New York City.'],
#  ['111',
#   'The Killing',
#   '(2011 TV Series)',
#   '45 mins.',
#   '8.2',
#   '55,911',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A police investigation, the saga of a grieving family, and a Seattle mayoral campaign all interlock after the body of 17-year-old Rosie Larsen is found in the trunk of a submerged car.'],
#  ['112',
#   'Dragon Ball Z',
#   '(1996 TV Series)',
#   '24 mins.',
#   '8.9',
#   '55,784',
#   "[u'Animation', u'Action', u'Adventure', u'Fantasy', u'Sci-Fi', u'Thriller']",
#   'After learning that he is from another planet, a warrior named Goku and his friends are prompted to defend it from an onslaught of extraterrestrial enemies.'],
#  ['113',
#   'Curb Your Enthusiasm',
#   '(1999 TV Series)',
#   '28 mins.',
#   '8.8',
#   '55,734',
#   "[u'Comedy']",
#   'The life and times of Larry David and the predicaments he gets himself in with his friends and complete strangers.'],
#  ['114',
#   'Oz',
#   '(1997 TV Series)',
#   '55 mins.',
#   '8.9',
#   '55,305',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'A series chronicling the daily activities of an unusual prison facility and its criminal inhabitants.'],
#  ['115',
#   'The Office',
#   '(2001 TV Series)',
#   '30 mins.',
#   '8.7',
#   '54,959',
#   "[u'Comedy', u'Drama']",
#   'The story of an office that faces closure when the company decides to downsize its branches. A documentary film crew follow staff and the manager Brent as they continue their daily lives.'],
#  ['116',
#   'Burn Notice',
#   '(2007 TV Series)',
#   '44 mins.',
#   '8.0',
#   '54,436',
#   "[u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A spy recently disavowed by the U.S. government uses his special ops training to help others in trouble.'],
#  ['117',
#   'Deadwood',
#   '(2004 TV Series)',
#   '55 mins.',
#   '8.8',
#   '53,288',
#   "[u'Crime', u'Drama', u'History', u'Western']",
#   'A show set in the late 1800s, revolving around the characters of Deadwood, South Dakota; a town of deep corruption and crime.'],
#  ['118',
#   'Stargate SG-1',
#   '(1997 TV Series)',
#   '44 mins.',
#   '8.5',
#   '53,234',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'A secret military team, SG-1, is formed to explore the recently discovered Stargates.'],
#  ['119',
#   'Justified',
#   '(2010 TV Series)',
#   '44 mins.',
#   '8.7',
#   '53,199',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'Old-school U.S. Marshal Raylan Givens is reassigned from Miami to his childhood home in the poor, rural coal-mining towns in Eastern Kentucky.'],
#  ['120',
#   'The King of Queens',
#   '(1998 TV Series)',
#   '22 mins.',
#   '7.4',
#   '52,913',
#   "[u'Comedy']",
#   "Delivery man Doug Heffernan has a good life: He's got a pretty wife (Carrie), a big TV and friends to watch it with. Then Carrie's goofy and annoying father Arthur moves in with them."],
#  ['121',
#   'The Legend of Korra',
#   '(2012 TV Series)',
#   '23 mins.',
#   '8.7',
#   '52,399',
#   "[u'Animation', u'Action', u'Adventure', u'Drama', u'Family', u'Fantasy']",
#   'Avatar Korra fights to keep Republic City safe from the evil forces of both the physical and spiritual worlds.'],
#  ['122',
#   'Gilmore Girls',
#   '(2000 TV Series)',
#   '44 mins.',
#   '8.0',
#   '52,065',
#   "[u'Comedy', u'Drama']",
#   'A drama centering around the relationship between a thirtysomething single mother and her teen daughter living in Stars Hollow, Connecticut.'],
#  ['123',
#   'Skins',
#   '(2007 TV Series)',
#   '46 mins.',
#   '8.2',
#   '52,018',
#   "[u'Drama']",
#   'The story of a group of British teens who are trying to grow up and find love and happiness despite questionable parenting and teachers who more want to be friends (and lovers) rather than authority figures.'],
#  ['124',
#   'Star Trek: The Next Generation',
#   '(1987 TV Series)',
#   '44 mins.',
#   '8.7',
#   '51,752',
#   "[u'Action', u'Adventure', u'Mystery', u'Sci-Fi']",
#   "Set decades after Captain James T. Kirk's 5-year mission, a new generation of Starfleet officers in a new Enterprise set off on their own mission to go where no one has gone before."],
#  ['125',
#   'FlashForward',
#   '(2009 TV Series)',
#   '60 mins.',
#   '7.6',
#   '51,517',
#   "[u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'A special task force in the FBI investigates after every person on Earth simultaneously blackouts and awakens with a short vision of their future.'],
#  ['126',
#   'Veronica Mars',
#   '(2004 TV Series)',
#   '60 mins.',
#   '8.4',
#   '50,981',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'After her best friend is murdered and her father is removed as county sheriff, Veronica Mars dedicates her life to cracking the toughest mysteries in the affluent town of Neptune.'],
#  ['127',
#   'The Originals',
#   '(2013 TV Series)',
#   '45 mins.',
#   '8.5',
#   '50,959',
#   "[u'Drama', u'Fantasy', u'Horror', u'Mystery']",
#   "Many years ago, an original family of vampires lived in the city of New Orleans where they lived happily. However, all has changed and it's up to them to take back what they built."],
#  ['128',
#   'One Tree Hill',
#   '(2003 TV Series)',
#   '60 mins.',
#   '7.7',
#   '50,252',
#   "[u'Drama', u'Sport']",
#   'This series follows the eventful lives of some high-school kids in Tree Hill, a small but not too quiet town in North Carolina, where the greatest source of pride is the high school basketball team, the Ravens,'],
#  ['129',
#   'Merlin',
#   '(2008 TV Series)',
#   '45 mins.',
#   '7.9',
#   '49,550',
#   "[u'Adventure', u'Drama', u'Family', u'Fantasy']",
#   'The adventures of the legendary sorcerer as a young man.'],
#  ['130',
#   'Luther',
#   '(2010 TV Series)',
#   '60 mins.',
#   '8.6',
#   '49,134',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'A crime drama series starring '],
#  ['131',
#   'Frasier',
#   '(1993 TV Series)',
#   '60 mins.',
#   '8.0',
#   '48,821',
#   "[u'Comedy']",
#   'Dr. Frasier Crane moves back to his hometown of Seattle where he lives with his father and works as a radio psychiatrist.'],
#  ['132',
#   'SpongeBob SquarePants',
#   '(1999 TV Series)',
#   '30 mins.',
#   '8.1',
#   '48,519',
#   "[u'Animation', u'Comedy', u'Family', u'Fantasy']",
#   'The misadventures of a fast-food restaurant working sponge who lives under the sea.'],
#  ['133',
#   'Charmed',
#   '(1998 TV Series)',
#   '42 mins.',
#   '7.1',
#   '48,215',
#   "[u'Drama', u'Fantasy', u'Mystery']",
#   'Three sisters discover their destiny - to battle against the forces of evil, using their witchcraft. They are the Charmed Ones.'],
#  ['134',
#   'Terminator: The Sarah Connor Chronicles',
#   '(2008 TV Series)',
#   '60 mins.',
#   '7.7',
#   '48,086',
#   "[u'Action', u'Drama', u'Sci-Fi', u'Thriller']",
#   'Set after the events in '],
#  ['135',
#   'The 100',
#   '(2014 TV Series)',
#   '43 mins.',
#   '7.8',
#   '47,995',
#   "[u'Drama', u'Sci-Fi']",
#   "Set 97 years after a nuclear war has destroyed civilization, when a spaceship housing humanity's lone survivors sends 100 juvenile delinquents back to Earth in hopes of possibly re-populating the planet."],
#  ['136',
#   'Da Vinci&#x27;s Demons',
#   '(2013 TV Series)',
#   '59 mins.',
#   '8.1',
#   '47,625',
#   "[u'Adventure', u'Drama', u'Fantasy', u'History', u'Mystery']",
#   'Written by '],
#  ['137',
#   'The Shield',
#   '(2002 TV Series)',
#   '47 mins.',
#   '8.8',
#   '46,550',
#   "[u'Crime', u'Drama', u'Thriller']",
#   "The story of an inner-city Los Angeles police precinct where some of the cops aren't above breaking..."],
#  ['138',
#   'Monk',
#   '(2002 TV Series)',
#   '47 mins.',
#   '8.0',
#   '45,981',
#   "[u'Comedy', u'Crime', u'Drama', u'Mystery']",
#   'Adrian Monk is a brilliant San Francisco detective, whose obsessive compulsive disorder just happens to get in the way.'],
#  ['139',
#   'Louie',
#   '(2010 TV Series)',
#   '22 mins.',
#   '8.7',
#   '45,440',
#   "[u'Comedy', u'Drama']",
#   'The life of Louis CK, a divorced comedian with two kids living in New York.'],
#  ['140',
#   'Angel',
#   '(1999 TV Series)',
#   '44 mins.',
#   '8.0',
#   '45,285',
#   "[u'Action', u'Drama', u'Fantasy', u'Thriller']",
#   'The vampire Angel, cursed with a soul, moves to Los Angeles and aids people with supernatural-related problems while questing for his own redemption.'],
#  ['141',
#   'Fawlty Towers',
#   '(1975 TV Series)',
#   '30 mins.',
#   '8.9',
#   '45,011',
#   "[u'Comedy']",
#   "Hotel owner Basil Fawlty's incompetence, short fuse, and arrogance form a combination that ensures accidents and trouble are never far away."],
#  ['142',
#   'Nip/Tuck',
#   '(2003 TV Series)',
#   '44 mins.',
#   '7.7',
#   '44,816',
#   "[u'Drama']",
#   'Two plastic surgeons - one a dedicated family man and one an unscrupulous playboy - strive to maintain their business whilst having to face numerous hardships ranging from personal relationships to clients with criminal connections.'],
#  ['143',
#   'Law &#x26; Order: Special Victims Unit',
#   '(1999 TV Series)',
#   '60 mins.',
#   '8.1',
#   '44,646',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'This show introduces the Special Victims Unit, a new elite squad of NYPD detectives who investigate sexually related crimes.'],
#  ['144',
#   'The Tudors',
#   '(2007 TV Series)',
#   '60 mins.',
#   '8.1',
#   '44,295',
#   "[u'Drama', u'History', u'Romance', u'War']",
#   'A dramatic series about the reign and marriages of King Henry VIII.'],
#  ['145',
#   'The Inbetweeners',
#   '(2008 TV Series)',
#   '25 mins.',
#   '8.5',
#   '44,196',
#   "[u'Comedy']",
#   'The exploits of four friends, who are socially only marginally above what one of them calls "the freaks"...'],
#  ['146',
#   'Jericho',
#   '(2006 TV Series)',
#   '45 mins.',
#   '8.0',
#   '44,165',
#   "[u'Action', u'Drama', u'Mystery', u'Sci-Fi']",
#   'A small town in Kansas is literally left in the dark after seeing a mushroom cloud over near-by Denver, Colorado. The townspeople struggle to find answers about the blast and solutions on how to survive.'],
#  ['147',
#   'Everybody Loves Raymond',
#   '(1996 TV Series)',
#   '22 mins.',
#   '7.1',
#   '44,031',
#   "[u'Comedy']",
#   'The comical everyday life of a successful sports columnist and his dysfunctional family.'],
#  ['148',
#   'Mr. Bean',
#   '(1990 TV Series)',
#   '350 mins.',
#   '8.6',
#   '43,740',
#   "[u'Comedy', u'Family']",
#   'Life is a difficult challenge for Mr Bean, who despite being a grown adult, has trouble completing even the simplest of tasks. Thankfully, his perseverence is usually rewarded, and he finds an ingenious way around the problem.'],
#  ['149',
#   'Stargate: Atlantis',
#   '(2004 TV Series)',
#   '45 mins.',
#   '8.1',
#   '43,069',
#   "[u'Action', u'Drama', u'Sci-Fi', u'Adventure']",
#   'An international team of scientists and military personnel discover a Stargate network in the Pegasus Galaxy and come face-to-face with a new, powerful enemy, The Wraith.'],
#  ['150',
#   'Bates Motel',
#   '(2013 TV Series)',
#   '45 mins.',
#   '8.2',
#   '42,922',
#   "[u'Drama', u'Mystery', u'Thriller']",
#   '"Bates Motel" is a contemporary prequel to the genre-defining film "Psycho," and gives a portrayal of...'],
#  ['151',
#   'V',
#   '(2009 TV Series)',
#   '42 mins.',
#   '6.9',
#   '42,530',
#   "[u'Drama', u'Sci-Fi', u'Thriller']",
#   'An extraterrestrial race arrives on Earth with seemingly good intentions, only to slowly reveal their true machinations the more ingrained into society they become.'],
#  ['152',
#   'Orphan Black',
#   '(2013 TV Series)',
#   '44 mins.',
#   '8.5',
#   '41,771',
#   "[u'Action', u'Drama', u'Sci-Fi']",
#   'A streetwise hustler is pulled into a compelling conspiracy after witnessing the suicide of a girl who looks just like her.'],
#  ['153',
#   'Girls',
#   '(2012 TV Series)',
#   '30 mins.',
#   '7.4',
#   '41,214',
#   "[u'Comedy', u'Drama']",
#   'A comedy about the experiences of a group of girls in their early 20s.'],
#  ['154',
#   'Penny Dreadful',
#   '(2014 TV Series)',
#   '60 mins.',
#   '8.2',
#   '40,024',
#   "[u'Drama', u'Horror']",
#   'Explorer Sir Malcolm Murray, American gunslinger Ethan Chandler, and others unite to combat supernatural threats in Victorian London.'],
#  ['155',
#   'Pushing Daisies',
#   '(2007 TV Series)',
#   '44 mins.',
#   '8.5',
#   '39,659',
#   "[u'Comedy', u'Drama', u'Fantasy', u'Mystery', u'Romance']",
#   'A pie-maker, with the power to bring dead people back to life, solves murder mysteries with his alive-again childhood sweetheart, a cynical private investigator, and a lovesick waitress.'],
#  ['156',
#   'CSI: Miami',
#   '(2002 TV Series)',
#   '43 mins.',
#   '6.4',
#   '39,473',
#   "[u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   "The cases of the Miami-Dade, Florida police department's Crime Scene Investigations unit."],
#  ['157',
#   'Batman: The Animated Series',
#   '(1992 TV Series)',
#   '23 mins.',
#   '9.0',
#   '39,460',
#   "[u'Animation', u'Action', u'Adventure', u'Crime', u'Drama', u'Fantasy', u'Mystery', u'Romance', u'Sci-Fi', u'Thriller']",
#   'The Dark Knight battles crime in Gotham City with occasional help from Robin and Batgirl.'],
#  ['158',
#   'Scandal',
#   '(2012 TV Series)',
#   '43 mins.',
#   '8.0',
#   '39,363',
#   "[u'Drama', u'Thriller']",
#   'A former White House Communications Director starts her own crisis management firm only to realize her clients are not the only ones with secrets.'],
#  ['159',
#   'Sleepy Hollow',
#   '(2013 TV Series)',
#   '45 mins.',
#   '7.7',
#   '39,266',
#   "[u'Adventure', u'Drama', u'Fantasy', u'Mystery', u'Thriller']",
#   'Ichabod Crane is resurrected and pulled two and a half centuries through time to unravel a mystery that dates all the way back to the founding fathers.'],
#  ['160',
#   'The Good Wife',
#   '(2009 TV Series)',
#   '60 mins.',
#   '8.3',
#   '39,083',
#   "[u'Crime', u'Drama', u'Mystery']",
#   "Alicia has been a good wife to her husband, a former state's attorney. After a very humiliating sex and corruption scandal, he is behind bars. She must now provide for her family and returns to work as a litigator in a law firm."],
#  ['161',
#   'Nikita',
#   '(2010 TV Series)',
#   '60 mins.',
#   '7.7',
#   '38,985',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'A rogue assassin returns to take down the secret organization that trained her.'],
#  ['162',
#   'Continuum',
#   '(2012 TV Series)',
#   '45 mins.',
#   '7.8',
#   '38,910',
#   "[u'Action', u'Sci-Fi', u'Thriller']",
#   'A detective from the year 2077 finds herself trapped in present day Vancouver and searching for ruthless criminals from the future.'],
#  ['163',
#   'Cowboy Bebop',
#   '(1998 TV Series)',
#   '24 mins.',
#   '9.0',
#   '38,908',
#   "[u'Animation', u'Action', u'Adventure', u'Drama', u'Sci-Fi', u'Thriller']",
#   'The futuristic misadventures and tragedies of an easygoing bounty hunter and his partners.'],
#  ['164',
#   'Star Trek',
#   '(1966 TV Series)',
#   '4050 mins.',
#   '8.4',
#   '38,818',
#   "[u'Action', u'Adventure', u'Sci-Fi']",
#   'Captain James T. Kirk and the crew of the Starship Enterprise explore the Galaxy and defend the United Federation of Planets.'],
#  ['165',
#   'Hawaii Five-0',
#   '(2010 TV Series)',
#   '42 mins.',
#   '7.4',
#   '38,749',
#   "[u'Action', u'Crime', u'Drama']",
#   'Steve McGarrett returns home to Oahu, in order to find his father\'s killer. The governor offers him the chance to run his own task force (Five-0). Steve\'s team is joined by Chin Ho Kelly, Danny "Danno" Williams, and Kono Kalakaua.'],
#  ['166',
#   'Brooklyn Nine-Nine',
#   '(2013 TV Series)',
#   '22 mins.',
#   '8.3',
#   '38,640',
#   "[u'Comedy', u'Crime']",
#   "Jake Peralta, an immature but talented NYPD detective in Brooklyn's 99th Precinct, comes into immediate conflict with his new commanding officer, the serious and stern Captain Ray Holt."],
#  ['167',
#   'Eastbound &#x26; Down',
#   '(2009 TV Series)',
#   '28 mins.',
#   '8.3',
#   '38,055',
#   "[u'Comedy', u'Drama', u'Sport']",
#   'Years after he turned his back on his hometown, a burned-out major league ballplayer returns to teach phys ed at his old middle school.'],
#  ['168',
#   'Dollhouse',
#   '(2009 TV Series)',
#   '44 mins.',
#   '7.8',
#   '36,479',
#   "[u'Drama', u'Mystery', u'Sci-Fi', u'Thriller']",
#   'A futuristic laboratory assigns different tasks to its various residents, who then have their memories erased upon the completion of their assignments.'],
#  ['169',
#   'ER',
#   '(1994 TV Series)',
#   '44 mins.',
#   '7.7',
#   '36,162',
#   "[u'Drama']",
#   'The work and lives of a group of emergency room doctors in Chicago.'],
#  ['170',
#   'The West Wing',
#   '(1999 TV Series)',
#   '44 mins.',
#   '8.8',
#   '36,133',
#   "[u'Drama']",
#   'Inside the lives of staffers in the west wing of the White House.'],
#  ['171',
#   'Banshee',
#   '(2013 TV Series)',
#   '60 mins.',
#   '8.4',
#   '35,966',
#   "[u'Action', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'Lucas Hood (Antony Starr), an ex-con and master thief assumes the identity of a murdered sheriff where he continues his criminal activities...'],
#  ['172',
#   'Touch',
#   '(2012 TV Series)',
#   '43 mins.',
#   '7.4',
#   '35,863',
#   "[u'Drama', u'Mystery', u'Sci-Fi']",
#   'A widower struggling to raise his emotionally challenged son discovers that he can predict events before they happen.'],
#  ['173',
#   'Eureka',
#   '(2006 TV Series)',
#   '60 mins.',
#   '7.9',
#   '35,859',
#   "[u'Comedy', u'Drama', u'Sci-Fi']",
#   "The best minds in the US are tucked away in a remote town where they build futuristic inventions for the government's benefit."],
#  ['174',
#   'Flight of the Conchords',
#   '(2007 TV Series)',
#   '28 mins.',
#   '8.7',
#   '35,770',
#   "[u'Comedy', u'Music']",
#   'Bret and Jemaine are Flight of the Conchords, a folk-rock band from New Zealand living in New York City in search of stardom.'],
#  ['175',
#   'Attack on Titan',
#   '(2013 TV Series)',
#   '24 mins.',
#   '9.0',
#   '35,788',
#   "[u'Animation', u'Action', u'Adventure', u'Drama', u'Fantasy', u'Horror']",
# ...
#   '7 mins.',
#   '8.5',
#   '4,728',
#   "[u'Animation', u'Comedy', u'Family']",
#   "Shaun is a sheep who doesn't follow the flock - in fact, he leads them into all sorts of scrapes and scraps..."],
#  ['941',
#   'Taz-Mania',
#   '(1991 TV Series)',
#   '30 mins.',
#   '7.0',
#   '4,718',
#   "[u'Animation', u'Comedy', u'Family', u'Sci-Fi']",
#   'The daily satirical adventures of the Looney Tunes star The Tazmanian Devil, along with his extended family, friends, and enemies on the island of Tasmania.'],
#  ['942',
#   'The League of Gentlemen',
#   '(1999 TV Series)',
#   '60 mins.',
#   '8.6',
#   '4,719',
#   "[u'Comedy', u'Horror']",
#   'An interweaving narrative chronicling the antics of such diverse characters as: a transsexual taxi driver, a family obsessed with hygiene and toads, a fiery reverend, a carnival owner who kidnaps women into marriage, and a xenophobic couple who run a local shop for local people.'],
#  ['943',
#   'Adventures of the Gummi Bears',
#   '(1985 TV Series)',
#   '30 mins.',
#   '7.7',
#   '4,712',
#   "[u'Fantasy', u'Animation', u'Family']",
#   'A group of reclusive humanoid bears and a few trusted humans explore their lost heritage and prevent their enemies from exploiting it.'],
#  ['944',
#   'Paranoia Agent',
#   '(2004 TV Series)',
#   '30 mins.',
#   '8.2',
#   '4,711',
#   "[u'Animation', u'Drama', u'Horror', u'Mystery']",
#   "Seemingly unconnected citizens of Tokyo are targeted for bludgeoning by a boy with a golden baseball bat. As detectives try to link the victims, they discover that following the assaults, the victims' lives have improved in some way."],
#  ['945',
#   'Mozart in the Jungle',
#   '(2014 TV Series)',
#   '29 mins.',
#   '8.2',
#   '4,716',
#   "[u'Comedy']",
#   'Sex, drugs and classical music illustrate what happens behind the curtains at the symphony can be just as captivating as what occurs on stage.'],
#  ['946',
#   'Yes Minister',
#   '(1980 TV Series)',
#   '60 mins.',
#   '8.8',
#   '4,707',
#   "[u'Comedy']",
#   'The Right Honorable James Hacker has landed the plum job of Cabinet Minister to the Department of Administration. At last he is in a position of power and can carry out some long-needed reforms - or so he thinks.'],
#  ['947',
#   'Spawn',
#   '(1997 TV Series)',
#   '144 mins.',
#   '8.1',
#   '4,704',
#   "[u'Animation', u'Action', u'Crime', u'Drama', u'Fantasy', u'Horror', u'Thriller']",
#   'Spawn goes after his killer, the head of the top secret agency for which he formerly worked.'],
#  ['948',
#   'The Nostalgia Critic',
#   '(2007 TV Series)',
#   '',
#   '8.7',
#   '4,679',
#   "[u'Comedy']",
#   'A film critic, raised on pop culture reviews films and television shows from his childhood, often feels betrayed by how poorly they hold up.'],
#  ['949',
#   'Sleeper Cell',
#   '(2005 TV Series)',
#   '60 mins.',
#   '8.2',
#   '4,673',
#   "[u'Crime', u'Drama', u'Thriller']",
#   'An American undercover FBI agent is assigned to infiltrate a terrorist sleeper cell that is planning an attack in Los Angeles.'],
#  ['950',
#   'Dilbert',
#   '(1999 TV Series)',
#   '30 mins.',
#   '7.3',
#   '4,660',
#   "[u'Animation', u'Comedy']",
#   'Cubicle denizen Dilbert toils away at Path-E-Tech which makes undefined products. The focus is on his survival amongst a moronic boss, hostile co-workers and his malevolent pet, Dogbert.'],
#  ['951',
#   'Gang Related',
#   '(2014 TV Series)',
#   '46 mins.',
#   '7.6',
#   '4,660',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'Every villain has a noble cause, and every hero has a dark side. In the gritty new action-drama GANG RELATED...'],
#  ['952',
#   'Detective Conan',
#   '(1996 TV Series)',
#   '30 mins.',
#   '8.5',
#   '4,647',
#   "[u'Animation', u'Comedy', u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'The cases of a detective whose physical age was chemically reversed to that of a prepubescent boy but must hide his true mental development.'],
#  ['953',
#   'All That',
#   '(1994 TV Series)',
#   '30 mins.',
#   '7.5',
#   '4,645',
#   "[u'Comedy', u'Music']",
#   'A combination sketch comedy/musical performance show in the tradition of "Saturday Night Live," this...'],
#  ['954',
#   'Ben 10',
#   '(2005 TV Series)',
#   '30 mins.',
#   '7.0',
#   '4,641',
#   "[u'Animation', u'Action', u'Adventure', u'Family', u'Sci-Fi']",
#   'The story of Ben Tennyson, a typical kid who becomes very atypical after he discovers the Omnitrix, a mysterious alien device with the power to transform the wearer into ten different alien species.'],
#  ['955',
#   'Titus',
#   '(2000 TV Series)',
#   '23 mins.',
#   '7.6',
#   '4,626',
#   "[u'Comedy', u'Drama']",
#   'A mechanic, Christopher Titus, along with his brother and his friends, try to deal with his father, a lewd, crude, drinking multiple divorcee.'],
#  ['956',
#   'Transporter: The Series',
#   '(2012 TV Series)',
#   '48 mins.',
#   '6.7',
#   '4,624',
#   "[u'Action', u'Crime']",
#   'Frank Martin is an ex special ops, who now spends his life as a transporter on the other side of the law. With three rules, he always completes his contracts. One way, or the other.'],
#  ['957',
#   'Jonas',
#   '(2009 TV Series)',
#   '25 mins.',
#   '4.4',
#   '4,616',
#   "[u'Comedy', u'Family', u'Music']",
#   'The show follows the Jonas Brothers through fun and unusual situations as they try to live ordinary lives...'],
#  ['958',
#   'The Dick Van Dyke Show',
#   '(1961 TV Series)',
#   '30 mins.',
#   '8.5',
#   '4,577',
#   "[u'Comedy', u'Family']",
#   'The misadventures of a TV writer both at work and at home.'],
#  ['959',
#   'Phil of the Future',
#   '(2004 TV Series)',
#   '25 mins.',
#   '7.3',
#   '4,561',
#   "[u'Adventure', u'Comedy', u'Family', u'Sci-Fi']",
#   'A family from 2121 is stuck in 2004, trying desperately to fit in.'],
#  ['960',
#   'Teenage Mutant Ninja Turtles',
#   '(2012 TV Series)',
#   '24 mins.',
#   '8.3',
#   '4,553',
#   "[u'Animation', u'Action', u'Adventure', u'Comedy', u'Family', u'Sci-Fi']",
#   'Four ninja turtles, mutated by a mysterious alien substance, must rise up out of the sewers and defend their city against evil forces from both the past and present.'],
#  ['961',
#   'Skins',
#   '(2011 TV Series)',
#   '42 mins.',
#   '3.9',
#   '4,541',
#   "[u'Comedy', u'Drama']",
#   'About a group of teenagers in their final years of high school in Baltimore.'],
#  ['962',
#   'WWF Raw',
#   '(1993 TV Series)',
#   '60 mins.',
#   '8.0',
#   '4,541',
#   "[u'Sport']",
#   'The best of the World wrestling federation battle it out every week. In the squared circle, to see just who is the best of the best'],
#  ['963',
#   'The Firm',
#   '(2012 TV Series)',
#   '60 mins.',
#   '7.1',
#   '4,538',
#   "[u'Action', u'Drama', u'Mystery', u'Thriller']",
#   'Defense Attorney Mitch McDeere is targeted for execution by the Chicago Mob in retaliation for bringing down a profitable Mob-operated Memphis law firm ten years earlier.'],
#  ['964',
#   'British Men Behaving Badly',
#   '(1992 TV Series)',
#   '45 mins.',
#   '7.8',
#   '4,542',
#   "[u'Comedy']",
#   'This comedy series is all about two mates, Gary and Tony who share a two bedroom home. They are grown men who act like a couple of drunk two year olds...'],
#  ['965',
#   'Zero Hour',
#   '(2013 TV Series)',
#   '60 mins.',
#   '6.4',
#   '4,535',
#   "[u'Drama', u'Fantasy', u'Thriller']",
#   "Revolves around a bizarre twist of fate that pulls a man who's spent 20 years as the editor of a skeptics magazine into one of the most compelling conspiracies in human history."],
#  ['966',
#   'Wire in the Blood',
#   '(2002 TV Series)',
#   '69 mins.',
#   '8.4',
#   '4,527',
#   "[u'Crime', u'Drama', u'Mystery', u'Thriller']",
#   'A psychologist gets inside of the minds of both killers and victims to aid the police in solving gruesome serial killings in Northern England.'],
#  ['967',
#   'Low Winter Sun',
#   '(2013 TV Series)',
#   '43 mins.',
#   '7.1',
#   '4,507',
#   "[u'Crime', u'Drama']",
#   'Murder, deception, revenge and corruption that starts with the murder of a cop by fellow Detroit detective, Frank Agnew.'],
#  ['968',
#   'Bonanza',
#   '(1959 TV Series)',
#   '49 mins.',
#   '7.4',
#   '4,506',
#   "[u'Western']",
#   'The adventures of Ben Cartwright and his sons as they run and defend their ranch while helping the surrounding community.'],
#  ['969',
#   'The Fades',
#   '(2010 TV Series)',
#   '55 mins.',
#   '7.9',
#   '4,501',
#   "[u'Fantasy', u'Horror']",
#   "A teenage boy named Paul is haunted by apocalyptic dreams that nobody can explain. As if that weren't terrifying enough..."],
#  ['970',
#   'Sealab 2021',
#   '(2000 TV Series)',
#   '11 mins.',
#   '8.0',
#   '4,492',
#   "[u'Animation', u'Comedy', u'Sci-Fi']",
#   'The drama of an oft-doomed aquatic colony and its personnel, who hate each other.'],
#  ['971',
#   'Chowder',
#   '(2007 TV Series)',
#   '11 mins.',
#   '7.5',
#   '4,487',
#   "[u'Animation', u'Comedy', u'Family']",
#   'In Marzipan City, the young, excitable food-loving Chowder is the apprentice of Mung Daal, a very old chef who runs a catering company with his wife, Truffles and assistant, Shnitzel.'],
#  ['972',
#   'The Amazing World of Gumball',
#   '(2011 TV Series)',
#   '11 mins.',
#   '8.1',
#   '4,471',
#   "[u'Animation', u'Comedy', u'Family', u'Fantasy']",
#   'Join Gumball Watterson and his family as they must deal with all kind of funny and crazy situations.'],
#  ['973',
#   '10 Things I Hate About You',
#   '(2009 TV Series)',
#   '30 mins.',
#   '7.5',
#   '4,442',
#   "[u'Comedy']",
#   'Kat and Bianca Straford may be sisters but all comparisons end there. Kat is an outspoken, independent feminist...'],
#  ['974',
#   'Mission: Impossible',
#   '(1966 TV Series)',
#   '50 mins.',
#   '8.0',
#   '4,439',
#   "[u'Action', u'Adventure', u'Crime', u'Drama', u'Thriller']",
#   'An elite covert operations unit carries out highly sensitive missions subject to official denial in the event of failure, death or capture.'],
#  ['975',
#   'Men in Trees',
#   '(2006 TV Series)',
#   '45 mins.',
#   '7.3',
#   '4,435',
#   "[u'Comedy', u'Drama', u'Romance']",
#   "A relationship-advice guru, upon learning that her fiancÃ© is cheating on her, decides to stay in a small town in Alaska, the most recent stop on her book tour. It's in this remote town, where the ratio of men to women is ten to one, she realizes she can truly learn about the subject she thought she knew so well -- how to find, and keep, a good man."],
#  ['976',
#   'The Simple Life',
#   '(2003 TV Series)',
#   '22 mins.',
#   '3.7',
#   '4,433',
#   "[u'Comedy', u'Reality-TV']",
#   'Paris and Nicole accept various internships along the east coast. Hilarity ensues as the girls leave their limos behind, and travel by Greyhound Bus.'],
#  ['977',
#   'Kurtlar Vadisi: Pusu',
#   '(2007 TV Series)',
#   '120 mins.',
#   '6.6',
#   '4,434',
#   "[u'Action', u'Adventure', u'Drama', u'Thriller']",
#   "A continuation series of Osman Sinav's The Wolves Of The Valley. This produce focuses on politics, National Security and Regional Middle East problems..."],
#  ['978',
#   'The Biggest Loser',
#   '(2004 TV Series)',
#   '43 mins.',
#   '5.5',
#   '4,430',
#   "[u'Game-Show', u'Reality-TV']",
#   'The simple idea of The Biggest Loser, familiar to dieters the world over, is that "whomever loses the most...'],
#  ['979',
#   'Star Wars Rebels',
#   '(2014 TV Series)',
#   '30 mins.',
#   '7.9',
#   '4,435',
#   "[u'Animation', u'Action', u'Adventure', u'Fantasy', u'Sci-Fi']",
#   'A brave and clever ragtag starship crew stands up against the evil Empire as it tightens its grip on the galaxy and hunts down the last of the Jedi Knights.'],
#  ['980',
#   'The Confession',
#   '(2011 TV Series)',
#   '',
#   '7.9',
#   '4,424',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'A unique story of redemption and an exploration of good and evil featuring a hit man and a priest.'],
#  ['981',
#   'Girl Meets World',
#   '(2014 TV Series)',
#   '23 mins.',
#   '7.1',
#   '4,423',
#   "[u'Comedy', u'Family']",
#   'More than a decade after "Boy Meets World," Cory and Topanga Matthews are married and have two children. Their daughter, Riley, faces life lessons through her family, friends, and school--where her father is her history teacher--as her parents did when they were younger.'],
#  ['982',
#   'The Kill Point',
#   '(2007 TV Series)',
#   '',
#   '7.5',
#   '4,405',
#   "[u'Action', u'Crime', u'Drama', u'Thriller']",
#   'A group of military veterans, who recently returned home from serving in Iraq, band together to pull off a major bank heist.'],
#  ['983',
#   'The Love Boat',
#   '(1977 TV Series)',
#   '60 mins.',
#   '6.0',
#   '4,406',
#   "[u'Comedy', u'Romance']",
#   'The romantic and comic tales of the passengers and crew of the cruise ship, Pacific Princess.'],
#  ['984',
#   'Cory in the House',
#   '(2007 TV Series)',
#   '22 mins.',
#   '4.5',
#   '4,395',
#   "[u'Comedy', u'Drama', u'Family']",
#   '"Cory in the House," Disney Channel\'s first series spin-off, will feature characters Cory and Victor...'],
#  ['985',
#   'Blossom',
#   '(1990 TV Series)',
#   '30 mins.',
#   '5.9',
#   '4,385',
#   "[u'Comedy', u'Drama']",
#   'A teenage girl living in a house run by men dreams what life would be like if she lived in a more conventional family.'],
#  ['986',
#   'Friends with Better Lives',
#   '(2014 TV Series)',
#   '22 mins.',
#   '7.1',
#   '4,384',
#   "[u'Comedy']",
#   'A comedy centered around six 30-something friends who each think the other has it better.'],
#  ['987',
#   'Fear Factor',
#   '(2001 TV Series)',
#   '60 mins.',
#   '5.6',
#   '4,370',
#   "[u'Game-Show', u'Reality-TV', u'Thriller']",
#   'In each pulse-racing "Fear Factor" episode, contestants (sometimes solo, often paired with spouses,...'],
#  ['988',
#   'Shark Tank',
#   '(2009 TV Series)',
#   '60 mins.',
#   '7.3',
#   '4,370',
#   "[u'Reality-TV']",
#   'Ambitious entrepreneurs present their breakthrough business concepts.'],
#  ['989',
#   'The Unusuals',
#   '(2009 TV Series)',
#   '60 mins.',
#   '8.0',
#   '4,364',
#   "[u'Comedy', u'Drama']",
#   'Darkly comedic drama focusing on the dysfunctional cops and staff of an infamous NYPD precinct.'],
#  ['990',
#   'Martin',
#   '(1992 TV Series)',
#   '30 mins.',
#   '7.3',
#   '4,355',
#   "[u'Comedy', u'Drama', u'Romance']",
#   'The random misadventures of Martin Payne, an abrasive, loud-mouthed (though somewhat insecure) Detroit talk show host and his assortment of friends and enemies.'],
#  ['991',
#   'The Playboy Club',
#   '(2011 TV Series)',
#   '60 mins.',
#   '6.5',
#   '4,343',
#   "[u'Crime', u'Drama']",
#   'Centers on the Bunnies and patrons of the original Playboy Club in 1960s Chicago.'],
#  ['992',
#   'Kardes Payi',
#   '(2014 TV Series)',
#   '70 mins.',
#   '9.3',
#   '4,335',
#   "[u'Comedy', u'Drama', u'Family']",
#   'The two brothers have a plumbing company and they are trying to invent something that would make the world a better place.'],
#  ['993',
#   'Jonathan Creek',
#   '(1997 TV Series)',
#   '120 mins.',
#   '8.2',
#   '4,330',
#   "[u'Crime', u'Drama', u'Mystery']",
#   'Working from his home in a converted windmill, Jonathan Creek is a magician with a natural ability for solving puzzles. He soon puts this ability to the use of solving impossible crimes and mysterious murders.'],
#  ['994',
#   'The Larry Sanders Show',
#   '(1992 TV Series)',
#   '30 mins.',
#   '8.6',
#   '4,327',
#   "[u'Comedy']",
#   'A comedic behind the scenes look at a late night talk show.'],
#  ['995',
#   'The Michael J. Fox Show',
#   '(2013 TV Series)',
#   '30 mins.',
#   '6.7',
#   '4,326',
#   "[u'Comedy']",
#   'A comedy inspired by the life of Michael J. Fox.'],
#  ['996',
#   'The Real Ghostbusters',
#   '(1986 TV Series)',
#   '30 mins.',
#   '7.7',
#   '4,311',
#   "[u'Animation', u'Action', u'Comedy', u'Family', u'Fantasy', u'Sci-Fi']",
#   'The continuing adventures of the staff of the ghost removal service.'],
#  ['997',
#   'Ben and Kate',
#   '(2012 TV Series)',
#   '22 mins.',
#   '6.6',
#   '4,306',
#   "[u'Comedy']",
#   "A free-spirited young guy moves in with his type-A, tightly wound sister under the guise of being his niece's nanny."],
#  ['998',
#   'Gantz',
#   '(2004 TV Series)',
#   '',
#   '7.4',
#   '4,299',
#   "[u'Animation', u'Drama', u'Fantasy', u'Horror', u'Sci-Fi', u'Thriller']",
#   'A group of people are resurrected from their deaths by a mysterious black ball called GANTZ to combat alien criminals hiding on Earth.'],
#  ['999',
#   'Baccano!',
#   '(2007 TV Series)',
#   '25 mins.',
#   '8.5',
#   '4,293',
#   "[u'Animation', u'Action', u'Adventure', u'Comedy', u'Crime', u'Fantasy', u'Horror', u'Thriller']",
#   'A crazy fantasy caper involving alchemists, immortals, gangsters, outlaws and an elixir of immortality, spread over several decades.'],
#  ...]

# %%
# 1 - convert years to int values and clean, and add title, year pairs to a list

tvshow_years = []

for row in myList:
    title = row[1]
    raw_year = row[2]
    # look for only the numbers in the raw_year: look in string for 1st occurence of 4 digits in a row
    # if 4 digits in a row is found, return the object to match
    # r' = don't treat backslashes as escape character
    # \d = searches for 0-9
    # {4} = quantifier that says 4 times of the regex character before it 
    match = re.search(r'\d{4}', raw_year)
    if match: 
        year = int(match.group()) # convert year str to int
        # .group() returns the actual text of the object it is applied to
        tvshow_years.append((title, year))
print(tvshow_years)
# Out:
# [('Game of Thrones', 2011), ('Breaking Bad', 2008), ('The Walking Dead', 2010), ('The Big Bang Theory', 2007), ('Dexter', 2006), ('How I Met Your Mother', 2005), ('Friends', 1994), ('Sherlock', 2010), ('Lost', 2004), ('Prison Break', 2005), ('House M.D.', 2004), ('Supernatural', 2005), ('True Detective', 2014), ('Arrow', 2012), ('The Simpsons', 1989), ('House of Cards', 2013), ('Family Guy', 1999), ('Modern Family', 2009), ('South Park', 1997), ('True Blood', 2008), ('The Vampire Diaries', 2009), ('Homeland', 2011), ('Suits', 2011), ('Heroes', 2006), ('Arrested Development', 2003), ('Two and a Half Men', 2003), ('Scrubs', 2001), ('The Office', 2005), ('Firefly', 2002), ('Fringe', 2008), ('American Horror Story', 2011), ('The Sopranos', 1999), ('The Wire', 2002), ('Spartacus: War of the Damned', 2010), ('Sons of Anarchy', 2008), ('Once Upon a Time', 2011), ('Seinfeld', 1989), ('Grey&#x27;s Anatomy', 2005), ('Californication', 2007), ('24', 2001), ('Orange Is the New Black', 2013), ('Doctor Who', 2005), ('Community', 2009), ('Futurama', 1999), ('Vikings', 2013), ('Mad Men', 2007), ('The Mentalist', 2008), ('Boardwalk Empire', 2010), ('New Girl', 2011), ('Entourage', 2004), ('Hannibal', 2013), ('It&#x27;s Always Sunny in Philadelphia', 2005), ('Glee', 2009), ('The X-Files', 1993), ('Battlestar Galactica', 2004), ('Castle', 2009), ('That &#x27;70s Show', 1998), ('Avatar: The Last Airbender', 2005), ('Chuck', 2007), ('Gossip Girl', 2007), ('Bones', 2005), ('Person of Interest', 2011), ('Rome', 2005), ('Criminal Minds', 2005), ('Agents of S.H.I.E.L.D.', 2013), ('Pretty Little Liars', 2010), ('Buffy the Vampire Slayer', 1997), ('Downton Abbey', 2010), ('Revenge', 2011), ('Fargo', 2014), ('Smallville', 2001), ('Twin Peaks', 1990), ('Parks and Recreation', 2009), ('Desperate Housewives', 2004), ('Malcolm in the Middle', 2000), ('30 Rock', 2006), ('White Collar', 2009), ('Weeds', 2005), ('Lie to Me', 2009), ('Six Feet Under', 2001), ('My Name Is Earl', 2005), ('The Fresh Prince of Bel-Air', 1990), ('Freaks and Geeks', 1999), ('The IT Crowd', 2006), ('Death Note', 2006), ('Shameless', 2011), ('NCIS', 2003), ('The Flash', 2014), ('Sex and the City', 1998), ('Married with Children', 1987), ('The Blacklist', 2013), ('Gotham', 2014), ('American Dad!', 2005), ('Grimm', 2011), ('The Newsroom', 2012), ('Under the Dome', 2013), ('Revolution', 2012), ('Teen Wolf', 2011), ('The Following', 2013), ('Misfits', 2009), ('Terra Nova', 2011), ('Falling Skies', 2011), ('CSI: Crime Scene Investigation', 2000), ('Archer', 2009), ('Psych', 2006), ('Leyla and Mecnun', 2011), ('2 Broke Girls', 2011), ('The O.C.', 2003), ('Top Gear', 2002), ('Better Call Saul', 2015), ('Elementary', 2012), ('The Killing', 2011), ('Dragon Ball Z', 1996), ('Curb Your Enthusiasm', 1999), ('Oz', 1997), ('The Office', 2001), ('Burn Notice', 2007), ('Deadwood', 2004), ('Stargate SG-1', 1997), ('Justified', 2010), ('The King of Queens', 1998), ('The Legend of Korra', 2012), ('Gilmore Girls', 2000), ('Skins', 2007), ('Star Trek: The Next Generation', 1987), ('FlashForward', 2009), ('Veronica Mars', 2004), ('The Originals', 2013), ('One Tree Hill', 2003), ('Merlin', 2008), ('Luther', 2010), ('Frasier', 1993), ('SpongeBob SquarePants', 1999), ('Charmed', 1998), ('Terminator: The Sarah Connor Chronicles', 2008), ('The 100', 2014), ('Da Vinci&#x27;s Demons', 2013), ('The Shield', 2002), ('Monk', 2002), ('Louie', 2010), ('Angel', 1999), ('Fawlty Towers', 1975), ('Nip/Tuck', 2003), ('Law &#x26; Order: Special Victims Unit', 1999), ('The Tudors', 2007), ('The Inbetweeners', 2008), ('Jericho', 2006), ('Everybody Loves Raymond', 1996), ('Mr. Bean', 1990), ('Stargate: Atlantis', 2004), ('Bates Motel', 2013), ('V', 2009), ('Orphan Black', 2013), ('Girls', 2012), ('Penny Dreadful', 2014), ('Pushing Daisies', 2007), ('CSI: Miami', 2002), ('Batman: The Animated Series', 1992), ('Scandal', 2012), ('Sleepy Hollow', 2013), ('The Good Wife', 2009), ('Nikita', 2010), ('Continuum', 2012), ('Cowboy Bebop' ...

# %%
# 2 - find top 5 most recent shows 

# newList = sorted(myList, key=None, reverse=True) sorts the list from small to big
# key = tells sorted() whatg value in the list to sort by
    # if key none, compares whole item
    # if key = lambda x: x[1] means 'for item x, return x at index 1 
# True = if true, put biggest first 
sorted_shows = sorted(tvshow_years, key = lambda x: x[1], reverse = True)
#print(sorted_shows)

# 3 - add to top 5 list
top5 = sorted_shows[0:5]
print("The top 5 most recent shows are: ")
print(top5)
# Out:
# The top 5 most recent shows are:
# [('Better Call Saul', 2015), ('Daredevil', 2015), ('Agent Carter', 2015), ('Unbreakable Kimmy Schmidt', 2015), ('The Last Man on Earth', 2015)]

# %% [markdown]
# # JSON Files
# [JavaScript Object Notation](https://www.json.org/)
#
# A JSON file is a file that stores simple data structures and objects in JavaScript Object Notation (JSON) format, which is a standard data interchange format. It is primarily used for transmitting data between a web application and a server. JSON files are lightweight, text-based, human-readable, and can be edited using a text editor.
#
# While many applications use JSON for data interchange, they may not actually save .json files on the hard drive since the data interchange occurs between Internet-connected computers. However, some applications do enable users to save .json files.
#
# [JavaScript Object Notation](https://www.json.org/) (JSON) is a common data structure that one encounters working with [Application Programming Interfaces](https://en.wikipedia.org/wiki/API) (API)s. They organize through 'depth' by 'nesting' concepts within one another, much like a dictionary does.
#
# for example:

# %%
# JSON - like a dictionaries
# used in APIs
# out put for APIs is a json file or structure

# %%
import pprint
dict = {
    'key1':
        'value1',
    'key2':
        'value2',
    'key3':
        'value3'
}
pprint.pprint(dict)
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %% [markdown]
# json notation allows for the engaging of deeper and more complex dictionaries that do not always have the same datatype.
#
#
# for exmaple:

# %%
complexDict1 = {
    '23fallClasses': 
        ['Api', 'UCD'],
    '23springClasses' : 
        ['theory', 'linguistic anthropology'],
    '22fallClasses': 
        ['WoK', 'Media Sociology'],
    '22springClasses' : 
        ['War and Peace', 'Data II']
}
pprint.pprint(complexDict1)
# Out:
# {'22fallClasses': ['WoK', 'Media Sociology'],
#  '22springClasses': ['War and Peace', 'Data II'],
#  '23fallClasses': ['Api', 'UCD'],
#  '23springClasses': ['theory', 'linguistic anthropology']}

# %% [markdown]
# 'complex Dict 1' has strings and lists but jsons can even go further and nest to deeper levels besides the first one

# %%
complexDict2 = {
    '23fallClasses': { 
        'Api' : {
            'grade': 95.0,
            'teacher':'Brian Keegan'
        }, 
        'UCD':{
            'grade': 98.0,
            'teacher': 'Ricarose Roque'
        }},
    '23springClasses':{ 
        'theory': {
            'grade': 90.0,
            'teacher': 'Jed Burbaker'
        }, 
        'linguistic anthropology':{
            'grade': 95.1,
            'teacher': 'Kira Hall'
        }},
    '22fallClasses':{
        'WoK':{
            'grade': 92.0,
            'teacher': 'Bryan Semaan'
        }, 
        'Media Sociology':{
            'grade': 97.3,
            'teacher': 'Michael McDevitt'
        }},
    '22springClasses':{
        'War and Peace':{
            'grade': 89.0,
            'teacher': 'Jaroslav Tir'
        }, 
        'Data II':{
            'grade': 95.1,
            'teacher': 'Andrew Philips'
        }}
    
}
pprint.pprint(complexDict2)
# Out:
# {'22fallClasses': {'Media Sociology': {'grade': 97.3,
#                                        'teacher': 'Michael McDevitt'},
#                    'WoK': {'grade': 92.0, 'teacher': 'Bryan Semaan'}},
#  '22springClasses': {'Data II': {'grade': 95.1, 'teacher': 'Andrew Philips'},
#                      'War and Peace': {'grade': 89.0,
#                                        'teacher': 'Jaroslav Tir'}},
#  '23fallClasses': {'Api': {'grade': 95.0, 'teacher': 'Brian Keegan'},
#                    'UCD': {'grade': 98.0, 'teacher': 'Ricarose Roque'}},
#  '23springClasses': {'linguistic anthropology': {'grade': 95.1,
#                                                  'teacher': 'Kira Hall'},
#                      'theory': {'grade': 90.0, 'teacher': 'Jed Burbaker'}}}

# %% [markdown]
# <!-- space -->

# %% [markdown]
# Now lets make some of our own and work with it....

# %%
#example of a json file
person = {"name":"John", "age":30, "car":None}
pprint.pprint(person)
# Out:
# {'age': 30, 'car': None, 'name': 'John'}

# %%
#what data type is it?
type(person)
# Out:
# dict

# %%
#grab data at a position
person["name"]
# Out:
# 'John'

# %%
#get data at another position
person["car"]

# %%
# lets try something bigger

movie = {'id': 538,
 'url': 'https://www.tvmaze.com/shows/538/futurama',
 'name': 'Futurama',
 'type': 'Animation',
 'language': 'English',
 'genres': ['Comedy', 'Adventure', 'Science-Fiction'],
 'status': 'Ended',
 'runtime': 30,
 'averageRuntime': 30,
 'premiered': '1999-03-28',
 'ended': '2013-09-04',
 'officialSite': 'http://www.cc.com/shows/futurama',
 'schedule': {'time': '22:00', 'days': ['Wednesday']},
 'rating': {'average': 8.9},
 'weight': 98,
 'network': {'id': 23,
  'name': 'Comedy Central',
  'country': {'name': 'United States',
   'code': 'US',
   'timezone': 'America/New_York'}},
 'webChannel': None,
 'dvdCountry': None,
 'externals': {'tvrage': 3628, 'thetvdb': 73871, 'imdb': 'tt0149460'},
 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/4/11403.jpg',
  'original': 'https://static.tvmaze.com/uploads/images/original_untouched/4/11403.jpg'},
 'summary': '<p><b>Futurama</b> follows pizza guy Philip J. Fry, who reawakens in 31st century New New York after a cryonics lab accident. Now part of the Planet Express delivery crew, Fry travels to the farthest reaches of the universe with his robot buddy Bender and cyclopsian love interest Leela, discovering freaky mutants, intergalactic conspiracies and other strange stuff.</p>',
 'updated': 1643062596,
 '_links': {'self': {'href': 'https://api.tvmaze.com/shows/538'},
  'previousepisode': {'href': 'https://api.tvmaze.com/episodes/49411'}}}

# %%
# Out:
# 'Beast Machines: Transformers'

# %%
#what data type is this? 
type(movie)
# Out:
# dict

# %%
#grab data at a position
movie["network"]
# Out:
# {'id': 23,
#  'name': 'Comedy Central',
#  'country': {'name': 'United States',
#   'code': 'US',
#   'timezone': 'America/New_York'}}

# %%
#get the timezone
movie["network"]["country"]["timezone"]
# Out:
# 'America/New_York'

# %%
#get an image .jpg name
movie["image"]["original"]

#image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/4/11403.jpg',
 # 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/4/11403.jpg'},
# Out:
# 'https://static.tvmaze.com/uploads/images/original_untouched/4/11403.jpg'

# %% [markdown]
# #### reading a json file
#
# json exposes an API familiar to users of the standard library marshal and pickle modules. Encoding basic Python object hierarchies, Compact encoding, Compact encoding, and Specializing JSON object decoding.
#
# json encoder and decoder docs - [https://docs.python.org/3/library/json.html]

# %%
# importing json library
import json

# %%
# open sample_users.json
# read json file

f = open("data/sample_users.json", 'r') # assign json file to a variable

data = json.loads(f.read())

# %%
# look at the data
pprint.pprint(data)
# Out:
# [{'created_at': '2016-11-28T14:10:11.338Z',
#   'email': 'test@test.com',
#   'email_verified': True,
#   'family_name': 'Test',
#   'given_name': 'Hello',
#   'last_ip': '94.121.163.63',
#   'last_login': '2016-12-02T01:17:29.310Z',
#   'logins_count': 15,
#   'name': 'test@test.com',
#   'nickname': 'test',
#   'updated_at': '2016-12-02T01:17:29.310Z',
#   'user_id': '583c3ac3f38e84297c002546'},
#  {'created_at': '2016-11-28T16:00:04.209Z',
#   'email': 'test1@test.com',
#   'email_verified': True,
#   'family_name': 'Test1',
#   'given_name': 'Hello1',
#   'last_ip': '94.121.168.53',
#   'last_login': '2016-11-28T16:00:47.203Z',
#   'logins_count': 1,
#   'name': 'test1@test.com',
#   'nickname': 'test1',
#   'updated_at': '2016-11-28T16:00:47.203Z',
#   'user_id': '583c5484cb79a5fe593425a9'},
#  {'created_at': '2016-11-28T16:12:23.777Z',
#   'email': 'aaa@aaa.com',
#   'email_verified': True,
#   'family_name': 'Dough',
#   'given_name': 'John',
#   'last_ip': '94.121.168.53',
#   'last_login': '2016-11-28T16:12:52.353Z',
#   'logins_count': 2,
#   'name': 'aaa@aaa.com',
#   'nickname': 'aaa',
#   'updated_at': '2016-11-28T16:12:52.353Z',
#   'user_id': '583c57672c7686377d2f66c9'},
#  {'created_at': '2016-12-01T23:59:16.473Z',
#   'email': 'a@a.com',
#   'email_verified': True,
#   'family_name': 'Dough',
#   'given_name': 'Jane',
#   'last_ip': '94.121.163.63',
#   'last_login': '2016-12-01T23:59:53.474Z',
#   'logins_count': 3,
#   'name': 'a@a.com',
#   'nickname': 'a',
#   'updated_at': '2016-12-01T23:59:53.474Z',
#   'user_id': '5840b954da0529cd293d76fe'},
#  {'created_at': '2016-12-09T12:01:23.787Z',
#   'email': 'test9999@test.com',
#   'email_verified': False,
#   'family_name': 'User',
#   'given_name': 'Dummy',
#   'updated_at': '2016-12-09T12:01:23.787Z',
#   'user_id': '584a9d13e808bcf75f05f580'}]

# %%
#get the type of data
type(data)
# Out:
# list

# %% [markdown]
# #### Your data get's imported as list, because in your JSON file the main structure is an Array (squared brackets), which is comparable to a list in Python.

# %%
# you can get how long it is
len(data) # 5 items/dictionarie
# Out:
# 5

# %%
# get the first email 
data[0]["email"]
# Out:
# 'test@test.com'

# %% [markdown]
# <!--    -->

# %% [markdown]
# #### pprint
#
# The pprint module provides a capability to “pretty-print” arbitrary Python data structures in a form which can be used as input to the interpreter
#
# docs - [https://docs.python.org/3/library/pprint.html]

# %%
import pprint # allows u to see data better

# %%
#print original data (w/o pprint)
data
# Out:
# [{'user_id': '583c3ac3f38e84297c002546',
#   'email': 'test@test.com',
#   'name': 'test@test.com',
#   'given_name': 'Hello',
#   'family_name': 'Test',
#   'nickname': 'test',
#   'last_ip': '94.121.163.63',
#   'logins_count': 15,
#   'created_at': '2016-11-28T14:10:11.338Z',
#   'updated_at': '2016-12-02T01:17:29.310Z',
#   'last_login': '2016-12-02T01:17:29.310Z',
#   'email_verified': True},
#  {'user_id': '583c5484cb79a5fe593425a9',
#   'email': 'test1@test.com',
#   'name': 'test1@test.com',
#   'given_name': 'Hello1',
#   'family_name': 'Test1',
#   'nickname': 'test1',
#   'last_ip': '94.121.168.53',
#   'logins_count': 1,
#   'created_at': '2016-11-28T16:00:04.209Z',
#   'updated_at': '2016-11-28T16:00:47.203Z',
#   'last_login': '2016-11-28T16:00:47.203Z',
#   'email_verified': True},
#  {'user_id': '583c57672c7686377d2f66c9',
#   'email': 'aaa@aaa.com',
#   'name': 'aaa@aaa.com',
#   'given_name': 'John',
#   'family_name': 'Dough',
#   'nickname': 'aaa',
#   'last_ip': '94.121.168.53',
#   'logins_count': 2,
#   'created_at': '2016-11-28T16:12:23.777Z',
#   'updated_at': '2016-11-28T16:12:52.353Z',
#   'last_login': '2016-11-28T16:12:52.353Z',
#   'email_verified': True},
#  {'user_id': '5840b954da0529cd293d76fe',
#   'email': 'a@a.com',
#   'name': 'a@a.com',
#   'given_name': 'Jane',
#   'family_name': 'Dough',
#   'nickname': 'a',
#   'last_ip': '94.121.163.63',
#   'logins_count': 3,
#   'created_at': '2016-12-01T23:59:16.473Z',
#   'updated_at': '2016-12-01T23:59:53.474Z',
#   'last_login': '2016-12-01T23:59:53.474Z',
#   'email_verified': True},
#  {'user_id': '584a9d13e808bcf75f05f580',
#   'email': 'test9999@test.com',
#   'given_name': 'Dummy',
#   'family_name': 'User',
#   'created_at': '2016-12-09T12:01:23.787Z',
#   'updated_at': '2016-12-09T12:01:23.787Z',
#   'email_verified': False}]

# %%
#now try pprint
pprint.pprint(data)
# Out:
# [{'created_at': '2016-11-28T14:10:11.338Z',
#   'email': 'test@test.com',
#   'email_verified': True,
#   'family_name': 'Test',
#   'given_name': 'Hello',
#   'last_ip': '94.121.163.63',
#   'last_login': '2016-12-02T01:17:29.310Z',
#   'logins_count': 15,
#   'name': 'test@test.com',
#   'nickname': 'test',
#   'updated_at': '2016-12-02T01:17:29.310Z',
#   'user_id': '583c3ac3f38e84297c002546'},
#  {'created_at': '2016-11-28T16:00:04.209Z',
#   'email': 'test1@test.com',
#   'email_verified': True,
#   'family_name': 'Test1',
#   'given_name': 'Hello1',
#   'last_ip': '94.121.168.53',
#   'last_login': '2016-11-28T16:00:47.203Z',
#   'logins_count': 1,
#   'name': 'test1@test.com',
#   'nickname': 'test1',
#   'updated_at': '2016-11-28T16:00:47.203Z',
#   'user_id': '583c5484cb79a5fe593425a9'},
#  {'created_at': '2016-11-28T16:12:23.777Z',
#   'email': 'aaa@aaa.com',
#   'email_verified': True,
#   'family_name': 'Dough',
#   'given_name': 'John',
#   'last_ip': '94.121.168.53',
#   'last_login': '2016-11-28T16:12:52.353Z',
#   'logins_count': 2,
#   'name': 'aaa@aaa.com',
#   'nickname': 'aaa',
#   'updated_at': '2016-11-28T16:12:52.353Z',
#   'user_id': '583c57672c7686377d2f66c9'},
#  {'created_at': '2016-12-01T23:59:16.473Z',
#   'email': 'a@a.com',
#   'email_verified': True,
#   'family_name': 'Dough',
#   'given_name': 'Jane',
#   'last_ip': '94.121.163.63',
#   'last_login': '2016-12-01T23:59:53.474Z',
#   'logins_count': 3,
#   'name': 'a@a.com',
#   'nickname': 'a',
#   'updated_at': '2016-12-01T23:59:53.474Z',
#   'user_id': '5840b954da0529cd293d76fe'},
#  {'created_at': '2016-12-09T12:01:23.787Z',
#   'email': 'test9999@test.com',
#   'email_verified': False,
#   'family_name': 'User',
#   'given_name': 'Dummy',
#   'updated_at': '2016-12-09T12:01:23.787Z',
#   'user_id': '584a9d13e808bcf75f05f580'}]

# %%
#what data type is this?
type(data)
# Out:
# list

# %% [markdown]
# ### Excercise 1:
# import nationalParks.json
#
# Create a dictionary of the number of national parks per state
#
# Hint: go to the example of counting genres

# %%
# 1 - read in file
f = open("data/nationalParks.json", 'r')
np_data = json.loads(f.read()) 
pprint.pprint(np_data)
# Out:
# [{'area': {'acres': '49,057.36', 'square_km': '198.5'},
#   'coordinates': {'latitude': 44.35, 'longitude': -68.21},
#   'date_established_readable': 'February 26, 1919',
#   'date_established_unix': -1604599200,
#   'description': 'Covering most of Mount Desert Island and other coastal '
#                  'islands, Acadia features the tallest mountain on the '
#                  'Atlantic coast of the United States, granite peaks, ocean '
#                  'shoreline, woodlands, and lakes. There are freshwater, '
#                  'estuary, forest, and intertidal habitats.',
#   'id': 'park_acadia',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'acadia.jpg'},
#   'nps_link': 'https://www.nps.gov/acad/index.htm',
#   'states': [{'id': 'state_maine', 'title': 'Maine'}],
#   'title': 'Acadia',
#   'visitors': '3,303,393',
#   'world_heritage_site': False},
#  {'area': {'acres': '8,256.67', 'square_km': '33.4'},
#   'coordinates': {'latitude': -14.25, 'longitude': -170.68},
#   'date_established_readable': 'October 31, 1988',
#   'date_established_unix': 594280800,
#   'description': 'The southernmost National Park is on three Samoan islands '
#                  'and protects coral reefs, rainforests, volcanic mountains, '
#                  'and white beaches. The area is also home to flying foxes, '
#                  'brown boobies, sea turtles, and 900 species of fish.',
#   'id': 'park_american-samoa',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'american-samoa.jpg'},
#   'nps_link': 'https://www.nps.gov/npsa/index.htm',
#   'states': [{'id': 'state_american-samoa', 'title': 'American Samoa'}],
#   'title': 'American Samoa',
#   'visitors': '28,892',
#   'world_heritage_site': False},
#  {'area': {'acres': '76,678.98', 'square_km': '310.3'},
#   'coordinates': {'latitude': 38.68, 'longitude': -109.57},
#   'date_established_readable': 'November 12, 1971',
#   'date_established_unix': 58773600,
#   'description': 'This site features more than 2,000 natural sandstone arches, '
#                  'with some of the most popular arches in the park being '
#                  'Delicate Arch, Landscape Arch and Double Arch. Millions of '
#                  'years of erosion have created these structures located in a '
#                  'desert climate where the arid ground has life-sustaining '
#                  'biological soil crusts and potholes that serve as natural '
#                  'water-collecting basins. Other geologic formations include '
#                  'stone pinnacles, fins, and balancing rocks.',
#   'id': 'park_arches',
#   'image': {'attribution': 'PixelBay/@LoggaWiggler',
#             'attribution_url': 'https://pixabay.com/en/users/LoggaWiggler-15/',
#             'url': 'arches.jpg'},
#   'nps_link': 'https://www.nps.gov/arch/index.htm',
#   'states': [{'id': 'state_utah', 'title': 'Utah'}],
#   'title': 'Arches',
#   'visitors': '1,585,718',
#   'world_heritage_site': False},
#  {'area': {'acres': '242,755.94', 'square_km': '982.4'},
#   'coordinates': {'latitude': 43.75, 'longitude': -102.5},
#   'date_established_readable': 'November 10, 1978',
#   'date_established_unix': 279525600,
#   'description': 'The Badlands are a collection of buttes, pinnacles, spires, '
#                  'and mixed-grass prairies. The White River Badlands contain '
#                  'the largest assemblage of known late Eocene and Oligocene '
#                  'mammal fossils. The wildlife includes bison, bighorn sheep, '
#                  'black-footed ferrets, and prairie dogs.',
#   'id': 'park_badlands',
#   'image': {'attribution': 'PixelBay/@kasabubu',
#             'attribution_url': 'https://pixabay.com/en/users/kasabubu-1559919/',
#             'url': 'badlands.jpg'},
#   'nps_link': 'https://www.nps.gov/badl/index.htm',
#   'states': [{'id': 'state_south-dakota', 'title': 'South Dakota'}],
#   'title': 'Badlands',
#   'visitors': '996,263',
#   'world_heritage_site': False},
#  {'area': {'acres': '801,163.21', 'square_km': '3,242.2'},
#   'coordinates': {'latitude': 29.25, 'longitude': -103.25},
#   'date_established_readable': 'June 12, 1944',
#   'date_established_unix': -806439600,
#   'description': 'Named for the prominent bend in the Rio Grande along the '
#                  'U.S.–Mexico border, this park encompasses a large and remote '
#                  'part of the Chihuahuan Desert. Its main attraction is '
#                  'backcountry recreation in the arid Chisos Mountains and in '
#                  'canyons along the river. A wide variety of Cretaceous and '
#                  'Tertiary fossils as well as cultural artifacts of Native '
#                  'Americans also exist within its borders.',
#   'id': 'park_big-bend',
#   'image': {'attribution': 'PixelBay/@Goodfreephotos_com',
#             'attribution_url': 'https://pixabay.com/en/users/Goodfreephotos_com-10388/',
#             'url': 'big-bend.jpg'},
#   'nps_link': 'https://www.nps.gov/bibe/index.htm',
#   'states': [{'id': 'state_texas', 'title': 'Texas'}],
#   'title': 'Big Bend',
#   'visitors': '388,290',
#   'world_heritage_site': False},
#  {'area': {'acres': '172,971.11', 'square_km': '700.0'},
#   'coordinates': {'latitude': 25.65, 'longitude': -80.08},
#   'date_established_readable': 'June 28, 1980',
#   'date_established_unix': 331016400,
#   'description': 'Located in Biscayne Bay, this park at the north end of the '
#                  'Florida Keys has four interrelated marine ecosystems: '
#                  'mangrove forest, the Bay, the Keys, and coral reefs. '
#                  'Threatened animals include the West Indian manatee, American '
#                  'crocodile, various sea turtles, and peregrine falcon.',
#   'id': 'park_biscayne',
#   'image': {'attribution': 'Wikipedia/@Catholic_85',
#             'attribution_url': 'https://en.wikipedia.org/wiki/User:Catholic_85',
#             'url': 'biscayne.jpg'},
#   'nps_link': 'https://www.nps.gov/bisc/index.htm',
#   'states': [{'id': 'state_florida', 'title': 'Florida'}],
#   'title': 'Biscayne',
#   'visitors': '514,709',
#   'world_heritage_site': False},
#  {'area': {'acres': '30,749.75', 'square_km': '124.4'},
#   'coordinates': {'latitude': 38.57, 'longitude': -107.72},
#   'date_established_readable': 'October 21, 1999',
#   'date_established_unix': 940482000,
#   'description': 'The park protects a quarter of the Gunnison River, which '
#                  'slices sheer canyon walls from dark Precambrian-era rock. '
#                  'The canyon features some of the steepest cliffs and oldest '
#                  'rock in North America, and is a popular site for river '
#                  'rafting and rock climbing. The deep, narrow canyon is '
#                  'composed of gneiss and schist which appears black when in '
#                  'shadow.',
#   'id': 'park_black-canyon-of-the-gunnison',
#   'image': {'attribution': 'PixaBay/@mudnwaffles',
#             'attribution_url': 'https://pixabay.com/en/users/mudnwaffles-1830161/',
#             'url': 'black-canyon-of-the-gunnison.jpg'},
#   'nps_link': 'https://www.nps.gov/blca/index.htm',
#   'states': [{'id': 'state_colorado', 'title': 'Colorado'}],
#   'title': 'Black Canyon of the Gunnison',
#   'visitors': '238,018',
#   'world_heritage_site': False},
#  {'area': {'acres': '35,835.08', 'square_km': '145.0'},
#   'coordinates': {'latitude': 37.57, 'longitude': -112.18},
#   'date_established_readable': 'February 25, 1928',
#   'date_established_unix': -1320688800,
#   'description': 'Bryce Canyon is a geological amphitheater on the Paunsaugunt '
#                  'Plateau with hundreds of tall, multicolored sandstone '
#                  'hoodoos formed by erosion. The region was originally settled '
#                  'by Native Americans and later by Mormon pioneers.',
#   'id': 'park_bryce-canyon',
#   'image': {'attribution': '@kevinnayar',
#             'attribution_url': 'https://kevinnayar.github.io/',
#             'url': 'bryce-canyon.jpg'},
#   'nps_link': 'https://www.nps.gov/brca/index.htm',
#   'states': [{'id': 'state_utah', 'title': 'Utah'}],
#   'title': 'Bryce Canyon',
#   'visitors': '2,365,110',
#   'world_heritage_site': False},
#  {'area': {'acres': '337,597.83', 'square_km': '1,366.2'},
#   'coordinates': {'latitude': 38.2, 'longitude': -109.93},
#   'date_established_readable': 'September 12, 1964',
#   'date_established_unix': -167338800,
#   'description': 'This landscape was eroded into a maze of canyons, buttes, '
#                  'and mesas by the combined efforts of the Colorado River, '
#                  'Green River, and their tributaries, which divide the park '
#                  'into three districts. The park also contains rock pinnacles '
#                  'and arches, as well as artifacts from Ancient Pueblo '
#                  'peoples.',
#   'id': 'park_canyonlands',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'canyonlands.jpg'},
#   'nps_link': 'https://www.nps.gov/cany/index.htm',
#   'states': [{'id': 'state_utah', 'title': 'Utah'}],
#   'title': 'Canyonlands',
#   'visitors': '776,218',
#   'world_heritage_site': False},
#  {'area': {'acres': '241,904.26', 'square_km': '979.0'},
#   'coordinates': {'latitude': 38.2, 'longitude': -111.17},
#   'date_established_readable': 'December 18, 1971',
#   'date_established_unix': 61884000,
#   'description': "The park's Waterpocket Fold is a 100-mile (160 km) monocline "
#                  "that exhibits the earth's diverse geologic layers. Other "
#                  'natural features include monoliths, cliffs, and sandstone '
#                  'domes shaped like the United States Capitol.',
#   'id': 'park_capitol-reef',
#   'image': {'attribution': 'PixelBay/@derwiki',
#             'attribution_url': 'https://pixabay.com/en/users/derwiki-562673/',
#             'url': 'capitol-reef.jpg'},
#   'nps_link': 'https://www.nps.gov/care/index.htm',
#   'states': [{'id': 'state_utah', 'title': 'Utah'}],
#   'title': 'Capitol Reef',
#   'visitors': '1,064,904',
#   'world_heritage_site': False},
#  {'area': {'acres': '46,766.45', 'square_km': '189.3'},
#   'coordinates': {'latitude': 32.17, 'longitude': -104.44},
#   'date_established_readable': 'May 14, 1930',
#   'date_established_unix': -1250794800,
#   'description': 'Carlsbad Caverns has 117 caves, the longest of which is over '
#                  '120 miles (190 km) long. The Big Room is almost 4,000 feet '
#                  '(1,200 m) long, and the caves are home to over 400,000 '
#                  'Mexican free-tailed bats and sixteen other species. Above '
#                  'ground are the Chihuahuan Desert and Rattlesnake Springs.',
#   'id': 'park_carlsbad-caverns',
#   'image': {'attribution': 'PixelBay/@MartinStr',
#             'attribution_url': 'https://pixabay.com/en/users/MartinStr-108372/',
#             'url': 'carlsbad-caverns.jpg'},
#   'nps_link': 'https://www.nps.gov/cave/index.htm',
#   'states': [{'id': 'state_new-mexico', 'title': 'New Mexico'}],
#   'title': 'Carlsbad Caverns',
#   'visitors': '466,773',
#   'world_heritage_site': True},
#  {'area': {'acres': '249,561.00', 'square_km': '1,009.9'},
#   'coordinates': {'latitude': 34.01, 'longitude': -119.42},
#   'date_established_readable': 'March 5, 1980',
#   'date_established_unix': 321084000,
#   'description': 'Five of the eight Channel Islands are protected, and half of '
#                  "the park's area is underwater. The islands have a unique "
#                  'Mediterranean ecosystem originally settled by the Chumash '
#                  'people. They are home to over 2,000 species of land plants '
#                  'and animals, and 145 are unique to them, including the '
#                  'island fox. Ferry services offer transportation to the '
#                  'islands from the mainland.',
#   'id': 'park_channel-islands',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'channel-islands.jpg'},
#   'nps_link': 'https://www.nps.gov/chis/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Channel Islands',
#   'visitors': '364,807',
#   'world_heritage_site': False},
#  {'area': {'acres': '26,275.82', 'square_km': '106.3'},
#   'coordinates': {'latitude': 33.78, 'longitude': -80.78},
#   'date_established_readable': 'November 10, 2003',
#   'date_established_unix': 1068444000,
#   'description': 'On the Congaree River, this park is the largest portion of '
#                  'old-growth floodplain forest left in North America. Some of '
#                  'the trees are the tallest in the eastern United States. An '
#                  'elevated walkway called the Boardwalk Loop guides visitors '
#                  'through the swamp.',
#   'id': 'park_congaree',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'congaree.jpg'},
#   'nps_link': 'https://www.nps.gov/cong/index.htm',
#   'states': [{'id': 'state_south-carolina', 'title': 'South Carolina'}],
#   'title': 'Congaree',
#   'visitors': '143,843',
#   'world_heritage_site': False},
#  {'area': {'acres': '183,224.05', 'square_km': '741.5'},
#   'coordinates': {'latitude': 42.94, 'longitude': -122.1},
#   'date_established_readable': 'May 22, 1902',
#   'date_established_unix': -2133716400,
#   'description': 'Crater Lake lies in the caldera of an ancient volcano called '
#                  'Mount Mazama that collapsed 7,700 years ago. It is the '
#                  'deepest lake in the United States and is noted for its vivid '
#                  'blue color and water clarity. There are two more recent '
#                  'volcanic islands in the lake, and, with no inlets or '
#                  'outlets, all water comes through precipitation.',
#   'id': 'park_crater-lake',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'crater-lake.jpg'},
#   'nps_link': 'https://www.nps.gov/crla/index.htm',
#   'states': [{'id': 'state_oregon', 'title': 'Oregon'}],
#   'title': 'Crater Lake',
#   'visitors': '756,344',
#   'world_heritage_site': False},
#  {'area': {'acres': '32,572.35', 'square_km': '131.8'},
#   'coordinates': {'latitude': 41.24, 'longitude': -81.55},
#   'date_established_readable': 'October 11, 2000',
#   'date_established_unix': 971240400,
#   'description': 'This park along the Cuyahoga River has waterfalls, hills, '
#                  'trails, and exhibits on early rural living. The Ohio and '
#                  'Erie Canal Towpath Trail follows the Ohio and Erie Canal, '
#                  'where mules towed canal boats. The park has numerous '
#                  'historic homes, bridges, and structures, and also offers a '
#                  'scenic train ride.',
#   'id': 'park_cuyahoga-valley',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'cuyahoga-valley.jpg'},
#   'nps_link': 'https://www.nps.gov/cuva/index.htm',
#   'states': [{'id': 'state_ohio', 'title': 'Ohio'}],
#   'title': 'Cuyahoga Valley',
#   'visitors': '2,423,390',
#   'world_heritage_site': False},
#  {'area': {'acres': '3,373,063.14', 'square_km': '13,650.3'},
#   'coordinates': {'latitude': 36.24, 'longitude': -116.82},
#   'date_established_readable': 'October 31, 1994',
#   'date_established_unix': 783583200,
#   'description': 'Death Valley is the hottest, lowest, and driest place in the '
#                  'United States. Daytime temperatures have topped 130 °F (54 '
#                  '°C) and it is home to Badwater Basin, the lowest elevation '
#                  'in North America. The park contains canyons, badlands, sand '
#                  'dunes, and mountain ranges, while more than 1000 species of '
#                  'plants grow in this geologic graben. Additional points of '
#                  'interest include salt flats, historic mines, and springs.',
#   'id': 'park_death-valley',
#   'image': {'attribution': 'PixelBay/@esudroff',
#             'attribution_url': 'https://pixabay.com/en/users/esudroff-627167/',
#             'url': 'death-valley.jpg'},
#   'nps_link': 'https://www.nps.gov/deva/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'},
#              {'id': 'state_nevada', 'title': 'Nevada'}],
#   'title': 'Death Valley',
#   'visitors': '1,296,283',
#   'world_heritage_site': False},
#  {'area': {'acres': '4,740,911.16', 'square_km': '19,185.8'},
#   'coordinates': {'latitude': 63.33, 'longitude': -150.5},
#   'date_established_readable': 'February 26, 1917',
#   'date_established_unix': -1667671200,
#   'description': 'Centered on Denali, the tallest mountain in North America, '
#                  'Denali is serviced by a single road leading to Wonder Lake. '
#                  'Denali and other peaks of the Alaska Range are covered with '
#                  'long glaciers and boreal forest. Wildlife includes grizzly '
#                  'bears, Dall sheep, caribou, and gray wolves.',
#   'id': 'park_denali',
#   'image': {'attribution': 'PixelBay/@MarPockStudios',
#             'attribution_url': 'https://pixabay.com/en/users/MarPockStudios-3375534/',
#             'url': 'denali.jpg'},
#   'nps_link': 'https://www.nps.gov/dena/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Denali',
#   'visitors': '587,412',
#   'world_heritage_site': False},
#  {'area': {'acres': '64,701.22', 'square_km': '261.8'},
#   'coordinates': {'latitude': 24.63, 'longitude': -82.87},
#   'date_established_readable': 'October 26, 1992',
#   'date_established_unix': 720079200,
#   'description': 'The islands of the Dry Tortugas, at the westernmost end of '
#                  'the Florida Keys, are the site of Fort Jefferson, a Civil '
#                  'War-era fort that is the largest masonry structure in the '
#                  'Western Hemisphere. With most of the park being remote '
#                  'ocean, it is home to undisturbed coral reefs and shipwrecks '
#                  'and is only accessible by plane or boat.',
#   'id': 'park_dry-tortugas',
#   'image': {'attribution': 'Homestead AFRC',
#             'attribution_url': 'http://www.homestead.afrc.af.mil/News/Photos/igphoto/2000830258/',
#             'url': 'dry-tortugas.jpg'},
#   'nps_link': 'https://www.nps.gov/drto/index.htm',
#   'states': [{'id': 'state_florida', 'title': 'Florida'}],
#   'title': 'Dry Tortugas',
#   'visitors': '73,661',
#   'world_heritage_site': False},
#  {'area': {'acres': '1,508,968.1', 'square_km': '6,106.6'},
#   'coordinates': {'latitude': 25.32, 'longitude': -80.93},
#   'date_established_readable': 'May 30, 1934',
#   'date_established_unix': -1123182000,
#   'description': 'The Everglades are the largest tropical wilderness in the '
#                  'United States. This mangrove and tropical rainforest '
#                  'ecosystem and marine estuary is home to 36 protected '
#                  'species, including the Florida panther, American crocodile, '
#                  'and West Indian manatee. Some areas have been drained and '
#                  'developed; restoration projects aim to restore the ecology.',
#   'id': 'park_everglades',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'everglades.jpg'},
#   'nps_link': 'https://www.nps.gov/ever/index.htm',
#   'states': [{'id': 'state_florida', 'title': 'Florida'}],
#   'title': 'Everglades',
#   'visitors': '930,907',
#   'world_heritage_site': True},
#  {'area': {'acres': '7,523,897.45', 'square_km': '30,448.1'},
#   'coordinates': {'latitude': 67.78, 'longitude': -153.3},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': "The country's northernmost park protects an expanse of pure "
#                  "wilderness in Alaska's Brooks Range and has no park "
#                  'facilities. The land is home to Alaska Natives who have '
#                  'relied on the land and caribou for 11,000 years.',
#   'id': 'park_gates-of-the-arctic',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'gates-of-the-arctic.jpg'},
#   'nps_link': 'https://www.nps.gov/gaar/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Gates of the Arctic',
#   'visitors': '10,047',
#   'world_heritage_site': False},
#  {'area': {'acres': '1,013,128.94', 'square_km': '4,100.0'},
#   'coordinates': {'latitude': 48.8, 'longitude': -114},
#   'date_established_readable': 'May 11, 1910',
#   'date_established_unix': -1882206000,
#   'description': 'The U.S. half of Waterton-Glacier International Peace Park, '
#                  'this park includes 26 glaciers and 130 named lakes '
#                  'surrounded by Rocky Mountain peaks. There are historic '
#                  'hotels and a landmark road called the Going-to-the-Sun Road '
#                  'in this region of rapidly receding glaciers. The local '
#                  'mountains, formed by an overthrust, expose Paleozoic fossils '
#                  'including trilobites, mollusks, giant ferns and dinosaurs.',
#   'id': 'park_glacier',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'glacier.jpg'},
#   'nps_link': 'https://www.nps.gov/glac/index.htm',
#   'states': [{'id': 'state_montana', 'title': 'Montana'}],
#   'title': 'Glacier',
#   'visitors': '2,946,681',
#   'world_heritage_site': True},
#  {'area': {'acres': '3,223,383.43', 'square_km': '13,044.6'},
#   'coordinates': {'latitude': 58.5, 'longitude': -137},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'Glacier Bay contains tidewater glaciers, mountains, fjords, '
#                  'and a temperate rainforest, and is home to large populations '
#                  'of grizzly bears, mountain goats, whales, seals, and eagles. '
#                  'When discovered in 1794 by George Vancouver, the entire bay '
#                  'was covered by ice, but the glaciers have since receded more '
#                  'than 65 miles (105 km).',
#   'id': 'park_glacier-bay',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'glacier-bay.jpg'},
#   'nps_link': 'https://www.nps.gov/glba/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Glacier Bay',
#   'visitors': '520,171',
#   'world_heritage_site': True},
#  {'area': {'acres': '1,201,647.03', 'square_km': '4,862.9'},
#   'coordinates': {'latitude': 36.06, 'longitude': -112.14},
#   'date_established_readable': 'February 26, 1919',
#   'date_established_unix': -1604599200,
#   'description': 'The Grand Canyon, carved by the mighty Colorado River, is '
#                  '277 miles (446 km) long, up to 1 mile (1.6 km) deep, and up '
#                  'to 15 miles (24 km) wide. Millions of years of erosion have '
#                  'exposed the multicolored layers of the Colorado Plateau in '
#                  'mesas and canyon walls, visible from both the north and '
#                  'south rims, or from a number of trails that descend into the '
#                  'canyon itself.',
#   'id': 'park_grand-canyon',
#   'image': {'attribution': 'PixelBay/@BKD',
#             'attribution_url': 'https://pixabay.com/en/users/BKD-1006949/',
#             'url': 'grand-canyon.jpg'},
#   'nps_link': 'https://www.nps.gov/grca/index.htm',
#   'states': [{'id': 'state_arizona', 'title': 'Arizona'}],
#   'title': 'Grand Canyon',
#   'visitors': '5,969,811',
#   'world_heritage_site': True},
#  {'area': {'acres': '310,043.96', 'square_km': '1,254.7'},
#   'coordinates': {'latitude': 43.73, 'longitude': -110.8},
#   'date_established_readable': 'February 26, 1929',
#   'date_established_unix': -1288980000,
#   'description': 'Grand Teton is the tallest mountain in the Teton Range. The '
#                  "park's historic Jackson Hole and reflective piedmont lakes "
#                  'teem with endemic wildlife, with a backdrop of craggy '
#                  'mountains that rise abruptly from the sage-covered valley.',
#   'id': 'park_grand-teton',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'grand-teton.jpg'},
#   'nps_link': 'https://www.nps.gov/grte/index.htm',
#   'states': [{'id': 'state_wyoming', 'title': 'Wyoming'}],
#   'title': 'Grand Teton',
#   'visitors': '3,270,076',
#   'world_heritage_site': False},
#  {'area': {'acres': '77,180.00', 'square_km': '312.3'},
#   'coordinates': {'latitude': 38.98, 'longitude': -114.3},
#   'date_established_readable': 'October 27, 1986',
#   'date_established_unix': 530776800,
#   'description': "Based around Nevada's second tallest mountain, Wheeler Peak, "
#                  'Great Basin National Park contains 5,000-year-old '
#                  'bristlecone pines, a rock glacier, and the limestone Lehman '
#                  'Caves. Due to its remote location, the park has some of the '
#                  "country's darkest night skies. Wildlife includes the "
#                  "Townsend's big-eared bat, pronghorn, and Bonneville "
#                  'cutthroat trout.',
#   'id': 'park_great-basin',
#   'image': {'attribution': 'PixelBay/@vmalysova0',
#             'attribution_url': 'https://pixabay.com/en/users/vmalysova0-695458/',
#             'url': 'great-basin.jpg'},
#   'nps_link': 'https://www.nps.gov/grba/index.htm',
#   'states': [{'id': 'state_nevada', 'title': 'Nevada'}],
#   'title': 'Great Basin',
#   'visitors': '144,846',
#   'world_heritage_site': False},
#  {'area': {'acres': '107,341.87', 'square_km': '434.4'},
#   'coordinates': {'latitude': 37.73, 'longitude': -105.51},
#   'date_established_readable': 'September 13, 2004',
#   'date_established_unix': 1095051600,
#   'description': 'The tallest sand dunes in North America, up to 750 feet (230 '
#                  'm) tall, were formed by deposits of the ancient Rio Grande '
#                  'in the San Luis Valley. Abutting a variety of grasslands, '
#                  'shrublands, and wetlands, the park also has alpine lakes, '
#                  'six 13,000-foot mountains, and old-growth forests.',
#   'id': 'park_great-sand-dunes',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'great-sand-dunes.jpg'},
#   'nps_link': 'https://www.nps.gov/grsa/index.htm',
#   'states': [{'id': 'state_colorado', 'title': 'Colorado'}],
#   'title': 'Great Sand Dunes',
#   'visitors': '388,308',
#   'world_heritage_site': False},
#  {'area': {'acres': '522,426.88', 'square_km': '2,114.2'},
#   'coordinates': {'latitude': 35.68, 'longitude': -83.53},
#   'date_established_readable': 'June 15, 1934',
#   'date_established_unix': -1121799600,
#   'description': 'The Great Smoky Mountains, part of the Appalachian '
#                  'Mountains, span a wide range of elevations, making them home '
#                  'to over 400 vertebrate species, 100 tree species, and 5000 '
#                  "plant species. Hiking is the park's main attraction, with "
#                  'over 800 miles (1,300 km) of trails, including 70 miles (110 '
#                  'km) of the Appalachian Trail. Other activities include '
#                  'fishing, horseback riding, and touring nearly 80 historic '
#                  'structures.',
#   'id': 'park_great-smoky-mountains',
#   'image': {'attribution': 'PixelBay/@Broesis',
#             'attribution_url': 'https://pixabay.com/en/users/Broesis-5213623/',
#             'url': 'great-smoky-mountains.jpg'},
#   'nps_link': 'https://www.nps.gov/grsm/index.htm',
#   'states': [{'id': 'state_tennessee', 'title': 'Tennessee'},
#              {'id': 'state_north-carolina', 'title': 'North Carolina'}],
#   'title': 'Great Smoky Mountains',
#   'visitors': '11,312,786',
#   'world_heritage_site': True},
#  {'area': {'acres': '86,367.10', 'square_km': '349.5'},
#   'coordinates': {'latitude': 31.92, 'longitude': -104.87},
#   'date_established_readable': 'October 15, 1966',
#   'date_established_unix': -101415600,
#   'description': 'This park contains Guadalupe Peak, the highest point in '
#                  'Texas, as well as the scenic McKittrick Canyon filled with '
#                  'bigtooth maples, a corner of the arid Chihuahuan Desert, and '
#                  'a fossilized coral reef from the Permian era.',
#   'id': 'park_guadalupe-mountains',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'guadalupe-mountains.jpg'},
#   'nps_link': 'https://www.nps.gov/gumo/index.htm',
#   'states': [{'id': 'state_texas', 'title': 'Texas'}],
#   'title': 'Guadalupe Mountains',
#   'visitors': '181,839',
#   'world_heritage_site': False},
#  {'area': {'acres': '33,264.62', 'square_km': '134.6'},
#   'coordinates': {'latitude': 20.72, 'longitude': -156.17},
#   'date_established_readable': 'August 1, 1916',
#   'date_established_unix': -1685732400,
#   'description': 'The Haleakala volcano on Maui features a very large crater '
#                  "with numerous cinder cones, Hosmer's Grove of alien trees, "
#                  "the Kipahulu section's scenic pools of freshwater fish, and "
#                  'the native Hawaiian goose. It is home to the greatest number '
#                  'of endangered species within a U.S. National Park.',
#   'id': 'park_haleakala',
#   'image': {'attribution': 'Wikipedia/@KennyLouie',
#             'attribution_url': 'https://commons.wikimedia.org/wiki/File:Taking_it_all_in_(6881870120).jpg',
#             'url': 'haleakala.jpg'},
#   'nps_link': 'https://www.nps.gov/hale/index.htm',
#   'states': [{'id': 'state_hawaii', 'title': 'Hawaii'}],
#   'title': 'Haleakala',
#   'visitors': '1,263,558',
#   'world_heritage_site': False},
#  {'area': {'acres': '323,431.38', 'square_km': '1,308.9'},
#   'coordinates': {'latitude': 19.38, 'longitude': -155.2},
#   'date_established_readable': 'August 1, 1916',
#   'date_established_unix': -1685732400,
#   'description': 'This park on the Big Island protects the Kīlauea and Mauna '
#                  "Loa volcanoes, two of the world's most active geological "
#                  'features. Diverse ecosystems range from tropical forests at '
#                  'sea level to barren lava beds at more than 13,000 feet '
#                  '(4,000 m).',
#   'id': 'park_hawaii-volcanoes',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'hawaii-volcanoes.jpg'},
#   'nps_link': 'https://www.nps.gov/havo/index.htm',
#   'states': [{'id': 'state_hawaii', 'title': 'Hawaii'}],
#   'title': 'Hawaii Volcanoes',
#   'visitors': '1,887,580',
#   'world_heritage_site': True},
#  {'area': {'acres': '5,549.10', 'square_km': '22.5'},
#   'coordinates': {'latitude': 34.51, 'longitude': -93.05},
#   'date_established_readable': 'March 4, 1921',
#   'date_established_unix': -1540922400,
#   'description': 'Hot Springs was established by act of Congress as a federal '
#                  'reserve on April 20, 1832. As such it is the oldest park '
#                  'managed by the National Park Service. Congress changed the '
#                  "reserve's designation to National Park on March 4, 1921 "
#                  'after the National Park Service was established in 1916. Hot '
#                  'Springs is the smallest and only National Park in an urban '
#                  'area and is based around natural hot springs that flow out '
#                  'of the low lying Ouachita Mountains. The springs provide '
#                  'opportunities for relaxation in an historic setting; '
#                  'Bathhouse Row preserves numerous examples of 19th-century '
#                  'architecture.',
#   'id': 'park_hot-springs',
#   'image': {'attribution': 'Wikipedia/@YinanChen',
#             'attribution_url': 'https://commons.wikimedia.org/wiki/File%3AGfp-arkansas-hot-springs-steam-from-spring.jpg',
#             'url': 'hot-springs.jpg'},
#   'nps_link': 'https://www.nps.gov/hosp/index.htm',
#   'states': [{'id': 'state_arkansas', 'title': 'Arkansas'}],
#   'title': 'Hot Springs',
#   'visitors': '1,544,300',
#   'world_heritage_site': False},
#  {'area': {'acres': '571,790.11', 'square_km': '2,314.0'},
#   'coordinates': {'latitude': 48.1, 'longitude': -88.55},
#   'date_established_readable': 'April 3, 1940',
#   'date_established_unix': -938718000,
#   'description': 'The largest island in Lake Superior is a place of isolation '
#                  'and wilderness. Along with its many shipwrecks, waterways, '
#                  'and hiking trails, the park also includes over 400 smaller '
#                  'islands within 4.5 miles (7.2 km) of its shores. There are '
#                  'only 20 mammal species on the entire island, though the '
#                  'relationship between its wolf and moose populations is '
#                  'especially unique.',
#   'id': 'park_isle-royale',
#   'image': {'attribution': 'Flickr/@rtdphotography',
#             'attribution_url': 'https://www.flickr.com/photos/rtdphotography/3047464978',
#             'url': 'isle-royale.jpg'},
#   'nps_link': 'https://www.nps.gov/isro/index.htm',
#   'states': [{'id': 'state_michigan', 'title': 'Michigan'}],
#   'title': 'Isle Royale',
#   'visitors': '24,966',
#   'world_heritage_site': False},
#  {'area': {'acres': '790,635.74', 'square_km': '3,199.6'},
#   'coordinates': {'latitude': 33.79, 'longitude': -115.9},
#   'date_established_readable': 'October 31, 1994',
#   'date_established_unix': 783583200,
#   'description': 'Covering large areas of the Colorado and Mojave Deserts and '
#                  'the Little San Bernardino Mountains, this desert landscape '
#                  'is populated by vast stands of Joshua trees. Large changes '
#                  'in elevation reveal various contrasting environments '
#                  'including bleached sand dunes, dry lakes, rugged mountains, '
#                  'and maze-like clusters of monzogranite monoliths.',
#   'id': 'park_joshua-tree',
#   'image': {'attribution': 'PixelBay/@nightowl',
#             'attribution_url': 'https://pixabay.com/en/users/nightowl-29/',
#             'url': 'joshua-tree.jpg'},
#   'nps_link': 'https://www.nps.gov/jotr/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Joshua Tree',
#   'visitors': '2,505,286',
#   'world_heritage_site': False},
#  {'area': {'acres': '3,674,529.33', 'square_km': '14,870.3'},
#   'coordinates': {'latitude': 58.5, 'longitude': -155},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'This park on the Alaska Peninsula protects the Valley of Ten '
#                  'Thousand Smokes, an ash flow formed by the 1912 eruption of '
#                  'Novarupta, as well as Mount Katmai. Over 2,000 grizzly bears '
#                  'come here each year to catch spawning salmon. Other wildlife '
#                  'includes caribou, wolves, moose, and wolverines.',
#   'id': 'park_katmai',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'katmai.jpg'},
#   'nps_link': 'https://www.nps.gov/katm/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Katmai',
#   'visitors': '37,818',
#   'world_heritage_site': False},
#  {'area': {'acres': '669,983.65', 'square_km': '2,711.3'},
#   'coordinates': {'latitude': 59.92, 'longitude': -149.65},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'Near Seward on the Kenai Peninsula, this park protects the '
#                  'Harding Icefield and at least 38 glaciers and fjords '
#                  'stemming from it. The only area accessible to the public by '
#                  'road is Exit Glacier; the rest must be viewed or reached '
#                  'from boat tours.',
#   'id': 'park_kenai-fjords',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'kenai-fjords.jpg'},
#   'nps_link': 'https://www.nps.gov/kefj/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Kenai Fjords',
#   'visitors': '346,534',
#   'world_heritage_site': False},
#  {'area': {'acres': '461,901.20', 'square_km': '1,869.2'},
#   'coordinates': {'latitude': 36.8, 'longitude': -118.55},
#   'date_established_readable': 'March 4, 1940',
#   'date_established_unix': -941306400,
#   'description': 'Home to several giant sequoia groves and the General Grant '
#                  "Tree, the world's second largest measured tree, this park "
#                  'also features part of the Kings River, sculptor of the '
#                  'dramatic granite canyon that is its namesake, and the San '
#                  'Joaquin River, as well as Boyden Cave.',
#   'id': 'park_kings-canyon',
#   'image': {'attribution': 'PixelBay/@tdellav',
#             'attribution_url': 'https://pixabay.com/en/users/tdellav-889026/',
#             'url': 'kings-canyon.jpg'},
#   'nps_link': 'https://www.nps.gov/seki/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Kings Canyon',
#   'visitors': '607,479',
#   'world_heritage_site': False},
#  {'area': {'acres': '1,750,716.16', 'square_km': '7,084.9'},
#   'coordinates': {'latitude': 67.55, 'longitude': -159.28},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'Kobuk Valley protects 61 miles (98 km) of the Kobuk River '
#                  'and three regions of sand dunes. Created by glaciers, the '
#                  'Great Kobuk, Little Kobuk, and Hunt River Sand Dunes can '
#                  'reach 100 feet (30 m) high and 100 °F (38 °C), and they are '
#                  'the largest dunes in the Arctic. Twice a year, half a '
#                  'million caribou migrate through the dunes and across river '
#                  'bluffs that expose well-preserved ice age fossils.',
#   'id': 'park_kobuk-valley',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'kobuk-valley.jpg'},
#   'nps_link': 'https://www.nps.gov/kova/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Kobuk Valley',
#   'visitors': '15,500',
#   'world_heritage_site': False},
#  {'area': {'acres': '2,619,816.49', 'square_km': '10,602.0'},
#   'coordinates': {'latitude': 60.97, 'longitude': -153.42},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'The region around Lake Clark features four active volcanoes, '
#                  'including Mount Redoubt, as well as an abundance of rivers, '
#                  'glaciers, and waterfalls. Temperate rainforests, a tundra '
#                  'plateau, and three mountain ranges complete the landscape.',
#   'id': 'park_lake-clark',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'lake-clark.jpg'},
#   'nps_link': 'https://www.nps.gov/lacl/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Lake Clark',
#   'visitors': '21,102',
#   'world_heritage_site': False},
#  {'area': {'acres': '106,589.02', 'square_km': '431.4'},
#   'coordinates': {'latitude': 40.49, 'longitude': -121.51},
#   'date_established_readable': 'August 9, 1916',
#   'date_established_unix': -1685041200,
#   'description': 'Lassen Peak, the largest plug dome volcano in the world, is '
#                  'joined by all three other types of volcanoes in this park: '
#                  'shield, cinder dome, and composite. Though Lassen itself '
#                  'last erupted in 1915, most of the rest of the park is '
#                  'continuously active. Numerous hydrothermal features, '
#                  'including fumaroles, boiling pools, and bubbling mud pots, '
#                  'are heated by molten rock from beneath the peak.',
#   'id': 'park_lassen-volcanic',
#   'image': {'attribution': 'PixelBay/@SteenJepsen',
#             'attribution_url': 'https://pixabay.com/en/users/SteenJepsen-1490089/',
#             'url': 'lassen-volcanic.jpg'},
#   'nps_link': 'https://www.nps.gov/lavo/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Lassen Volcanic',
#   'visitors': '536,068',
#   'world_heritage_site': False},
#  {'area': {'acres': '52,830.19', 'square_km': '213.8'},
#   'coordinates': {'latitude': 37.18, 'longitude': -86.1},
#   'date_established_readable': 'July 1, 1941',
#   'date_established_unix': -899492400,
#   'description': 'With more than 400 miles (640 km) of passageways explored, '
#                  "Mammoth Cave is the world's longest known cave system. "
#                  'Subterranean wildlife includes eight bat species, Kentucky '
#                  'cave shrimp, Northern cavefish, and cave salamanders. Above '
#                  'ground, the park provides recreation on the Green River, 70 '
#                  'miles of hiking trails, and plenty of sinkholes and springs.',
#   'id': 'park_mammoth-cave',
#   'image': {'attribution': 'Wikipedia/@DanielSchwen',
#             'attribution_url': 'https://commons.wikimedia.org/wiki/File%3AMammoth_Cave_tour.jpg',
#             'url': 'mammoth-cave.jpg'},
#   'nps_link': 'https://www.nps.gov/maca/index.htm',
#   'states': [{'id': 'state_kentucky', 'title': 'Kentucky'}],
#   'title': 'Mammoth Cave',
#   'visitors': '586,514',
#   'world_heritage_site': True},
#  {'area': {'acres': '52,485.17', 'square_km': '212.4'},
#   'coordinates': {'latitude': 37.18, 'longitude': -108.49},
#   'date_established_readable': 'June 29, 1906',
#   'date_established_unix': -2004202800,
#   'description': 'This area constitutes over 4,000 archaeological sites of the '
#                  'Ancestral Puebloan people, who lived here and elsewhere in '
#                  'the Four Corners region for at least 700 years. Cliff '
#                  'dwellings built in the 12th and 13th centuries include Cliff '
#                  'Palace, which has 150 rooms and 23 kivas, and the Balcony '
#                  'House, with its many passages and tunnels.',
#   'id': 'park_mesa-verde',
#   'image': {'attribution': 'PixelBay/@kaylee',
#             'attribution_url': 'https://pixabay.com/en/users/kaylee-393151/',
#             'url': 'mesa-verde.jpg'},
#   'nps_link': 'https://www.nps.gov/meve/index.htm',
#   'states': [{'id': 'state_colorado', 'title': 'Colorado'}],
#   'title': 'Mesa Verde',
#   'visitors': '583,527',
#   'world_heritage_site': True},
#  {'area': {'acres': '236,381.64', 'square_km': '956.6'},
#   'coordinates': {'latitude': 46.85, 'longitude': -121.75},
#   'date_established_readable': 'March 2, 1899',
#   'date_established_unix': -2235319200,
#   'description': 'Mount Rainier, an active stratovolcano, is the most '
#                  'prominent peak in the Cascades and is covered by 26 named '
#                  'glaciers including Carbon Glacier and Emmons Glacier, the '
#                  'largest in the contiguous United States. The mountain is '
#                  'popular for climbing, and more than half of the park is '
#                  'covered by subalpine and alpine forests and meadows '
#                  'seasonally in bloom with wildflowers. Paradise on the south '
#                  'slope is the snowiest place on Earth where snowfall is '
#                  'measured regularly. The Longmire visitor center is the start '
#                  'of the Wonderland Trail, which encircles the mountain.',
#   'id': 'park_mount-rainier',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'mount-rainier.jpg'},
#   'nps_link': 'https://www.nps.gov/mora/index.htm',
#   'states': [{'id': 'state_washington', 'title': 'Washington'}],
#   'title': 'Mount Rainier',
#   'visitors': '1,356,913',
#   'world_heritage_site': False},
#  {'area': {'acres': '504,780.94', 'square_km': '2,042.8'},
#   'coordinates': {'latitude': 48.7, 'longitude': -121.2},
#   'date_established_readable': 'October 2, 1968',
#   'date_established_unix': -39380400,
#   'description': 'This complex encompasses two units of the National Park '
#                  'itself as well as the Ross Lake and Lake Chelan National '
#                  'Recreation Areas. The highly glaciated mountains are '
#                  'spectacular examples of Cascade geology. Popular hiking and '
#                  'climbing areas include Cascade Pass, Mount Shuksan, Mount '
#                  'Triumph, and Eldorado Peak.',
#   'id': 'park_north-cascades',
#   'image': {'attribution': 'PixelBay/@carolynhasemail',
#             'attribution_url': 'https://pixabay.com/en/users/carolynhasemail-2321451/',
#             'url': 'north-cascades.jpg'},
#   'nps_link': 'https://www.nps.gov/noca/index.htm',
#   'states': [{'id': 'state_washington', 'title': 'Washington'}],
#   'title': 'North Cascades',
#   'visitors': '28,646',
#   'world_heritage_site': False},
#  {'area': {'acres': '922,650.10', 'square_km': '3,733.8'},
#   'coordinates': {'latitude': 47.97, 'longitude': -123.5},
#   'date_established_readable': 'June 29, 1938',
#   'date_established_unix': -994359600,
#   'description': 'Situated on the Olympic Peninsula, this park includes a wide '
#                  'range of ecosystems from Pacific shoreline to temperate '
#                  'rainforests to the alpine slopes of the Olympic Mountains, '
#                  'the tallest of which is Mount Olympus. The Hoh Rainforest '
#                  'and Quinault Rainforest are the wettest area in the '
#                  'contiguous United States, with the Hoh receiving an average '
#                  'of almost 12 ft (3.7 m) of rain every year.',
#   'id': 'park_olympic',
#   'image': {'attribution': 'PixelBay/@RogerMosley',
#             'attribution_url': 'https://pixabay.com/en/users/RogerMosley-4311868/',
#             'url': 'olympic.jpg'},
#   'nps_link': 'https://www.nps.gov/olym/index.htm',
#   'states': [{'id': 'state_washington', 'title': 'Washington'}],
#   'title': 'Olympic',
#   'visitors': '3,390,221',
#   'world_heritage_site': True},
#  {'area': {'acres': '221,415.77', 'square_km': '896.0'},
#   'coordinates': {'latitude': 35.07, 'longitude': -109.78},
#   'date_established_readable': 'December 9, 1962',
#   'date_established_unix': -222890400,
#   'description': 'This portion of the Chinle Formation has a large '
#                  'concentration of 225-million-year-old petrified wood. The '
#                  'surrounding Painted Desert features eroded cliffs of '
#                  'red-hued volcanic rock called bentonite. Dinosaur fossils '
#                  'and over 350 Native American sites are also protected in '
#                  'this park.',
#   'id': 'park_petrified-forest',
#   'image': {'attribution': 'PixelBay/@jillmackie',
#             'attribution_url': 'https://pixabay.com/en/users/jillmackie-176435/',
#             'url': 'petrified-forest.jpg'},
#   'nps_link': 'https://www.nps.gov/pefo/index.htm',
#   'states': [{'id': 'state_arizona', 'title': 'Arizona'}],
#   'title': 'Petrified Forest',
#   'visitors': '643,274',
#   'world_heritage_site': False},
#  {'area': {'acres': '26,685.73', 'square_km': '108.0'},
#   'coordinates': {'latitude': 36.48, 'longitude': -121.16},
#   'date_established_readable': 'January 10, 2013',
#   'date_established_unix': 1357797600,
#   'description': 'Named for the eroded leftovers of a portion of an extinct '
#                  "volcano, the park's massive black and gold monoliths of "
#                  'andesite and rhyolite are a popular destination for rock '
#                  'climbers. Hikers have access to trails crossing the Coast '
#                  'Range wilderness. The park is home to the endangered '
#                  'California condor (Gymnogyps californianus) and one of the '
#                  'few locations in the world where these extremely rare birds '
#                  'can be seen in the wild. Pinnacles also supports a dense '
#                  'population of prairie falcons, and more than 13 species of '
#                  'bat which populate its talus caves.',
#   'id': 'park_pinnacles',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'pinnacles.jpg'},
#   'nps_link': 'https://www.nps.gov/pinn/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Pinnacles',
#   'visitors': '215,555',
#   'world_heritage_site': False},
#  {'area': {'acres': '138,999.37', 'square_km': '562.5'},
#   'coordinates': {'latitude': 41.3, 'longitude': -124},
#   'date_established_readable': 'October 2, 1968',
#   'date_established_unix': -39380400,
#   'description': 'This park and the co-managed state parks protect almost half '
#                  'of all remaining coastal redwoods, the tallest trees on '
#                  'earth. There are three large river systems in this very '
#                  'seismically active area, and 37 miles (60 km) of protected '
#                  'coastline reveal tide pools and seastacks. The prairie, '
#                  'estuary, coast, river, and forest ecosystems contain a wide '
#                  'variety of animal and plant species.',
#   'id': 'park_redwood',
#   'image': {'attribution': 'PixelBay/@12019',
#             'attribution_url': 'https://pixabay.com/en/users/12019-12019/',
#             'url': 'redwood.jpg'},
#   'nps_link': 'https://www.nps.gov/redw/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Redwood',
#   'visitors': '536,297',
#   'world_heritage_site': True},
#  {'area': {'acres': '265,795.20', 'square_km': '1,075.6'},
#   'coordinates': {'latitude': 40.4, 'longitude': -105.58},
#   'date_established_readable': 'January 26, 1915',
#   'date_established_unix': -1733508000,
#   'description': 'Bisected north to south by the Continental Divide, this '
#                  'portion of the Rockies has ecosystems varying from over 150 '
#                  'riparian lakes to montane and subalpine forests to treeless '
#                  'alpine tundra. Wildlife including mule deer, bighorn sheep, '
#                  'black bears, and cougars inhabit its igneous mountains and '
#                  'glacial valleys. Longs Peak, a classic Colorado fourteener, '
#                  'and the scenic Bear Lake are popular destinations, as well '
#                  'as the historic Trail Ridge Road, which reaches an elevation '
#                  'of more than 12,000 feet (3,700 m).',
#   'id': 'park_rocky-mountain',
#   'image': {'attribution': '@kevinnayar',
#             'attribution_url': 'https://kevinnayar.github.io/',
#             'url': 'rocky-mountain.jpg'},
#   'nps_link': 'https://www.nps.gov/romo/index.htm',
#   'states': [{'id': 'state_colorado', 'title': 'Colorado'}],
#   'title': 'Rocky Mountain',
#   'visitors': '4,517,585',
#   'world_heritage_site': False},
#  {'area': {'acres': '91,715.72', 'square_km': '371.2'},
#   'coordinates': {'latitude': 32.25, 'longitude': -110.5},
#   'date_established_readable': 'October 14, 1994',
#   'date_established_unix': 782110800,
#   'description': 'Split into the separate Rincon Mountain and Tucson Mountain '
#                  'districts, this park is evidence that the dry Sonoran Desert '
#                  'is still home to a great variety of life spanning six biotic '
#                  'communities. Beyond the namesake giant saguaro cacti, there '
#                  'are barrel cacti, chollas, and prickly pears, as well as '
#                  'lesser long-nosed bats, spotted owls, and javelinas.',
#   'id': 'park_saguaro',
#   'image': {'attribution': 'PixelBay/@dehenderson',
#             'attribution_url': 'https://pixabay.com/en/users/dehenderson-6454660/',
#             'url': 'saguaro.jpg'},
#   'nps_link': 'https://www.nps.gov/sagu/index.htm',
#   'states': [{'id': 'state_arizona', 'title': 'Arizona'}],
#   'title': 'Saguaro',
#   'visitors': '820,426',
#   'world_heritage_site': False},
#  {'area': {'acres': '404,062.63', 'square_km': '1,635.2'},
#   'coordinates': {'latitude': 36.43, 'longitude': -118.68},
#   'date_established_readable': 'September 25, 1890',
#   'date_established_unix': -2501434800,
#   'description': 'This park protects the Giant Forest, which boasts some of '
#                  "the world's largest trees, the General Sherman being the "
#                  'largest measured tree in the park. Other features include '
#                  'over 240 caves, a long segment of the Sierra Nevada '
#                  'including the tallest mountain in the contiguous United '
#                  'States, and Moro Rock, a large granite dome.',
#   'id': 'park_sequoia',
#   'image': {'attribution': 'PixelBay/@tripastute',
#             'attribution_url': 'https://pixabay.com/en/users/tripastute-5640805/',
#             'url': 'sequoia.jpg'},
#   'nps_link': 'https://www.nps.gov/seki/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Sequoia',
#   'visitors': '1,254,688',
#   'world_heritage_site': False},
#  {'area': {'acres': '199,195.27', 'square_km': '806.1'},
#   'coordinates': {'latitude': 38.53, 'longitude': -78.35},
#   'date_established_readable': 'December 26, 1935',
#   'date_established_unix': -1073498400,
#   'description': "Shenandoah's Blue Ridge Mountains are covered by hardwood "
#                  'forests that teem with a wide variety of wildlife. The '
#                  'Skyline Drive and Appalachian Trail run the entire length of '
#                  'this narrow park, along with more than 500 miles (800 km) of '
#                  'hiking trails passing scenic overlooks and cataracts of the '
#                  'Shenandoah River.',
#   'id': 'park_shenandoah',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'shenandoah.jpg'},
#   'nps_link': 'https://www.nps.gov/shen/index.htm',
#   'states': [{'id': 'state_virginia', 'title': 'Virginia'}],
#   'title': 'Shenandoah',
#   'visitors': '1,437,341',
#   'world_heritage_site': False},
#  {'area': {'acres': '70,446.89', 'square_km': '285.1'},
#   'coordinates': {'latitude': 46.97, 'longitude': -103.45},
#   'date_established_readable': 'November 10, 1978',
#   'date_established_unix': 279525600,
#   'description': 'This region that enticed and influenced President Theodore '
#                  'Roosevelt consists of a park of three units in the northern '
#                  "badlands. Besides Roosevelt's historic cabin, there are "
#                  'numerous scenic drives and backcountry hiking opportunities. '
#                  'Wildlife includes American bison, pronghorn, bighorn sheep, '
#                  'and wild horses.',
#   'id': 'park_theodore-roosevelt',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'theodore-roosevelt.jpg'},
#   'nps_link': 'https://www.nps.gov/thro/index.htm',
#   'states': [{'id': 'state_north-dakota', 'title': 'North Dakota'}],
#   'title': 'Theodore Roosevelt',
#   'visitors': '753,880',
#   'world_heritage_site': False},
#  {'area': {'acres': '14,948.46', 'square_km': '60.5'},
#   'coordinates': {'latitude': 18.33, 'longitude': -64.73},
#   'date_established_readable': 'August 2, 1956',
#   'date_established_unix': -423342000,
#   'description': 'This island park on Saint John preserves Taíno '
#                  'archaeological sites and the ruins of sugar plantations from '
#                  "Columbus's time, as well as all the natural environs. "
#                  'Surrounding the pristine beaches are mangrove forests, '
#                  'seagrass beds, and coral reefs.',
#   'id': 'park_virgin-islands',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'virgin-islands.jpg'},
#   'nps_link': 'https://www.nps.gov/viis/index.htm',
#   'states': [{'id': 'state_us-virgin-islands', 'title': 'US Virgin Islands'}],
#   'title': 'Virgin Islands',
#   'visitors': '411,343',
#   'world_heritage_site': False},
#  {'area': {'acres': '218,200.15', 'square_km': '883.0'},
#   'coordinates': {'latitude': 48.5, 'longitude': -92.88},
#   'date_established_readable': 'January 8, 1971',
#   'date_established_unix': 32162400,
#   'description': 'This park protecting four lakes near the Canada–US border is '
#                  'a site for canoeing, kayaking, and fishing. The park also '
#                  'preserves a history populated by Ojibwe Native Americans, '
#                  'French fur traders called voyageurs, and gold miners. Formed '
#                  'by glaciers, the region features tall bluffs, rock gardens, '
#                  'islands, bays, and several historic buildings.',
#   'id': 'park_voyageurs',
#   'image': {'attribution': 'PixelBay/@Goodfreephotos_com',
#             'attribution_url': 'https://pixabay.com/en/users/Goodfreephotos_com-10388/',
#             'url': 'voyageurs.jpg'},
#   'nps_link': 'https://www.nps.gov/voya/index.htm',
#   'states': [{'id': 'state_minnesota', 'title': 'Minnesota'}],
#   'title': 'Voyageurs',
#   'visitors': '241,912',
#   'world_heritage_site': False},
#  {'area': {'acres': '33,970.84', 'square_km': '137.5'},
#   'coordinates': {'latitude': 43.57, 'longitude': -103.48},
#   'date_established_readable': 'January 9, 1903',
#   'date_established_unix': -2113668000,
#   'description': 'Wind Cave is distinctive for its calcite fin formations '
#                  'called boxwork, a unique formation rarely found elsewhere, '
#                  'and needle-like growths called frostwork. The cave is one of '
#                  'the longest and most complex caves in the world. Above '
#                  'ground is a mixed-grass prairie with animals such as bison, '
#                  'black-footed ferrets, and prairie dogs, and ponderosa pine '
#                  'forests that are home to cougars and elk. The cave is '
#                  'culturally significant to the Lakota people as the site '
#                  "'from which Wakan Tanka, the Great Mystery, sent the buffalo "
#                  "out into their hunting grounds.'",
#   'id': 'park_wind-cave',
#   'image': {'attribution': 'NPS',
#             'attribution_url': 'https://www.nps.gov',
#             'url': 'wind-cave.jpg'},
#   'nps_link': 'https://www.nps.gov/wica/index.htm',
#   'states': [{'id': 'state_south-dakota', 'title': 'South Dakota'}],
#   'title': 'Wind Cave',
#   'visitors': '617,377',
#   'world_heritage_site': False},
#  {'area': {'acres': '8,323,146.48', 'square_km': '33,682.6'},
#   'coordinates': {'latitude': 61, 'longitude': -142},
#   'date_established_readable': 'December 2, 1980',
#   'date_established_unix': 344584800,
#   'description': 'An over 8 million acres (32,375 km2) plot of mountainous '
#                  'country—the largest National Park in the system—protects the '
#                  'convergence of the Alaska, Chugach, and Wrangell-Saint Elias '
#                  "Ranges, which include many of the continent's tallest "
#                  'mountains and volcanoes, including the 18,008-foot Mount '
#                  'Saint Elias. More than a quarter of the park is covered with '
#                  'glaciers, including the tidewater Hubbard Glacier, piedmont '
#                  'Malaspina Glacier, and valley Nabesna Glacier.',
#   'id': 'park_wrangell–st.-elias',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'wrangell-st-elias.jpg'},
#   'nps_link': 'https://www.nps.gov/wrst/index.htm',
#   'states': [{'id': 'state_alaska', 'title': 'Alaska'}],
#   'title': 'Wrangell–St. Elias',
#   'visitors': '79,047',
#   'world_heritage_site': True},
#  {'area': {'acres': '2,219,790.71', 'square_km': '8,983.2'},
#   'coordinates': {'latitude': 44.6, 'longitude': -110.5},
#   'date_established_readable': 'March 1, 1872',
#   'date_established_unix': -3087396000,
#   'description': 'Situated on the Yellowstone Caldera, the park has an '
#                  'expansive network of geothermal areas including boiling mud '
#                  'pots, vividly colored hot springs such as Grand Prismatic '
#                  'Spring, and regularly erupting geysers, the best-known being '
#                  'Old Faithful. The yellow-hued Grand Canyon of the '
#                  'Yellowstone River contains several high waterfalls, while '
#                  'four mountain ranges traverse the park. More than 60 mammal '
#                  'species including gray wolves, grizzly bears, black bears, '
#                  'lynxes, bison, and elk, make this park one of the best '
#                  'wildlife viewing spots in the country.',
#   'id': 'park_yellowstone',
#   'image': {'attribution': 'PixelBay/@Skeeze',
#             'attribution_url': 'https://pixabay.com/en/users/skeeze-272447/',
#             'url': 'yellowstone.jpg'},
#   'nps_link': 'https://www.nps.gov/yell/index.htm',
#   'states': [{'id': 'state_wyoming', 'title': 'Wyoming'},
#              {'id': 'state_montana', 'title': 'Montana'},
#              {'id': 'state_idaho', 'title': 'Idaho'}],
#   'title': 'Yellowstone',
#   'visitors': '4,257,177',
#   'world_heritage_site': True},
#  {'area': {'acres': '761,747.50', 'square_km': '3,082.7'},
#   'coordinates': {'latitude': 37.83, 'longitude': -119.5},
#   'date_established_readable': 'October 1, 1890',
#   'date_established_unix': -2500916400,
#   'description': 'Yosemite features sheer granite cliffs, exceptionally tall '
#                  'waterfalls, and old-growth forests at a unique intersection '
#                  'of geology and hydrology. Half Dome and El Capitan rise from '
#                  "the park's centerpiece, the glacier-carved Yosemite Valley, "
#                  'and from its vertical walls drop Yosemite Falls, one of '
#                  "North America's tallest waterfalls at 2,425 feet (739 m) "
#                  'high. Three giant sequoia groves, along with a pristine '
#                  'wilderness in the heart of the Sierra Nevada, are home to a '
#                  'wide variety of rare plant and animal species.',
#   'id': 'park_yosemite',
#   'image': {'attribution': 'PixelBay/@Free-Photos',
#             'attribution_url': 'https://pixabay.com/en/users/Free-Photos-242387/',
#             'url': 'yosemite.jpg'},
#   'nps_link': 'https://www.nps.gov/yose/index.htm',
#   'states': [{'id': 'state_california', 'title': 'California'}],
#   'title': 'Yosemite',
#   'visitors': '5,028,868',
#   'world_heritage_site': True},
#  {'area': {'acres': '147,237.02', 'square_km': '595.8'},
#   'coordinates': {'latitude': 37.3, 'longitude': -113.05},
#   'date_established_readable': 'November 19, 1919',
#   'date_established_unix': -1581616800,
#   'description': 'Located at the junction of the Colorado Plateau, Great '
#                  'Basin, and Mojave Desert, this park contains sandstone '
#                  'features such as mesas, rock towers, and canyons, including '
#                  'the Virgin River Narrows. The various sandstone formations '
#                  'and the forks of the Virgin River create a wilderness '
#                  'divided into four ecosystems: desert, riparian, woodland, '
#                  'and coniferous forest.',
#   'id': 'park_zion',
#   'image': {'attribution': '@kevinnayar',
#             'attribution_url': 'https://kevinnayar.github.io/',
#             'url': 'zion.jpg'},
#   'nps_link': 'https://www.nps.gov/zion/index.htm',
#   'states': [{'id': 'state_utah', 'title': 'Utah'}],
#   'title': 'Zion',
#   'visitors': '4,295,127',
#   'world_heritage_site': False}]

# %%
# 2 - Create a dictionary of the number of national parks per state
    # - json np file is list of national parks
    # - each item is a park
    # - loop thru each item at index 'state', add state to dictonary and increase frequency by 1 

# 3 - create empty dictionary to hold state counts
npStateCount = {}

# 4 - iterate thru each national park to extract the state 
for np in np_data: # each of these is a nat park
    # 4a - iterate thru each state for parks state list
    for state in np["states"]:  
    
        if state["title"] in npStateCount.keys():
            npStateCount[state["title"]] += 1
        else:
            npStateCount[state["title"]] = 1

npStateCount
# Out:
# {'Maine': 1,
#  'American Samoa': 1,
#  'Utah': 5,
#  'South Dakota': 2,
#  'Texas': 2,
#  'Florida': 3,
#  'Colorado': 4,
#  'New Mexico': 1,
#  'California': 9,
#  'South Carolina': 1,
#  'Oregon': 1,
#  'Ohio': 1,
#  'Nevada': 2,
#  'Alaska': 8,
#  'Montana': 2,
#  'Arizona': 3,
#  'Wyoming': 2,
#  'Tennessee': 1,
#  'North Carolina': 1,
#  'Hawaii': 2,
#  'Arkansas': 1,
#  'Michigan': 1,
#  'Kentucky': 1,
#  'Washington': 3,
#  'Virginia': 1,
#  'North Dakota': 1,
#  'US Virgin Islands': 1,
#  'Minnesota': 1,
#  'Idaho': 1}

# %%
# this is a list 
np_data[0]["states"][0]["title"]
# Out:
# 'Maine'
